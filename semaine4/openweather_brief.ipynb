# %% [markdown]
# # Imports and env set up

# %%
import requests
import pandas as pd
from typing import Optional
import os
from dotenv import load_dotenv
import datetime

# %%
if load_dotenv():
    API_KEY = os.getenv("open_weather_apikey")
else:
    print('cant find any open weather api key')
    exit()

# %% [markdown]
# # Custom functions

# %%
def coordinate_retrieve(city_name: str, api_key: str = API_KEY) -> Optional[tuple]:
    url = "https://api.openweathermap.org/geo/1.0/direct"

    params = {"q": city_name,
              "appid": api_key,
              "lang": "en",
              'limit': 1}
    try:
        response = requests.get(url, params=params).json()
        return response[0]['lat'], response[0]['lon']
    except Exception as e:
        return (e.args[0])

# %%
def get_current_weather(city_name, api_key: str = API_KEY) -> Optional[
    str]:
    # latitude,longitude = coordinate_retrieve(city_name, api_key)
    url = "https://api.openweathermap.org/data/2.5/weather"
    params = {
        'q': city_name,
        'appid': api_key,
        'units': 'metric',  # pour obtenir les données en degrés Celsius
        'lang': 'fr'
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        weather = {
            'city': data['name'],
            'temperature': data['main']['temp'],
            'temp_min': data['main']['temp_min'],
            'temp_max': data['main']['temp_max'],
            'description': data['weather'][0]['description'],
            'humidity': data['main']['humidity'],
            'pressure': data['main']['pressure'],
            'wind_speed': data['wind']['speed'],
            'local_time': str(datetime.datetime.fromtimestamp(data['dt']).astimezone(
                datetime.timezone(datetime.timedelta(seconds=data['timezone']))))
        }
        return weather
    else:
        return None

# %%
def weather_over5(city_name, api_key: str = API_KEY) -> Optional[
    pd.DataFrame]:
    url = "https://api.openweathermap.org/data/2.5/forecast"
    params = {
        'q': city_name,
        'appid': api_key,
        'units': 'metric',  # pour obtenir les données en degrés Celsius
        'lang': 'fr'
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        result = []
        for item in data['list']:
            weather = {
                'city': data['city']['name'],
                'temperature': item['main']['temp'],
                'temp_min': item['main']['temp_min'],
                'temp_max': item['main']['temp_max'],
                'weather': item['weather'][0]['description'],
                'humidity': item['main']['humidity'],
                'pressure': item['main']['pressure'],
                'wind_speed': item['wind']['speed'],
                'local_time': str(datetime.datetime.fromtimestamp(item['dt']).astimezone(
                    datetime.timezone(datetime.timedelta(seconds=data['city']['timezone']))))
            }
            result.append(weather)
        return pd.DataFrame.from_dict(result)
    else:
        return None

# %%
def get_air_pollution_data(city_name: str, api_key: str = API_KEY) -> Optional[
    str]:
    url = "https://api.openweathermap.org/data/2.5/air_pollution"
    latitude, longitude = coordinate_retrieve(city_name)
    params = {
        'lat': latitude,
        'lon': longitude,
        'appid': api_key,
        'lang': 'fr'
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()['list']
        result = {
            'city': city_name,
            'aqi': data[0]['main']['aqi'],
            'co': data[0]['components']['co'],
            'no': data[0]['components']['no'],
            'no2': data[0]['components']['no2'],
            'o3': data[0]['components']['o3'],
            'so2': data[0]['components']['so2'],
            'pm2_5': data[0]['components']['pm2_5'],
            'pm10': data[0]['components']['pm10'],
            'nh3': data[0]['components']['nh3'],
            'local_time': str(datetime.datetime.fromtimestamp(data[0]['dt']))
        }
        return result
    else:
        return None

# %%
def air_pollution_data_over5(city_name: str, start: int, api_key: str = API_KEY) -> Optional[
    pd.DataFrame]:
    url = "https://api.openweathermap.org/data/2.5/air_pollution/history"
    latitude, longitude = coordinate_retrieve(city_name)
    end = int((datetime.datetime.fromtimestamp(start) + datetime.timedelta(days=4)).timestamp())
    params = {
        'lat': latitude,
        'lon': longitude,
        'start': start,
        'end': end,
        'appid': api_key,
    }
    response = requests.get(url, params=params)
    # print(response.status_code)
    if response.status_code == 200:
        results = []
        data = response.json()['list']
        for item in data:
            result = {
                'city': city_name,
                'aqi': item['main']['aqi'],
                'co': item['components']['co'],
                'no': item['components']['no'],
                'no2': item['components']['no2'],
                'o3': item['components']['o3'],
                'so2': item['components']['so2'],
                'pm2_5': item['components']['pm2_5'],
                'pm10': item['components']['pm10'],
                'nh3': item['components']['nh3'],
                'local_time': str(datetime.datetime.fromtimestamp(item['dt']))
            }
            results.append(result)
        return pd.DataFrame.from_records(results)
    else:
        return None

# %% [markdown]
# # API CAll examples

# %% [markdown]
# ## Single weather data API call

# %%
weather = get_current_weather('Paris')
if weather:
    print(f"Weather in {weather['city']}:")
    print(f"Temperature: {weather['temperature']}°C")
    print(f"Description: {weather['description']}")
    print(f"Humidity: {weather['humidity']}%")
    print(f"Pressure: {weather['pressure']} hPa")
    print(f"Wind Speed: {weather['wind_speed']} m/s")
else:
    print("Failed to get weather data")
# Out:
# Weather in Paris:
# Temperature: 22.13°C
# Description: nuageux
# Humidity: 54%
# Pressure: 1015 hPa
# Wind Speed: 8.23 m/s

# %% [markdown]
# ## 5 day / 3 hours weather forecast

# %%
weather_over5('Paris')
# Out:
#      city  temperature  temp_min  temp_max                weather  humidity  \
# 0   Paris        22.18     22.18     22.53           légère pluie        52
# 1   Paris        21.76     21.63     21.76           légère pluie        56
# 2   Paris        18.89     18.89     18.89                couvert        68
# 3   Paris        17.88     17.88     17.88                couvert        70
# 4   Paris        15.93     15.93     15.93                nuageux        77
# 5   Paris        16.95     16.95     16.95  partiellement nuageux        73
# 6   Paris        22.28     22.28     22.28            ciel dégagé        51
# 7   Paris        26.66     26.66     26.66            ciel dégagé        35
# 8   Paris        27.80     27.80     27.80            ciel dégagé        31
# 9   Paris        25.72     25.72     25.72            peu nuageux        38
# 10  Paris        22.45     22.45     22.45                couvert        56
# 11  Paris        20.12     20.12     20.12                couvert        63
# 12  Paris        18.58     18.58     18.58                couvert        68
# 13  Paris        19.23     19.23     19.23                couvert        68
# 14  Paris        23.94     23.94     23.94                couvert        48
# 15  Paris        27.36     27.36     27.36                couvert        36
# 16  Paris        29.60     29.60     29.60  partiellement nuageux        31
# 17  Paris        27.79     27.79     27.79                nuageux        38
# 18  Paris        23.92     23.92     23.92  partiellement nuageux        58
# 19  Paris        21.84     21.84     21.84                nuageux        68
# 20  Paris        20.47     20.47     20.47                couvert        73
# 21  Paris        21.12     21.12     21.12                couvert        69
# 34      1015        2.65  2024-07-20 23:00:00+02:00
# 35      1015        1.00  2024-07-21 02:00:00+02:00
# 36      1015        0.44  2024-07-21 05:00:00+02:00
# 37      1015        0.87  2024-07-21 08:00:00+02:00
# 38      1015        2.56  2024-07-21 11:00:00+02:00
# 39      1013        4.02  2024-07-21 14:00:00+02:00

# %%
weather_over5('Shanghai')
# Out:
#         city  temperature  temp_min  temp_max                weather  \
# 0   Shanghai        30.28     27.95     30.28  partiellement nuageux
# 1   Shanghai        28.60     27.18     28.60                nuageux
# 2   Shanghai        26.41     26.41     26.41                nuageux
# 3   Shanghai        29.29     29.29     29.29                nuageux
# 4   Shanghai        33.80     33.80     33.80                couvert
# 5   Shanghai        36.48     36.48     36.48                couvert
# 6   Shanghai        36.08     36.08     36.08  partiellement nuageux
# 7   Shanghai        29.92     29.92     29.92                nuageux
# 8   Shanghai        28.93     28.93     28.93                couvert
# 9   Shanghai        28.14     28.14     28.14                couvert
# 10  Shanghai        27.46     27.46     27.46                couvert
# 11  Shanghai        32.46     32.46     32.46                nuageux
# 12  Shanghai        37.72     37.72     37.72                nuageux
# 13  Shanghai        38.14     38.14     38.14                couvert
# 14  Shanghai        33.68     33.68     33.68           légère pluie
# 15  Shanghai        29.26     29.26     29.26                couvert
# 16  Shanghai        29.76     29.76     29.76                couvert
# 17  Shanghai        29.21     29.21     29.21                couvert
# 18  Shanghai        27.89     27.89     27.89           légère pluie
# 19  Shanghai        31.14     31.14     31.14                couvert
# 20  Shanghai        36.74     36.74     36.74                couvert
# 21  Shanghai        36.31     36.31     36.31                couvert
# 22  Shanghai        32.03     32.03     32.03                couvert
# 23  Shanghai        29.02     29.02     29.02                couvert
# 24  Shanghai        28.73     28.73     28.73                couvert
# 25  Shanghai        28.34     28.34     28.34                couvert
# 26  Shanghai        27.93     27.93     27.93                couvert
# 27  Shanghai        31.09     31.09     31.09                couvert
# 28  Shanghai        35.17     35.17     35.17                couvert
# 29  Shanghai        37.25     37.25     37.25                couvert
# 30  Shanghai        33.93     33.93     33.93                nuageux
# 31  Shanghai        30.05     30.05     30.05           légère pluie
# 32  Shanghai        28.17     28.17     28.17                couvert
# 33  Shanghai        27.87     27.87     27.87                couvert
# 34  Shanghai        27.64     27.64     27.64                couvert
# 35  Shanghai        30.21     30.21     30.21                couvert
# 36  Shanghai        34.29     34.29     34.29                couvert
# 37  Shanghai        35.86     35.86     35.86                couvert
# 38  Shanghai        32.81     32.81     32.81                couvert
# 39  Shanghai        29.23     29.23     29.23                couvert
#
#     humidity  pressure  wind_speed                 local_time
# 0         82      1008        4.75  2024-07-16 23:00:00+08:00
# 1         83      1008        4.40  2024-07-17 02:00:00+08:00
# 2         85      1007        3.91  2024-07-17 05:00:00+08:00
# 3         72      1007        4.11  2024-07-17 08:00:00+08:00
# 4         53      1007        4.03  2024-07-17 11:00:00+08:00
# 5         45      1006        3.46  2024-07-17 14:00:00+08:00
# 13  Toronto        16.01     16.01     16.01            ciel dégagé        75
# 14  Toronto        14.96     14.96     14.96            ciel dégagé        83
# 15  Toronto        16.09     16.09     16.09            ciel dégagé        71
# 16  Toronto        19.46     19.46     19.46            ciel dégagé        57
# 17  Toronto        21.49     21.49     21.49            peu nuageux        46
# 18  Toronto        21.30     21.30     21.30  partiellement nuageux        47
# 19  Toronto        19.15     19.15     19.15  partiellement nuageux        62
# 20  Toronto        16.74     16.74     16.74            ciel dégagé        72
# 21  Toronto        15.69     15.69     15.69  partiellement nuageux        75
# 22  Toronto        14.74     14.74     14.74            ciel dégagé        78
# 23  Toronto        16.98     16.98     16.98            ciel dégagé        63
# 24  Toronto        22.20     22.20     22.20            ciel dégagé        43
# 25  Toronto        24.47     24.47     24.47            ciel dégagé        40
# 26  Toronto        25.05     25.05     25.05            ciel dégagé        43
# 27  Toronto        23.02     23.02     23.02            ciel dégagé        56
# 28  Toronto        19.45     19.45     19.45            ciel dégagé        69
# 29  Toronto        17.66     17.66     17.66            ciel dégagé        65
# 30  Toronto        16.60     16.60     16.60            ciel dégagé        59
# 31  Toronto        18.54     18.54     18.54            ciel dégagé        64
# 32  Toronto        23.99     23.99     23.99            ciel dégagé        55
# 33  Toronto        27.39     27.39     27.39            ciel dégagé        42
# 34  Toronto        27.76     27.76     27.76  partiellement nuageux        38
# 35  Toronto        24.54     24.54     24.54  partiellement nuageux        53
# 36  Toronto        20.91     20.91     20.91            ciel dégagé        68
# 37  Toronto        19.51     19.51     19.51            ciel dégagé        74
# 38  Toronto        18.48     18.48     18.48            ciel dégagé        78
# 39  Toronto        20.29     20.29     20.29            peu nuageux        71
#
#     pressure  wind_speed                 local_time
# 0       1005        2.42  2024-07-16 11:00:00-04:00
# 1       1006        1.10  2024-07-16 14:00:00-04:00
# 2       1006        3.88  2024-07-16 17:00:00-04:00
# 3       1007        3.31  2024-07-16 20:00:00-04:00
# 4       1007        1.86  2024-07-16 23:00:00-04:00
# 5       1008        2.18  2024-07-17 02:00:00-04:00
# 6       1007        1.80  2024-07-17 05:00:00-04:00
# 7       1009        1.71  2024-07-17 08:00:00-04:00
# 8       1009        2.38  2024-07-17 11:00:00-04:00
# 9       1009        4.24  2024-07-17 14:00:00-04:00
# 10      1010        4.75  2024-07-17 17:00:00-04:00
# 11      1011        4.15  2024-07-17 20:00:00-04:00
# 12      1013        4.22  2024-07-17 23:00:00-04:00
# 13      1014        3.37  2024-07-18 02:00:00-04:00
# 14      1015        3.32  2024-07-18 05:00:00-04:00
# 15      1017        4.00  2024-07-18 08:00:00-04:00
# 16      1018        4.20  2024-07-18 11:00:00-04:00
# 17      1018        4.71  2024-07-18 14:00:00-04:00
# 18      1018        4.17  2024-07-18 17:00:00-04:00
# 19      1018        3.42  2024-07-18 20:00:00-04:00
# 20      1019        2.76  2024-07-18 23:00:00-04:00
# 21      1019        2.61  2024-07-19 02:00:00-04:00
# 22      1019        2.56  2024-07-19 05:00:00-04:00
# 23      1020        1.76  2024-07-19 08:00:00-04:00
# 24      1020        1.51  2024-07-19 11:00:00-04:00
# 25      1019        2.45  2024-07-19 14:00:00-04:00
# 26      1018        3.35  2024-07-19 17:00:00-04:00
# 27      1018        3.22  2024-07-19 20:00:00-04:00
# 28      1019        2.24  2024-07-19 23:00:00-04:00
# 29      1019        2.07  2024-07-20 02:00:00-04:00
# 30      1019        1.82  2024-07-20 05:00:00-04:00
# 31      1019        1.66  2024-07-20 08:00:00-04:00
# 32      1019        2.08  2024-07-20 11:00:00-04:00
# 33      1018        1.75  2024-07-20 14:00:00-04:00
# 34      1017        4.74  2024-07-20 17:00:00-04:00
# 35      1019        4.03  2024-07-20 20:00:00-04:00
# 36      1020        2.57  2024-07-20 23:00:00-04:00
# 37      1020        2.27  2024-07-21 02:00:00-04:00
# 38      1021        1.25  2024-07-21 05:00:00-04:00
# 39      1021        0.34  2024-07-21 08:00:00-04:00

# %% [markdown]
# ## Single Air Pollution data api call

# %%
get_air_pollution_data('Paris')
# Out:
# {'city': 'Paris',
#  'aqi': 2,
#  'co': 158.55,
#  'no': 0.35,
#  'no2': 1.41,
#  'o3': 62.94,
#  'so2': 0.5,
#  'pm2_5': 0.56,
#  'pm10': 0.79,
#  'nh3': 0.57,
#  'local_time': '2024-07-16 14:12:44'}

# %% [markdown]
# ## Forecast for 4 days ahead with 1-hour step

# %%
stamp = int(datetime.datetime.now().timestamp())
air_pollution_data_over5('Paris', stamp)
# Out:
#      city  aqi      co    no   no2     o3   so2  pm2_5  pm10   nh3  \
# 0   Paris    2  160.22  0.30  1.22  65.09  0.46   0.50  0.70  0.55
# 1   Paris    2  160.22  0.28  1.30  65.80  0.45   0.50  0.68  0.56
# 2   Paris    2  161.89  0.28  1.59  65.80  0.45   0.50  0.67  0.63
# 3   Paris    2  161.89  0.24  1.86  65.80  0.49   0.50  0.67  0.74
# 4   Paris    2  163.56  0.17  2.10  65.80  0.57   0.52  0.72  0.89
# ..    ...  ...     ...   ...   ...    ...   ...    ...   ...   ...
# 91  Paris    1  181.91  2.26  6.17  41.49  0.94   4.17  5.80  2.09
# 92  Paris    1  181.91  1.76  4.67  50.07  0.97   3.62  5.05  2.22
# 93  Paris    2  183.58  0.56  2.96  68.67  0.75   2.94  3.98  1.69
# 94  Paris    2  181.91  0.37  2.25  76.53  0.69   3.12  4.07  1.57
# 95  Paris    2  178.58  0.31  2.01  81.54  0.76   3.74  4.71  1.52
#
#              local_time
# 0   2024-07-16 15:00:00
# 1   2024-07-16 16:00:00
# 2   2024-07-16 17:00:00
# 3   2024-07-16 18:00:00
# 4   2024-07-16 19:00:00
# ..                  ...
# 91  2024-07-20 10:00:00
# 92  2024-07-20 11:00:00
# 93  2024-07-20 12:00:00
# 94  2024-07-20 13:00:00
# 95  2024-07-20 14:00:00
#
# [96 rows x 11 columns]

# %%
air_pollution_data_over5('Shanghai', stamp)
# Out:
#         city  aqi       co      no     no2    o3      so2   pm2_5    pm10  \
# 0   Shanghai    5  2056.12  107.29   61.69  0.00   350.95   49.04   72.62
# 1   Shanghai    5  2082.82  109.08   56.21  0.00   350.95   48.25   70.84
# 2   Shanghai    5  2216.34  119.81   55.52  0.00   377.66   51.70   74.60
# 3   Shanghai    5  2376.56  128.75   56.89  0.00   404.36   54.01   76.73
# 4   Shanghai    5  2269.75  121.59   57.58  0.00   392.91   51.77   73.12
# ..       ...  ...      ...     ...     ...   ...      ...     ...     ...
# 91  Shanghai    5  3952.03  153.78  167.25  9.48   625.61  111.52  139.69
# 92  Shanghai    5  4753.11  219.94  164.51  4.02   694.28  135.42  169.10
# 93  Shanghai    5  6034.85  318.29  169.99  1.16   862.12  179.54  223.47
# 94  Shanghai    5  8117.68  457.76  183.70  0.07  1159.67  255.17  308.03
# 95  Shanghai    5  5233.77  303.98  132.98  0.00   740.05  178.76  220.11
#
#     nh3           local_time
# 0   0.0  2024-07-16 15:00:00
# 1   0.0  2024-07-16 16:00:00
# 2   0.0  2024-07-16 17:00:00
# 3   0.0  2024-07-16 18:00:00
# 4   0.0  2024-07-16 19:00:00
# ..  ...                  ...
# 91  0.0  2024-07-20 10:00:00
# 92  0.0  2024-07-20 11:00:00
# 93  0.0  2024-07-20 12:00:00
# 94  0.0  2024-07-20 13:00:00
# 95  0.0  2024-07-20 14:00:00
#
# [96 rows x 11 columns]

# %%
air_pollution_data_over5('Toronto', stamp)
# Out:
#        city  aqi      co     no    no2     o3    so2  pm2_5   pm10   nh3  \
# 0   Toronto    2  373.84   0.18  29.47  29.68  13.11  14.59  16.05  1.44
# 1   Toronto    2  370.50   0.40  29.13  22.17  12.52  12.97  14.08  1.36
# 2   Toronto    2  357.15   1.15  26.05  21.28  11.68  10.37  11.29  1.25
# 3   Toronto    1  330.45   2.18  21.25  27.54  10.49   7.55   8.28  1.06
# 4   Toronto    1  317.10   2.46  18.34  36.84   9.78   5.89   6.55  1.00
# ..      ...  ...     ...    ...    ...    ...    ...    ...    ...   ...
# 91  Toronto    1  253.68   0.05  10.11  20.74   2.15   4.00   5.12  0.61
# 92  Toronto    1  250.34   0.13  10.54  15.74   2.27   4.23   5.42  0.52
# 93  Toronto    1  260.35   0.37  11.82  10.73   2.47   4.40   5.81  0.55
# 94  Toronto    1  317.10   2.63  16.11   5.99   3.37   4.62   6.55  1.01
# 95  Toronto    1  427.25  10.73  17.99  10.10   4.53   5.07   7.58  1.92
#
#              local_time
# 0   2024-07-16 15:00:00
# 1   2024-07-16 16:00:00
# 2   2024-07-16 17:00:00
# 3   2024-07-16 18:00:00
# 4   2024-07-16 19:00:00
# ..                  ...
# 91  2024-07-20 10:00:00
# 92  2024-07-20 11:00:00
# 93  2024-07-20 12:00:00
# 94  2024-07-20 13:00:00
# 95  2024-07-20 14:00:00
#
# [96 rows x 11 columns]
