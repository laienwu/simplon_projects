# %% [markdown]
# # Projet Movies Database
#
# on considère, pour la suite, la base de données de Mflix Movies qui est déja installé dans le serveur MongoDB de votre Atlas Cluster.
#
# Dans cette base de données, nous disposons d'une collection contenant les informations de plus de 23000 films .
#
# Pour chaque film, nous avons des informations sur le:title, year, genres, countries ..
#
# => l'objectif est de l'exploiter..

# %% [markdown]
# # 1- Se connecter à la BDD Mflix
#
# - Se connecter au serveur MongoDB de votre Atlas cluster
#
# - Vérifier que les bases de données samples sont bien chargées sur votre cluster Atlas :
#
# https://www.mongodb.com/docs/atlas/sample-data/
#
# - Afficher les collections de la base de données : sample_mflix
#
# - Afficher le nombre de documents par collection

# %%
#import dependencies
import pymongo
from openpyxl.descriptors import ASCII
from pymongo import MongoClient, ASCENDING
import os
from dotenv import load_dotenv

# %%
try:
    load_dotenv()
    usr = os.getenv("mongo_atlas_usr")
    pwd = os.getenv("mongo_atlas_pw")
    api_key = os.getenv("mongo_altas_api")
except Exception as e:
    print(f"Error loading environment variables: {e}")
    exit()

# %%
#replace "uri" with your Atlas URI string - should look like mongodb+srv://...
db_name = "sample_mflix"
uri = f"mongodb+srv://{usr}:{pwd}@cluster0.xxqem.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(uri)
client
# Out:
# MongoClient(host=['cluster0-shard-00-00.xxqem.mongodb.net:27017', 'cluster0-shard-00-02.xxqem.mongodb.net:27017', 'cluster0-shard-00-01.xxqem.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-lbggfj-shard-0', tls=True)

# %% [markdown]
# Le constructeur MongoClient accepte en plus de l'adresse du cluster Atlas, de nombreux paramètres facultatifs.
# On peut définir le pool de connexions maximal, les problèmes de lecture et d’écriture par défaut, s’il faut réessayer les écritures, configurer SSL, l’authentification ...

# %% [markdown]
# * Afficher les collections de la base de données : sample_mflix
# * afficher le nombre de documents par collection

# %%
#Display available databases.
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
#Let's use the sample_mflix database, display available collections

mflix = client.sample_mflix
#mflix = client['sample_mflix']
mflix.list_collection_names()
# Out:
# ['sessions', 'comments', 'users', 'embedded_movies', 'theaters', 'movies']

# %%
# Afficher le nombre de documents par collection
mflix.movies.count_documents({})
# Out:
# 21349

# %%
movies = mflix.movies
movies.count_documents({})
# Out:
# 21349

# %% [markdown]
# # 2- Exploiter les données de Mflix

# %%
movies.find_one()
# Out:
# {'_id': ObjectId('573a1390f29313caabcd42e8'),
#  'plot': 'A group of bandits stage a brazen train hold-up, only to find a determined posse hot on their heels.',
#  'genres': ['Short', 'Western'],
#  'runtime': 11,
#  'cast': ['A.C. Abadie',
#   "Gilbert M. 'Broncho Billy' Anderson",
#   'George Barnes',
#   'Justus D. Barnes'],
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU3NjE5NzYtYTYyNS00MDVmLWIwYjgtMmYwYWIxZDYyNzU2XkEyXkFqcGdeQXVyNzQzNzQxNzI@._V1_SY1000_SX677_AL_.jpg',
#  'title': 'The Great Train Robbery',
#  'fullplot': "Among the earliest existing films in American cinema - notable as the first film that presented a narrative story to tell - it depicts a group of cowboy outlaws who hold up a train and rob the passengers. They are then pursued by a Sheriff's posse. Several scenes have color included - all hand tinted.",
#  'languages': ['English'],
#  'released': datetime.datetime(1903, 12, 1, 0, 0),
#  'directors': ['Edwin S. Porter'],
#  'rated': 'TV-G',
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-08-13 00:27:59.177000000',
#  'year': 1903,
#  'imdb': {'rating': 7.4, 'votes': 9847, 'id': 439},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 2559, 'meter': 75},
#   'fresh': 6,
#   'critic': {'rating': 7.6, 'numReviews': 6, 'meter': 100},
#   'rotten': 0,
#   'lastUpdated': datetime.datetime(2015, 8, 8, 19, 16, 10)},
#  'num_mflix_comments': 0}

# %% [markdown]
# * Combien ya t il de documents avec l'attribut year en string? et combien sont ils en int?

# %%
# Requête d'agrégation pour compter les types de 'year' et 'int'
pipeline = [
    {
        "$facet": {
            "year_string_format": [
                {"$match": {"year": {"$type": "string"}}},
                {"$count": "count"}
            ],
            "year_int_format": [
                {"$match": {"year": {"$type": "int"}}},
                {"$count": "count"}
            ],
            "total": [
                {"$count": "count"}
            ]
        }
    }
]

# Exécution de l'agrégation
result = list(movies.aggregate(pipeline))
result
# Out:
# [{'year_string_format': [{'count': 35}],
#   'year_int_format': [{'count': 21314}],
#   'total': [{'count': 21349}]}]

# %% [markdown]
#
# - Combien de films ou "Salma Hayek" a participé, afficher ces documents en se limitant au title et la liste des acteurs

# %%
movies.count_documents({"cast": {"$in": ["Salma Hayek"]}})
# Out:
# 20

# %% [markdown]
# * Combien de films nommés: "The Journey", la fonction find() retourne un objet itérable et non pas un document !
# * Afficher pour chaque document :le titre, l'année et la liste des genres .

# %%
#using find
result = movies.find(
    {
        "title": "The Journey"
    },
    {
        'genres': 1,
        'title': 1,
        'year': 1,
        '_id': 0
    }
)

# Converting the result cursor to a list
the_journey_list = list(result)
the_journey_list
# Out:
# [{'genres': ['Drama'], 'title': 'The Journey', 'year': 1986},
#  {'genres': ['Drama', 'History'], 'title': 'The Journey', 'year': 1992},
#  {'genres': ['Comedy', 'Drama'], 'title': 'The Journey', 'year': 1997},
#  {'genres': ['Documentary', 'Adventure'],
#   'title': 'The Journey',
#   'year': 2001},
#  {'genres': ['Drama', 'Romance'], 'title': 'The Journey', 'year': 2004},
#  {'genres': ['Comedy', 'Drama', 'Family'],
#   'title': 'The Journey',
#   'year': 2014}]

# %%
pipeline = [
    {
        "$match": {
            "title": 'The Journey'
        }
    },
    {
        "$project": {
            'genres': 1,
            "title": 1,
            "year": 1,
            '_id': 0
        }
    }]

the_journey_list = list(movies.aggregate(pipeline))

print(len(the_journey_list))
the_journey_list
# Out:
# 6
# [{'genres': ['Drama'], 'title': 'The Journey', 'year': 1986},
#  {'genres': ['Drama', 'History'], 'title': 'The Journey', 'year': 1992},
#  {'genres': ['Comedy', 'Drama'], 'title': 'The Journey', 'year': 1997},
#  {'genres': ['Documentary', 'Adventure'],
#   'title': 'The Journey',
#   'year': 2001},
#  {'genres': ['Drama', 'Romance'], 'title': 'The Journey', 'year': 2004},
#  {'genres': ['Comedy', 'Drama', 'Family'],
#   'title': 'The Journey',
#   'year': 2014}]

# %% [markdown]
# ## faites le max des requetes ci dessous:
#
# - afficher les 12 titres de la collection movies à partir du dixième inclus ,
#
# - afficher le résultat trié par ordre alphabétique décroissant
#
# - Lister ts les films produits en 1979 ?
#
# - Afficher les infos sur le film dont le title est "Alien" produit en 1979 ?
#
# - Trouver ts les films qui ont gagné 100 awards ?
#
# - Tous les films dont le titre commence par 'Re' ?
#
# - Tous les films produits après 2010 et avant 2015 ?
#
# - Afficher les films joués par l'acteur "Tom Cruise",sortis après  l'année 2000, en se limitant au titre du film et la liste des acteurs ?
#
# - Afficher tous les détails du film de "Tom Cruise",sorti en 2014, sauf son fullplot
#
# - Chercher les films dans lesquels joue au moins un des acteurs suivants : Angelina Jolie,Brad Pitt
#
# - Chercher les films dont on ne trouve aucun acteur de la liste suivante: Sandra Bullock,Tom Hanks,Julia Roberts,Kevin Spacey,George Clooney
#
# - Lister les films parus en 2016 ou avec qui ont gagné 100 awards
#
# - Lister les films parus après 2010 et dans lesquels l'un de ces acteurs a jouéSandra Bullock,Tom Hanks,Julia Roberts,Kevin Spacey,George Clooney
#
# - Combien de films a comme director Clint Eastwood
#
# - De la liste précédente  et dans la collection comments de la BDD sample_mflix, combien de films ont été commentés

# %%
#afficher les 12 titres de la collection movies à partir du dixième inclu:
[movie['title'] for movie in movies.find().skip(9).limit(12)]
# Out:
# ['Civilization',
#  'Where Are My Children?',
#  'The Poor Little Rich Girl',
#  'Wild and Woolly',
#  'The Blue Bird',
#  'From Hand to Mouth',
#  'High and Dizzy',
#  'One Week',
#  'The Saphead',
#  'The Ace of Hearts',
#  'The Four Horsemen of the Apocalypse',
#  'Miss Lulu Bett']

# %%
#afficher les 12 titres de la collection movies à partir du dixième inclus, ordre décroissant
pipeline = [
    {
        "$sort": {
            "title": -1
        }
    },
    {
        "$project": {
            "title": 1,
            "_id": 0
        }

    },
    {
        "$skip": 9
    },
    {
        "$limit": 12
    }
]

result = list(movies.aggregate(pipeline))
result
# Out:
# [{'title': 'èVivan las Antipodas!'},
#  {'title': 'èAy, Carmela!'},
#  {'title': 'èA volar joven!'},
#  {'title': 'è nos amours'},
#  {'title': 'è moi seule'},
#  {'title': 'è Paè, è'},
#  {'title': 'è Nous la Libertè'},
#  {'title': 'xXx: State of the Union'},
#  {'title': 'xXx'},
#  {'title': 'tom thumb'},
#  {'title': 's/y Glèdjen'},
#  {'title': 'iMurders'}]

# %%
# Lister tous les films produits en 1979 ?
pipeline = [
    {
        "$match": {
            "year": 1979
        }
    },
    {
        "$project": {
            "result": ["$title", "$year"],
            "_id": 0
        }
    }
]
[([a for _, a in v.items()][0]) for v in movies.aggregate(pipeline)]
# Out:
# [['Julio Begins in July', 1979],
#  ['Life Sentence', 1979],
#  ['Buck Rogers in the 25th Century', 1979],
#  ['Family Nest', 1979],
#  ['Hungarian Rhapsody', 1979],
#  ['Cop or Hood', 1979],
#  ['Traffic Jam', 1979],
#  ['Iskanderija... lih?', 1979],
#  ['Joi Baba Felunath: The Elephant God', 1979],
#  ['The Clonus Horror', 1979],
#  ['Un uomo in ginocchio', 1979],
#  ['...And Justice for All.', 1979],
#  ['10', 1979],
#  ['Agatha', 1979],
#  ["The Concorde... Airport '79", 1979],
#  ['Alien', 1979],
#  ['The Amityville Horror', 1979],
#  ['Love on the Run', 1979],
#  ['Camera Buff', 1979],
#  ['All That Jazz', 1979],
#  ['Apocalypse Now', 1979],
#  ['Arabian Adventure', 1979],
#  ['Rapture', 1979],
#  ['Being There', 1979],
#  ['Beyond the Poseidon Adventure', 1979],
#  ['The Black Hole', 1979],
#  ['Best Boy', 1979],
#  ['The Black Stallion', 1979],
#  ['The Tin Drum', 1979],
#  ['The Brood', 1979],
#  ['The Bugs Bunny/Road-Runner Movie', 1979],
#  ['Buffet Froid', 1979],
#  ['Breaking Away', 1979],
#  ['The Champ', 1979],
#  ['Chapter Two', 1979],
#  ['Chiedo asilo', 1979],
#  ['Caro papè', 1979],
#  ['Womanlight', 1979],
#  ['The China Syndrome', 1979],
#  ['Coup de tète', 1979],
#  ['Que Viva Mexico', 1979],
#  ['The Dark', 1979],
#  ['To Forget Venice', 1979],
#  ['Don Giovanni', 1979],
#  ['The Marriage of Maria Braun', 1979],
#  ['The Electric Horseman', 1979],
#  ['Elvis', 1979],
#  ["Eagle's Wing", 1979],
#  ['Dracula', 1979],
#  ['Ernesto', 1979],
#  ['The Europeans', 1979],
#  ['Tales from the Vienna Woods', 1979],
#  ['Going in Style', 1979],
#  ['The Troops & Aliens', 1979],
#  ['Il giocattolo', 1979],
#  ['The Great Santini', 1979],
#  ['The Hamburg Syndrome', 1979],
#  ['Hair', 1979],
#  ['Hardcore', 1979],
#  ['I as in Icarus', 1979],
#  ['Io sto con gli ippopotami', 1979],
#  ['The Jericho Mile', 1979],
#  ['I Am Maria', 1979],
#  ['Kramer vs. Kramer', 1979],
#  ['A Little Romance', 1979],
#  ['Love at First Bite', 1979],
#  ['Luna', 1979],
#  ['A Performance of Macbeth', 1979],
#  ['Hungarian Rhapsody', 1979],
#  ['The Main Event', 1979],
#  ['Mad Max', 1979],
#  ['Velvet Hands', 1979],
#  ['Meatballs', 1979],
#  ['Manhattan', 1979],
#  ['The Miracle Worker', 1979],
#  ['Moonraker', 1979],
#  ['Murder by Natural Causes', 1979],
#  ['The Muppet Movie', 1979],
#  ['Murder by Decree', 1979],
#  ['My Brilliant Career', 1979],
#  ['North Dallas Forty', 1979],
#  ['Norma Rae', 1979],
#  ['Nightwing', 1979],
#  ['Nosferatu the Vampyre', 1979],
#  ['Nutcracker Fantasy', 1979],
#  ['Ogro', 1979],
#  ['The Onion Field', 1979],
#  ['Autumn Marathon', 1979],
#  ['Panny z Wilka', 1979],
#  ['Phantasm', 1979],
#  ['Doing Time', 1979],
#  ['Five Evenings', 1979],
#  ['Radio On', 1979],
#  ['Rich Kids', 1979],
#  ['Rocky II', 1979],
#  ['The Castle of Cagliostro', 1979],
#  ['The Rose', 1979],
#  ['Running', 1979],
#  ['Saint Jack', 1979],
#  ["Salem's Lot", 1979],
#  ['Uno sceriffo extraterrestre... poco extra e molto terrestre', 1979],
#  ['The Seduction of Joe Tynan', 1979],
#  ['Siberiade', 1979],
#  ['Les soeurs Brontè', 1979],
#  ['One More Minute', 1979],
#  ['One More Minute', 1979],
#  ['Starting Over', 1979],
#  ['Sèrie noire', 1979],
#  ['That Sinking Feeling', 1979],
#  ['Thirst', 1979],
#  ['Star Trek: The Motion Picture', 1979],
#  ['El Super', 1979],
#  ['Tale of Tales', 1979],
#  ['Tess', 1979],
#  ['Time After Time', 1979],
#  ['Zombie', 1979],
#  ['When a Stranger Calls', 1979],
#  ['Wise Blood', 1979],
#  ['Yanks', 1979],
#  ['Zulu Dawn', 1979],
#  ['Tinker Tailor Soldier Spy', 1979],
#  ['Galaxy Express 999', 1979],
#  ['Return of the Secaucus Seven', 1979],
#  ['The Burgos Trial', 1979],
#  ['The Thrushes Are Still Singing', 1979],
#  ['Nosferatu the Vampyre', 1979],
#  ['I Am Maria', 1979],
#  ['Year Zero: The Silent Death of Cambodia', 1979],
#  ['Galaxy Express 999', 1979],
#  ["The Halloween That Almost Wasn't", 1979],
#  ['Radio On', 1979]]

# %%
#Afficher les infos sur le film dont le title est "Alien" produit en 1979 ?
pipeline = [
    {
        "$match": {
            "title": "Alien",
            "year": 1979
        }
    },
    {
        "$project": {
            "title": 1,
            "year": 1,
            "cast": 1,
            '_id': 0
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'cast': ['Tom Skerritt',
#    'Sigourney Weaver',
#    'Veronica Cartwright',
#    'Harry Dean Stanton'],
#   'title': 'Alien',
#   'year': 1979}]

# %%
#Trouver ts les films qui ont gagné 100 awards ?
pipeline = [
    {
        "$match": {
            "awards.wins": {
                "$gte": 100
            }
        }
    },
    {
        "$project": {
            "title": 1,
            "_id": 0
        }
    }
]
movies.aggregate(pipeline)

# %%
#Tous les films dont le titre commence par 'Re' ?
pipeline = [
    {
        "$match": {
            "title": {
                "$regex": "^Re"
            }
        }
    },
    {
        "$project": {
            "title": 1,
            "_id": 0
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'title': 'Regeneration'},
#  {'title': 'Red Dust'},
#  {'title': 'Rembrandt'},
#  {'title': 'Report from the Aleutians'},
#  {'title': 'Red Meadows'},
#  {'title': 'Red River'},
#  {'title': 'Repast'},
#  {'title': 'Rear Window'},
#  {'title': 'Rebel Without a Cause'},
#  {'title': 'Requiem for a Heavyweight'},
#  {'title': 'Rece do gèry'},
#  {'title': 'Rengè kantai shirei chèkan: Yamamoto Isoroku'},
#  {'title': 'Reconstruction'},
#  {'title': 'Red Psalm'},
#  {'title': 'Reminiscences of a Journey to Lithuania'},
#  {'title': 'Release the Prisoners to Spring'},
#  {'title': 'Remember My Name'},
#  {'title': 'Revenge of the Pink Panther'},
#  {'title': 'Resurrection'},
#  {'title': 'Return of the Secaucus Seven'},
#  {'title': 'Revenge of the Stepford Wives'},
#  {'title': 'Reds'},
#  {'title': 'Red Bells Part I: Mexico on Fire'},
#  {'title': 'Reuben, Reuben'},
#  {'title': 'Reilly: Ace of Spies'},
#  {'title': 'Rembetiko'},
#  {'title': 'Repo Man'},
#  {'title': 'Red Dawn'},
#  {'title': 'Real Genius'},
#  {'title': 'Red Sonja'},
#  {'title': 'Rendez-vous'},
#  {'title': 'Restless Natives'},
#  {'title': 'Remo Williams: The Adventure Begins'},
#  {'title': 'Revolution'},
#  {'title': 'Return to Oz'},
#  {'title': 'Red Sorghum'},
#  {'title': 'Repentance'},
#  {'title': 'Rent-a-Cop'},
#  {'title': 'Return to Snowy River'},
#  {'title': 'Return of the Living Dead II'},
#  {'title': 'Recollections of the Yellow House'},
#  {'title': 'Renegades'},
#  {'title': 'Resurrected'},
#  {'title': 'Reunion'},
#  {'title': 'Red Dust'},
#  {'title': 'Repossessed'},
#  {'title': 'Return Home'},
#  {'title': 'Reversal of Fortune'},
#  {'title': 'Regarding Henry'},
#  {'title': 'Return to the Blue Lagoon'},
#  {'title': 'Rebels of the Neon God'},
#  {'title': 'Red Rock West'},
#  {'title': 'Reservoir Dogs'},
#  {'title': 'Return to Lonesome Dove'},
#  {'title': 'Return of the Living Dead III'},
#  {'title': 'Red Firecracker, Green Firecracker'},
#  {'title': 'Ready to Wear'},
#  {'title': 'Reality Bites'},
#  {'title': 'Rendezvous in Paris'},
#  {'title': 'Restoration'},
#  {'title': 'Rent-a-Kid'},
#  {'title': 'Regular Guys'},
#  {'title': "Rebound: The Legend of Earl 'The Goat' Manigault"},
#  {'title': 'Retroactive'},
#  {'title': 'Re dai yu'},
#  {'title': 'Red Corner'},
#  {'title': 'Resident Evil'},
#  {'title': 'Return to Me'},
#  {'title': 'Return to Paradise'},
#  {'title': 'Resurrection Man'},
#  {'title': 'Restaurant'},
#  {'title': "Relax... It's Just Sex"},
#  {'title': 'Rembrandt'},
#  {'title': 'Return with Honor'},
#  {'title': 'Requiem for a Dream'},
#  {'title': 'Reindeer Games'},
#  {'title': 'Red Planet'},
#  {'title': 'Red Dust'},
#  {'title': 'Remember the Titans'},
#  {'title': 'Ready to Rumble'},
#  {'title': 'Ready to Rumble'},
#  {'title': 'Restless'},
#  {'title': 'Replicant'},
#  {'title': 'Refugee'},
#  {'title': 'Reign of Fire'},
#  {'title': 'Revolution #9'},
#  {'title': 'Real Fiction'},
#  {'title': 'Read My Lips'},
#  {'title': 'Renegade'},
#  {'title': 'Revelation'},
#  {'title': 'Return to Never Land'},
#  {'title': 'Respiro'},
#  {'title': 'Revengers Tragedy'},
#  {'title': 'Red Dragon'},
#  {'title': 'Rent'},
#  {'title': 'Real Women Have Curves'},
#  {'title': 'Red Satin'},
#  {'title': 'Red Bear'},
#  {'title': 'Resident Evil: Apocalypse'},
#  {'title': 'Remember Me, My Love'},
#  {'title': 'Resurrection of the Little Match Girl'},
#  {'title': 'Returner'},
#  {'title': 'Ready, Steady, Charlie!'},
#  {'title': 'Revolver'},
#  {'title': 'Reconstruction'},
#  {'title': 'Rebound'},
#  {'title': 'Red Passport'},
#  {'title': 'Renaissance'},
#  {'title': 'Red Dust'},
#  {'title': 'Redemption: The Stan Tookie Williams Story'},
#  {'title': 'Repatriation'},
#  {'title': 'Return to Sender'},
#  {'title': 'Reefer Madness: The Movie Musical'},
#  {'title': 'Red Doors'},
#  {'title': 'Resurrecting the Champ'},
#  {'title': 'Red Eye'},
#  {'title': 'Restart'},
#  {'title': 'Red Cliff'},
#  {'title': 'Red Ants'},
#  {'title': 'Resident Evil: Extinction'},
#  {'title': 'Real Steel'},
#  {'title': 'Regular Lovers'},
#  {'title': 'Red Like the Sky'},
#  {'title': 'Requiem'},
#  {'title': 'Rescue Dawn'},
#  {'title': 'Red Tails'},
#  {'title': 'Reign Over Me'},
#  {'title': 'Read It and Weep'},
#  {'title': "Refugee All Stars, Sierra Leone's"},
#  {'title': 'Re-cycle'},
#  {'title': 'Reno 911!: Miami'},
#  {'title': 'Redline'},
#  {'title': 'Remember the Daze'},
#  {'title': 'Retrieval'},
#  {'title': 'Red Dog'},
#  {'title': 'Rendition'},
#  {'title': 'Religulous'},
#  {'title': 'Return to Halloweentown'},
#  {'title': 'Reprise'},
#  {'title': 'Return to House on Haunted Hill'},
#  {'title': 'Reservation Road'},
#  {'title': 'Requiem from Java'},
#  {'title': 'Red State'},
#  {'title': 'Recipes for Disaster'},
#  {'title': 'Redacted'},
#  {'title': 'Revolutionary Road'},
#  {'title': 'Repo! The Genetic Opera'},
#  {'title': 'Redland'},
#  {'title': 'Red'},
#  {'title': 'Real Time'},
#  {'title': 'Recount'},
#  {'title': 'Redbelt'},
#  {'title': 'Repo Men'},
#  {'title': 'Ready? OK!'},
#  {'title': 'Reykjavik Whale Watching Massacre'},
#  {'title': 'Red Sands'},
#  {'title': 'Resident Evil: Afterlife'},
#  {'title': 'Reykjavik-Rotterdam'},
#  {'title': 'Red Dawn'},
#  {'title': 'Rebellion'},
#  {'title': 'Revue'},
#  {'title': 'Red Cliff II'},
#  {'title': 'Rebirth'},
#  {'title': 'Resistance'},
#  {'title': 'Remember Me'},
#  {'title': 'Revenge of the Electric Car'},
#  {'title': 'Reflexèes de um Liquidificador'},
#  {'title': 'Reign of Assassins'},
#  {'title': 'Red White & Blue'},
#  {'title': 'Realnyy papa'},
#  {'title': 'Redline'},
#  {'title': 'Reel Injun'},
#  {'title': 'Red Riding Hood'},
#  {'title': 'Restless'},
#  {'title': 'Resurrecting the Street Walker'},
#  {'title': 'Red Hill'},
#  {'title': 'Retratos en un mar de mentiras'},
#  {'title': 'Restrepo'},
#  {'title': 'ReGeneration'},
#  {'title': 'Repeaters'},
#  {'title': 'Reindeerspotting - Escape from Santaland'},
#  {'title': 'Revenge of the Bridesmaids'},
#  {'title': 'Remembrance'},
#  {'title': 'Red Eagle'},
#  {'title': 'Red Lights'},
#  {'title': 'Resurrect Dead: The Mystery of the Toynbee Tiles'},
#  {'title': 'Reagan'},
#  {'title': 'Recoil'},
#  {'title': 'Reality'},
#  {'title': 'Resident Evil: Retribution'},
#  {'title': 'Requiem for a Village'},
#  {'title': 'Red Hook Summer'},
#  {'title': 'Redemption Trail'},
#  {'title': 'Real Playing Game'},
#  {'title': 'Renoir'},
#  {'title': 'Remote Area Medical'},
#  {'title': 'Reis e Ratos'},
#  {'title': 'Red Knot'},
#  {'title': 'Reaching for the Moon'},
#  {'title': "Return to Nim's Island"},
#  {'title': 'Restless'},
#  {'title': 'Rentaneko'},
#  {'title': 'Redirected'},
#  {'title': 'Real'},
#  {'title': 'Reincarnated'},
#  {'title': 'Revolution'},
#  {'title': 'Reality'},
#  {'title': 'Red Obsession'},
#  {'title': 'Regret!'},
#  {'title': 'Redemption'},
#  {'title': "Relationship Status: It's Complicated"},
#  {'title': 'Red Family'},
#  {'title': 'Red Army'},
#  {'title': 'Redeemer'},
#  {'title': 'Return to Ithaca'},
#  {'title': 'Regarding Susan Sontag'},
#  {'title': 'Remember Me?'},
#  {'title': 'Remember'},
#  {'title': 'Refugiado'},
#  {'title': 'Requisitos para ser una persona normal'},
#  {'title': 'Results'},
#  {'title': 'Remake, Remix, Rip-Off: About Copy Culture & Turkish Pop Cinema'}]

# %%
#Tous les films produits après 2010 et avant 2015 ?
pipeline = [
    {
        "$match": {
            "year": {
                "$gte": 2010,
                "$lte": 2015
            }
        }
    },
    {
        "$project": {
            "title": 1,
            "year": 1,
            "_id": 0
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'title': 'Pèl Adrienn', 'year': 2010},
#  {'year': 2010, 'title': 'In My Sleep'},
#  {'year': 2012, 'title': 'On the Road'},
#  {'year': 2013, 'title': 'The Secret Life of Walter Mitty'},
#  {'title': 'Jurassic World', 'year': 2015},
#  {'title': 'The Pacific', 'year': 2010},
#  {'title': 'The Rum Diary', 'year': 2011},
#  {'title': 'Gnomeo & Juliet', 'year': 2011},
#  {'title': 'The Three Stooges', 'year': 2012},
#  {'title': 'The Crimson Petal and the White', 'year': 2011},
#  {'title': 'Tangled', 'year': 2010},
#  {'title': 'John Carter', 'year': 2012},
#  {'title': 'Utomlyonnye solntsem 2: Predstoyanie', 'year': 2010},
#  {'title': 'Action Jackson', 'year': 2014},
#  {'year': 2013, 'title': 'In Secret'},
#  {'year': 2011, 'title': 'Cowboys & Aliens'},
#  {'title': 'The Stanford Prison Experiment', 'year': 2015},
#  {'title': 'Hemingway & Gellhorn', 'year': 2012},
#  {'year': 2010, 'title': 'Dinner for Schmucks'},
#  {'title': 'The A-Team', 'year': 2010},
#  {'title': 'The Possession', 'year': 2012},
#  {'year': 2011, 'title': 'Real Steel'},
#  {'year': 2014, 'title': 'The Giver'},
#  {'title': 'Toy Story 3', 'year': 2010},
#  {'year': 2012, 'title': 'Lincoln'},
#  {'title': '7 Days', 'year': 2010},
#  {'title': 'Scott Pilgrim vs. the World', 'year': 2010},
#  {'title': 'Puss in Boots', 'year': 2011},
#  {'title': 'Party Crashers', 'year': 2012},
#  {'year': 2012, 'title': 'Life of Pi'},
#  {'title': 'The Crazies', 'year': 2010},
#  {'year': 2014, 'title': 'The Equalizer'},
#  {'title': 'Captain America: The First Avenger', 'year': 2011},
#  {'title': 'Sin City: A Dame to Kill For', 'year': 2014},
#  {'title': 'Generation P', 'year': 2011},
#  {'year': 2010, 'title': 'Piranha 3D'},
#  {'year': 2011, 'title': 'Margaret'},
#  {'year': 2013, 'title': 'Alan Partridge'},
#  {'year': 2015, 'title': 'Ex Machina'},
#  {'title': 'Tower Heist', 'year': 2011},
#  {'title': 'The Smurfs', 'year': 2011},
#  {'year': 2011, 'title': 'The Mechanic'},
#  {'title': 'Prince of Persia: The Sands of Time', 'year': 2010},
#  {'year': 2012, 'title': 'On the Road'},
#  {'year': 2010, 'title': 'Unstoppable'},
#  {'title': 'Extremely Loud & Incredibly Close', 'year': 2011},
#  {'year': 2011, 'title': 'The Tree of Life'},
#  {'year': 2015, 'title': 'Ant-Man'},
#  {'year': 2011, 'title': 'Season of the Witch'},
#  {'title': 'Atlas Shrugged: Part I', 'year': 2011},
#  {'year': 2010, 'title': 'The Losers'},
#  {'title': 'The Croods', 'year': 2013},
#  {'title': 'Bandage', 'year': 2010},
#  {'year': 2010, 'title': 'Barry Munday'},
#  {'title': 'U Want Me 2 Kill Him?', 'year': 2013},
#  {'year': 2012, 'title': 'Red Tails'},
#  {'title': 'Something Borrowed', 'year': 2011},
#  {'year': 2010, 'title': 'Furry Vengeance'},
#  {'title': 'Ramona and Beezus', 'year': 2010},
#  {'title': "Who Is Harry Nilsson (And Why Is Everybody Talkin' About Him?)",
#   'year': 2010},
#  {'year': 2010, 'title': 'Love & Other Drugs'},
#  {'title': 'A Thousand Words', 'year': 2012},
#  {'year': 2013, 'title': 'Escape from Planet Earth'},
#  {'title': 'Samsara', 'year': 2011},
#  {'year': 2013, 'title': 'Man of Steel'},
#  {'title': "Who Is Harry Nilsson (And Why Is Everybody Talkin' About Him?)",
#   'year': 2010},
#  {'year': 2010, 'title': 'The Illusionist'},
#  {'year': 2010, 'title': 'Night Catches Us'},
#  {'title': 'Drive', 'year': 2011},
#  {'year': 2010, 'title': 'The Wolfman'},
#  {'title': 'The Attack', 'year': 2012},
#  {'year': 2014, 'title': 'The Boxtrolls'},
#  {'title': 'The Incredible Burt Wonderstone', 'year': 2013},
#  {'title': 'Dallas Buyers Club', 'year': 2013},
#  {'title': 'Elliot Loves', 'year': 2012},
#  {'year': 2010, 'title': 'The First Grader'},
#  {'year': 2012, 'title': 'Jack Reacher'},
#  {'year': 2013, 'title': 'Scary Movie 5'},
#  {'year': 2010, 'title': '13'},
#  {'year': 2010, 'title': 'Clash of the Titans'},
#  {'year': 2011, 'title': 'Thor'},
#  {'title': 'Red Dog', 'year': 2011},
#  {'year': 2010, 'title': "It's Kind of a Funny Story"},
#  {'title': 'A Letter to Elia', 'year': 2010},
#  {'year': 2010, 'title': 'Tooth Fairy'},
#  {'title': 'The Danish Girl', 'year': 2015},
#  {'title': 'Jack and Jill', 'year': 2011},
#  {'year': 2011, 'title': 'Take Me Home Tonight'},
#  {'year': 2012, 'title': 'The Do-Deca-Pentathlon'},
#  {'title': 'Percy Jackson & the Olympians: The Lightning Thief', 'year': 2010},
#  {'year': 2010, 'title': "She's Out of My League"},
#  {'year': 2013, 'title': 'The Book Thief'},
#  {'year': 2011, 'title': 'Conan the Barbarian'},
#  {'year': 2014, 'title': 'Interstellar'},
#  {'title': 'Flipped', 'year': 2010},
#  {'title': 'World War Z', 'year': 2013},
#  {'year': 2010, 'title': "Valentine's Day"},
#  {'title': 'Dreamkiller', 'year': 2010},
#  {'year': 2011, 'title': 'Priest'},
#  {'year': 2014, 'title': 'Dracula Untold'},
#  {'year': 2014, 'title': 'Godzilla'},
#  {'year': 2012, 'title': 'The Babymakers'},
#  {'title': 'Hotel Transylvania', 'year': 2012},
#  {'title': 'Bhopal: A Prayer for Rain', 'year': 2014},
#  {'title': 'The Town', 'year': 2010},
#  {'title': 'Everyday Sunshine: The Story of Fishbone', 'year': 2010},
#  {'year': 2010, 'title': 'The Kids Are All Right'},
#  {'year': 2011, 'title': 'Hoodwinked Too! Hood vs. Evil'},
#  {'year': 2012, 'title': 'The Avengers'},
#  {'title': 'Epic', 'year': 2013},
#  {'year': 2012, 'title': 'Jack & Diane'},
#  {'year': 2012, 'title': 'The Sweeney'},
#  {'title': 'Evangelion: 3.0 You Can (Not) Redo', 'year': 2012},
#  {'title': 'Lupin III', 'year': 2014},
#  {'year': 2014, 'title': 'Mr. Peabody & Sherman'},
#  {'title': '6 Month Rule', 'year': 2011},
#  {'year': 2010, 'title': 'My Soul to Take'},
#  {'year': 2011, 'title': 'Red State'},
#  {'title': 'Please Give', 'year': 2010},
#  {'year': 2010, 'title': 'Eat Pray Love'},
#  {'title': 'Sanctum', 'year': 2011},
#  {'title': 'Snitch', 'year': 2013},
#  {'title': 'Mr Hockey: The Gordie Howe Story', 'year': 2013},
#  {'year': 2013, 'title': "Legends of Oz: Dorothy's Return"},
#  {'year': 2015, 'title': 'The Wedding Ringer'},
#  {'year': 2010, 'title': 'The Switch'},
#  {'year': 2010, 'title': 'Letters to Juliet'},
#  {'year': 2010, 'title': 'How to Train Your Dragon'},
#  {'title': 'Shrek Forever After', 'year': 2010},
#  {'title': 'From Prada to Nada', 'year': 2011},
#  {'year': 2010, 'title': 'The Whistleblower'},
#  {'title': 'The Hobbit: An Unexpected Journey', 'year': 2012},
#  {'year': 2014, 'title': 'Love & Mercy'},
#  {'title': 'The Thing', 'year': 2011},
#  {'title': 'Prey', 'year': 2010},
#  {'title': 'Jackboots on Whitehall', 'year': 2010},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1', 'year': 2010},
#  {'title': 'Rabbit Hole', 'year': 2010},
#  {'title': 'The Last Airbender', 'year': 2010},
#  {'year': 2012, 'title': 'Silent Hill: Revelation 3D'},
#  {'title': 'Arthur 3: The War of the Two Worlds', 'year': 2010},
#  {'year': 2010, 'title': 'Salt'},
#  {'year': 2011, 'title': 'Source Code'},
#  {'year': 2010, 'title': 'Green Zone'},
#  {'year': 2010, 'title': 'Black Swan'},
#  {'year': 2012, 'title': 'The Amazing Spider-Man'},
#  {'title': 'The Killer Inside Me', 'year': 2010},
#  {'title': 'Robin Hood', 'year': 2010},
#  {'title': 'A Monster in Paris', 'year': 2011},
#  {'year': 2010, 'title': "The Sorcerer's Apprentice"},
#  {'year': 2010, 'title': 'The Fighter'},
#  {'title': 'The Conspirator', 'year': 2010},
#  {'title': 'Hugo', 'year': 2011},
#  {'year': 2010, 'title': 'Little Fockers'},
#  {'year': 2012, 'title': 'Hitchcock'},
#  {'title': 'Fair Game', 'year': 2010},
#  {'year': 2011, 'title': 'Sucker Punch'},
#  {'year': 2010,
#   'title': 'The Chronicles of Narnia: The Voyage of the Dawn Treader'},
#  {'title': 'Funkytown', 'year': 2011},
#  {'year': 2011, 'title': 'The Adventures of Tintin'},
#  {'year': 2010, 'title': 'Machete'},
#  {'year': 2010, 'title': 'Dear John'},
#  {'title': 'The Green Hornet', 'year': 2011},
#  {'year': 2013, 'title': 'The Wolf of Wall Street'},
#  {'title': 'Hanna', 'year': 2011},
#  {'year': 2011, 'title': 'Straw Dogs'},
#  {'year': 2010, 'title': 'Megamind'},
#  {'title': 'The Iron Lady', 'year': 2011},
#  {'year': 2010, 'title': 'Knight and Day'},
#  {'year': 2010, 'title': 'Dylan Dog: Dead of Night'},
#  {'title': 'Alice in Wonderland', 'year': 2010},
#  {'year': 2014, 'title': 'The Sisterhood of Night'},
#  {'year': 2010, 'title': 'Percy Jackson & the Olympians: The Lightning Thief'},
#  {'year': 2010, 'title': 'The Runaways'},
#  {'year': 2014, 'title': 'Selma'},
#  {'title': 'Centurion', 'year': 2010},
#  {'year': 2010, 'title': 'Babies'},
#  {'title': 'The Way Back', 'year': 2010},
#  {'title': 'Argo', 'year': 2012},
#  {'year': 2010, 'title': 'Wall Street: Money Never Sleeps'},
#  {'title': 'Secretariat', 'year': 2010},
#  {'title': 'Krrish 3', 'year': 2013},
#  {'title': 'Inseparable', 'year': 2011},
#  {'year': 2011, 'title': 'The Descendants'},
#  {'title': 'Iron Sky', 'year': 2012},
#  {'year': 2011, 'title': 'The Eagle'},
#  {'title': 'Everyday', 'year': 2012},
#  {'year': 2010, 'title': 'The Book of Eli'},
#  {'title': 'The Book of Eli', 'year': 2010},
#  {'title': 'The Story of Luke', 'year': 2012},
#  {'year': 2010, 'title': 'The Bounty Hunter'},
#  {'year': 2010, 'title': 'The Nutcracker in 3D'},
#  {'year': 2014, 'title': 'The Legend of Hercules'},
#  {'title': 'For the Good of Others', 'year': 2010},
#  {'year': 2012, 'title': 'Silver Linings Playbook'},
#  {'year': 2012, 'title': 'Unfinished Song'},
#  {'year': 2012, 'title': 'Parental Guidance'},
#  {'year': 2010, 'title': 'Howl'},
#  {'year': 2010, 'title': 'Repo Men'},
#  {'title': 'One Lucky Elephant', 'year': 2010},
#  {'title': 'Life as We Know It', 'year': 2010},
#  {'title': 'The Best Things in the World', 'year': 2010},
#  {'title': 'Bare Knuckles', 'year': 2010},
#  {'title': 'Boyhood', 'year': 2014},
#  {'year': 2011, 'title': 'Water for Elephants'},
#  {'year': 2013, 'title': 'Adult World'},
#  {'title': 'Game of Assassins', 'year': 2013},
#  {'year': 2011, 'title': 'Monte Carlo'},
#  {'year': 2011, 'title': 'Footloose'},
#  {'title': 'Midnight Son', 'year': 2011},
#  {'title': 'Elvis & Madona', 'year': 2010},
#  {'year': 2011, 'title': 'Ghost Rider: Spirit of Vengeance'},
#  {'title': 'Skyfall', 'year': 2012},
#  {'year': 2010, 'title': 'Jonah Hex'},
#  {'year': 2012, 'title': 'Dark Shadows'},
#  {'title': 'The Girl from the Naked Eye', 'year': 2012},
#  {'title': 'Happiness Runs', 'year': 2010},
#  {'title': 'Jack and the Beanstalk', 'year': 2010},
#  {'title': 'Richness of Internal Space', 'year': 2012},
#  {'title': 'A Princess for Christmas', 'year': 2011},
#  {'year': 2014, 'title': 'The Prince'},
#  {'year': 2014, 'title': 'Blended'},
#  {'title': 'Once Fallen', 'year': 2010},
#  {'title': 'Megan Is Missing', 'year': 2011},
#  {'year': 2013, 'title': 'Lone Survivor'},
#  {'title': 'With Great Power: The Stan Lee Story', 'year': 2010},
#  {'year': 2011, 'title': 'Paul'},
#  {'year': 2011, 'title': 'The Darkest Hour'},
#  {'title': 'The Hammer', 'year': 2010},
#  {'title': 'Bereavement', 'year': 2010},
#  {'year': 2014, 'title': 'Foxcatcher'},
#  {'title': 'Thirst', 'year': 2010},
#  {'year': 2010, 'title': 'Killers'},
#  {'title': 'TRON: Legacy', 'year': 2010},
#  {'year': 2010, 'title': 'TRON: Legacy'},
#  {'title': "Good Ol' Boy", 'year': 2015},
#  {'title': 'Eva', 'year': 2010},
#  {'title': 'Mars', 'year': 2010},
#  {'title': 'Between Us', 'year': 2012},
#  {'year': 2014, 'title': 'Paddington'},
#  {'title': 'The Elephant in the Living Room', 'year': 2010},
#  {'title': 'George Harrison: Living in the Material World', 'year': 2011},
#  {'year': 2010, 'title': 'Jackass 3D'},
#  {'title': 'The Special Relationship', 'year': 2010},
#  {'year': 2010, 'title': 'The Town'},
#  {'year': 2012, 'title': 'A Thousand Words'},
#  {'year': 2010, 'title': 'Detective Dee: Mystery of the Phantom Flame'},
#  {'year': 2010, 'title': 'Detective Dee: Mystery of the Phantom Flame'},
#  {'title': 'The Ides of March', 'year': 2011},
#  {'title': 'Love Ranch', 'year': 2010},
#  {'title': 'Big Eyes', 'year': 2014},
#  {'year': 2010, 'title': 'Burlesque'},
#  {'year': 2010, 'title': 'Morning Glory'},
#  {'year': 2012, 'title': 'The Girl'},
#  {'title': 'Another Harvest Moon', 'year': 2010},
#  {'title': 'Miss Nobody', 'year': 2010},
#  {'year': 2010, 'title': 'Shutter Island'},
#  {'title': "You Don't Know Jack", 'year': 2010},
#  {'title': 'Green Lantern', 'year': 2011},
#  {'year': 2010, 'title': 'Takers'},
#  {'title': 'Trader Games', 'year': 2010},
#  {'title': 'A Tale of Love and Darkness', 'year': 2015},
#  {'title': 'Sonny Boy', 'year': 2011},
#  {'year': 2010, 'title': 'The Ghost Writer'},
#  {'title': 'I Believe in Unicorns', 'year': 2014},
#  {'title': 'Frankenweenie', 'year': 2012},
#  {'year': 2010, 'title': 'Holy Rollers'},
#  {'year': 2011, 'title': 'Beastly'},
#  {'year': 2010, 'title': 'Freakonomics'},
#  {'title': 'Broken Kingdom', 'year': 2012},
#  {'year': 2010, 'title': 'The Karate Kid'},
#  {'title': 'A Dangerous Place', 'year': 2012},
#  {'title': 'Undisputed 3: Redemption', 'year': 2010},
#  {'title': 'Silent Sonata', 'year': 2010},
#  {'title': 'The Colony', 'year': 2013},
#  {'title': 'The Rite', 'year': 2011},
#  {'year': 2010, 'title': 'Biutiful'},
#  {'title': 'The Hobbit: The Desolation of Smaug', 'year': 2013},
#  {'year': 2013, 'title': 'Baggage Claim'},
#  {'year': 2012, 'title': 'Delhi Safari'},
#  {'year': 2010, 'title': 'The Company Men'},
#  {'year': 2010, 'title': 'The Bang Bang Club'},
#  {'title': 'All Good Things', 'year': 2010},
#  {'title': 'The Good Herbs', 'year': 2010},
#  {'title': 'The Extraordinary Adventures of Adèle Blanc-Sec', 'year': 2010},
#  {'year': 2014, 'title': 'Cold in July'},
#  {'year': 2010, 'title': 'A Nightmare on Elm Street'},
#  {'title': 'Buddies', 'year': 2012},
#  {'title': 'Black Death', 'year': 2010},
#  {'year': 2013, 'title': 'Jack and the Cuckoo-Clock Heart'},
#  {'year': 2013, 'title': 'Jack and the Cuckoo-Clock Heart'},
#  {'year': 2010, 'title': 'You Will Meet a Tall Dark Stranger'},
#  {'title': 'Mr. Nice', 'year': 2010},
#  {'title': 'Welcome to the Rileys', 'year': 2010},
#  {'title': 'Marley', 'year': 2012},
#  {'title': "Corman's World: Exploits of a Hollywood Rebel", 'year': 2011},
#  {'year': 2010, 'title': 'When in Rome'},
#  {'title': 'The Outlaw', 'year': 2010},
#  {'title': 'My Soul to Take', 'year': 2010},
#  {'year': 2010, 'title': 'My Name Is Khan'},
#  {'title': 'The Skin I Live In', 'year': 2011},
#  {'title': 'The Lincoln Lawyer', 'year': 2011},
#  {'title': 'The Hunter', 'year': 2010},
#  {'year': 2011, 'title': 'Rango'},
#  {'title': 'Step Up 3D', 'year': 2010},
#  {'year': 2012, 'title': 'The Bourne Legacy'},
#  {'year': 2010, 'title': 'Casino Jack'},
#  {'title': 'Into Eternity: A Film for the Future', 'year': 2010},
#  {'year': 2012, 'title': 'The Five-Year Engagement'},
#  {'title': 'Cemetery Junction', 'year': 2010},
#  {'title': 'Diary of a Wimpy Kid', 'year': 2010},
#  {'year': 2013, 'title': 'Charlie Countryman'},
#  {'title': 'One Chance', 'year': 2013},
#  {'title': 'About Sunny', 'year': 2011},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2', 'year': 2011},
#  {'year': 2011, 'title': 'The Muppets'},
#  {'year': 2014, 'title': 'Ouija'},
#  {'title': 'Last Vegas', 'year': 2013},
#  {'year': 2014, 'title': 'Jack Ryan: Shadow Recruit'},
#  {'year': 2013, 'title': 'Out of the Furnace'},
#  {'year': 2010, 'title': 'Blood Done Sign My Name'},
#  {'year': 2011, 'title': 'Moneyball'},
#  {'year': 2013, 'title': 'The Lone Ranger'},
#  {'title': 'Middle of Nowhere', 'year': 2012},
#  {'title': 'Escape Plan', 'year': 2013},
#  {'year': 2010, 'title': 'Hereafter'},
#  {'year': 2010, 'title': 'The Back-up Plan'},
#  {'year': 2012, 'title': 'Lawless'},
#  {'year': 2010, 'title': 'An Invisible Sign'},
#  {'year': 2010, 'title': 'Alpha and Omega'},
#  {'year': 2013, 'title': "The World's End"},
#  {'year': 2010, 'title': 'London Boulevard'},
#  {'year': 2011, 'title': 'Seeking Justice'},
#  {'year': 2011, 'title': 'Seeking Justice'},
#  {'year': 2011, 'title': 'Cars 2'},
#  {'title': 'Kill the Messenger', 'year': 2014},
#  {'title': 'Tinker Bell and the Great Fairy Rescue', 'year': 2010},
#  {'year': 2012, 'title': 'Brave'},
#  {'title': 'Secret of the Wings', 'year': 2012},
#  {'year': 2011, 'title': 'Battle Los Angeles'},
#  {'year': 2011, 'title': 'Limitless'},
#  {'title': "Legend of the Guardians: The Owls of Ga'Hoole", 'year': 2010},
#  {'title': 'Going Postal', 'year': 2010},
#  {'title': 'Resident Evil: Afterlife', 'year': 2010},
#  {'year': 2010, 'title': 'Frankie & Alice'},
#  {'year': 2012, 'title': 'Chimpanzee'},
#  {'title': 'Zookeeper', 'year': 2011},
#  {'title': 'African Cats', 'year': 2011},
#  {'year': 2010, 'title': 'Get Him to the Greek'},
#  {'year': 2010, 'title': 'Edge of Darkness'},
#  {'year': 2010, 'title': 'The Debt'},
#  {'title': 'Iron Man 2', 'year': 2010},
#  {'year': 2010, 'title': 'Let Me In'},
#  {'year': 2011, 'title': 'Mission: Impossible - Ghost Protocol'},
#  {'year': 2013, 'title': 'Anchorman 2: The Legend Continues'},
#  {'title': 'Jane Eyre', 'year': 2011},
#  {'title': "A Turtle's Tale: Sammy's Adventures", 'year': 2010},
#  {'year': 2012, 'title': 'Not Fade Away'},
#  {'year': 2010, 'title': 'The Yellow Sea'},
#  {'year': 2010, 'title': 'Due Date'},
#  {'title': 'Hot Tub Time Machine', 'year': 2010},
#  {'year': 2012, 'title': "That's My Boy"},
#  {'title': 'Teenage Paparazzo', 'year': 2010},
#  {'title': '21 Jump Street', 'year': 2012},
#  {'title': 'Drones', 'year': 2010},
#  {'title': 'Brighton Rock', 'year': 2010},
#  {'title': 'Captain Thunder', 'year': 2011},
#  {'year': 2011, 'title': 'Pariah'},
#  {'title': 'Chico Xavier', 'year': 2010},
#  {'title': 'Greenberg', 'year': 2010},
#  {'year': 2012, 'title': 'Red Dawn'},
#  {'year': 2014, 'title': 'RoboCop'},
#  {'title': 'The Future', 'year': 2011},
#  {'title': 'Greenberg', 'year': 2010},
#  {'title': 'VIPs', 'year': 2010},
#  {'title': 'Mahler on the Couch', 'year': 2010},
#  {'title': 'Sidewalls', 'year': 2011},
#  {'title': 'Mysteries of Lisbon', 'year': 2010},
#  {'title': 'Lemmy', 'year': 2010},
#  {'title': 'Mariachi Gringo', 'year': 2012},
#  {'title': 'Amazonia', 'year': 2013},
#  {'title': 'Your Highness', 'year': 2011},
#  {'title': 'Road Kill', 'year': 2010},
#  {'title': 'The River Why', 'year': 2010},
#  {'year': 2010, 'title': 'I Spit on Your Grave'},
#  {'title': 'Father, Son & Holy Cow', 'year': 2011},
#  {'year': 2011, 'title': 'We Need to Talk About Kevin'},
#  {'year': 2011, 'title': 'Bellflower'},
#  {'title': 'Rebellion', 'year': 2011},
#  {'title': 'Judas Kiss', 'year': 2011},
#  {'year': 2010, 'title': 'The Tourist'},
#  {'year': 2015, 'title': 'Aloha'},
#  {'title': 'Conviction', 'year': 2010},
#  {'year': 2013, 'title': 'This Is the End'},
#  {'title': 'RED', 'year': 2010},
#  {'title': 'Friendship!', 'year': 2010},
#  {'year': 2010, 'title': 'Norman'},
#  {'year': 2010, 'title': 'Kick-Ass'},
#  {'year': 2010, 'title': 'Under the Boardwalk: The Monopoly Story'},
#  {'title': 'Camp Rock 2: The Final Jam', 'year': 2010},
#  {'year': 2014, 'title': '300: Rise of an Empire'},
#  {'title': 'Immortals', 'year': 2011},
#  {'year': 2010, 'title': 'Incendies'},
#  {'title': 'Hello Lonesome', 'year': 2010},
#  {'year': 2012, 'title': 'The Man with the Iron Fists'},
#  {'title': 'SoulBoy', 'year': 2010},
#  {'year': 2012, 'title': 'The Cabin in the Woods'},
#  {'title': 'Bon appètit', 'year': 2010},
#  {'title': 'Take Me Home', 'year': 2011},
#  {'title': 'Sex and the City 2', 'year': 2010},
#  {'title': 'Pig', 'year': 2011},
#  {'title': 'Scream 4', 'year': 2011},
#  {'title': 'A Small Act', 'year': 2010},
#  {'year': 2011, 'title': 'The Roommate'},
#  {'title': 'Quartier lointain', 'year': 2010},
#  {'year': 2014, 'title': 'Hercules'},
#  {'title': 'Waste Land', 'year': 2010},
#  {'year': 2011, 'title': 'A Very Harold & Kumar 3D Christmas'},
#  {'title': 'The Last Rites of Ransom Pride', 'year': 2010},
#  {'title': 'Transfer', 'year': 2010},
#  {'title': 'Saints and Soldiers: The Void', 'year': 2014},
#  {'title': "The Devil's Double", 'year': 2011},
#  {'year': 2010, 'title': 'Sympathy for Delicious'},
#  {'year': 2010, 'title': "Don't Be Afraid of the Dark"},
#  {'title': 'X-Men: First Class', 'year': 2011},
#  {'year': 2010, 'title': 'Hatchet II'},
#  {'title': '2 Guns', 'year': 2013},
#  {'title': 'Small Apartments', 'year': 2012},
#  {'title': 'Deadheads', 'year': 2011},
#  {'year': 2010, 'title': 'Brotherhood'},
#  {'year': 2010, 'title': 'The Spy Next Door'},
#  {'title': 'Listen to Your Heart', 'year': 2010},
#  {'title': 'The Tempest', 'year': 2010},
#  {'title': 'USS Seaviper', 'year': 2012},
#  {'title': 'Father', 'year': 2010},
#  {'title': 'The Mosquito Net', 'year': 2010},
#  {'year': 2012, 'title': 'Looper'},
#  {'title': 'Who Killed Chea Vichea?', 'year': 2011},
#  {'year': 2012, 'title': 'A Royal Affair'},
#  {'title': 'How to Make Money Selling Drugs', 'year': 2012},
#  {'year': 2012, 'title': "Madagascar 3: Europe's Most Wanted"},
#  {'year': 2010, 'title': 'Jack Goes Boating'},
#  {'year': 2010, 'title': 'Sound of Noise'},
#  {'title': 'Temple Grandin', 'year': 2010},
#  {'year': 2010, 'title': 'Date Night'},
#  {'title': 'Smash His Camera', 'year': 2010},
#  {'title': "Anton Chekhov's The Duel", 'year': 2010},
#  {'title': 'Fort McCoy', 'year': 2011},
#  {'year': 2010, 'title': 'Easy A'},
#  {'title': 'Sweet Evil', 'year': 2010},
#  {'year': 2011, 'title': 'Bad Teacher'},
#  {'year': 2010, 'title': 'The Social Network'},
#  {'title': 'Lahore', 'year': 2010},
#  {'year': 2010, 'title': 'Cats & Dogs: The Revenge of Kitty Galore'},
#  {'year': 2013, 'title': 'Evil Dead'},
#  {'title': 'Lebanon, Pa.', 'year': 2010},
#  {'title': 'Au revoir Taipei', 'year': 2010},
#  {'year': 2014, 'title': 'Teenage Mutant Ninja Turtles'},
#  {'title': 'Raajneeti', 'year': 2010},
#  {'year': 2010, 'title': 'Meet Monica Velour'},
#  {'title': 'Behind the Candelabra', 'year': 2013},
#  {'year': 2011, 'title': 'Warrior'},
#  {'title': 'Easy Money', 'year': 2010},
#  {'title': 'Railways', 'year': 2010},
#  {'title': 'Casting By', 'year': 2012},
#  {'title': 'Shit Year', 'year': 2010},
#  {'title': 'The Last Song', 'year': 2010},
#  {'year': 2010, 'title': 'Last Night'},
#  {'title': 'Sennentuntschi: Curse of the Alps', 'year': 2010},
#  {'year': 2011, 'title': 'The FP'},
#  {'title': 'Sons of Perdition', 'year': 2010},
#  {'title': 'Waiting for Forever', 'year': 2010},
#  {'title': 'Wake Wood', 'year': 2010},
#  {'title': 'Animals', 'year': 2012},
#  {'year': 2011, 'title': 'Eva'},
#  {'title': 'The Presence', 'year': 2010},
#  {'year': 2012, 'title': 'The Watch'},
#  {'year': 2011, 'title': 'Pirates of the Caribbean: On Stranger Tides'},
#  {'title': 'Iron Man 3', 'year': 2013},
#  {'year': 2010, 'title': 'Harvest'},
#  {'year': 2011, 'title': 'Kung Fu Panda 2'},
#  {'year': 2010, 'title': 'Yogi Bear'},
#  {'year': 2010, 'title': 'Our Family Wedding'},
#  {'year': 2011, 'title': 'Mars Needs Moms'},
#  {'title': 'Fred & Vinnie', 'year': 2011},
#  {'title': 'Enthiran', 'year': 2010},
#  {'year': 2011, 'title': '50/50'},
#  {'title': 'Seeking a Friend for the End of the World', 'year': 2012},
#  {'title': 'All Stars 2: Old Stars', 'year': 2011},
#  {'title': 'Turn the Beat Around', 'year': 2010},
#  {'year': 2011, 'title': 'Go for It!'},
#  {'year': 2012, 'title': 'Bullet to the Head'},
#  {'year': 2012, 'title': "Don't Stop Believin': Everyman's Journey"},
#  {'title': 'Our Grand Despair', 'year': 2011},
#  {'title': 'Sam', 'year': 2015},
#  {'title': 'Kill Your Darlings', 'year': 2013},
#  {'year': 2013, 'title': 'A.C.O.D.'},
#  {'title': 'The Scientist', 'year': 2010},
#  {'title': 'The Human Resources Manager', 'year': 2010},
#  {'year': 2010, 'title': 'Skateland'},
#  {'year': 2010, 'title': 'Animal Kingdom'},
#  {'title': 'The Invisible Eye', 'year': 2010},
#  {'title': '3 Backyards', 'year': 2010},
#  {'title': 'Devil', 'year': 2010},
#  {'title': 'Cherry', 'year': 2010},
#  {'title': 'There Be Dragons', 'year': 2011},
#  {'title': 'Just Between Us', 'year': 2010},
#  {'year': 2011, 'title': 'Rise of the Planet of the Apes'},
#  {'title': 'Chatroom', 'year': 2010},
#  {'title': "It's a Wonderful Afterlife", 'year': 2010},
#  {'year': 2010, 'title': 'A Little Help'},
#  {'title': 'The Last Exorcism', 'year': 2010},
#  {'year': 2010, 'title': 'The Expendables'},
#  {'year': 2010, 'title': "Gulliver's Travels"},
#  {'title': '30 Days of Night: Dark Days', 'year': 2010},
#  {'year': 2013, 'title': 'Oldboy'},
#  {'title': 'Death at a Funeral', 'year': 2010},
#  {'year': 2013, 'title': 'Gangster Squad'},
#  {'year': 2013, 'title': 'Oldboy'},
#  {'year': 2011, 'title': 'The Beaver'},
#  {'year': 2010, 'title': 'The Dry Land'},
#  {'year': 2013, 'title': 'August: Osage County'},
#  {'title': 'Sunshine Superman', 'year': 2014},
#  {'title': 'The Burma Conspiracy', 'year': 2011},
#  {'title': 'Submarino', 'year': 2010},
#  {'year': 2010, 'title': 'Frozen'},
#  {'year': 2010, 'title': 'Despicable Me'},
#  {'title': 'The Mill and the Cross', 'year': 2011},
#  {'title': 'The Twilight Saga: Eclipse', 'year': 2010},
#  {'year': 2011, 'title': 'The Twilight Saga: Breaking Dawn - Part 1'},
#  {'title': 'Backlight', 'year': 2010},
#  {'title': "Jane's Journey", 'year': 2010},
#  {'year': 2012, 'title': 'The Lucky One'},
#  {'title': 'The Reeds', 'year': 2010},
#  {'year': 2013, 'title': "Lee Daniels' The Butler"},
#  {'title': 'Some Days Are Better Than Others', 'year': 2010},
#  {'title': "Preacher's Kid", 'year': 2010},
#  {'title': 'Gainsbourg: A Heroic Life', 'year': 2010},
#  {'title': 'The Final Storm', 'year': 2010},
#  {'title': 'Kiss Me Again', 'year': 2010},
#  {'title': 'Movie 43', 'year': 2013},
#  {'title': 'The Resident', 'year': 2011},
#  {'title': 'Never Let Me Go', 'year': 2010},
#  {'title': 'Raavan', 'year': 2010},
#  {'year': 2011, 'title': 'Arthur'},
#  {'year': 2010, 'title': 'The Perfect Host'},
#  {'year': 2013, 'title': '47 Ronin'},
#  {'title': 'The Pack', 'year': 2010},
#  {'title': 'Cyrus', 'year': 2010},
#  {'year': 2012, 'title': 'Rock of Ages'},
#  {'title': 'The Erotic Man', 'year': 2010},
#  {'title': 'Nokas', 'year': 2010},
#  {'title': 'The Robber', 'year': 2010},
#  {'title': 'In a Better World', 'year': 2010},
#  {'year': 2015, 'title': 'Terminator Genisys'},
#  {'year': 2010, 'title': 'Elektra Luxx'},
#  {'title': 'Tinker Tailor Soldier Spy', 'year': 2011},
#  {'title': 'Four Lions', 'year': 2010},
#  {'year': 2010, 'title': 'How Do You Know'},
#  {'title': 'The Inheritance', 'year': 2011},
#  {'year': 2013, 'title': 'The Great Gatsby'},
#  {'title': 'The Brest Fortress', 'year': 2010},
#  {'year': 2012, 'title': 'Dredd'},
#  {'title': 'Paradox', 'year': 2010},
#  {'title': 'Brothers on the Line', 'year': 2012},
#  {'title': 'The Pig Farm', 'year': 2011},
#  {'title': 'Ishqiya', 'year': 2010},
#  {'title': 'The Clinic', 'year': 2010},
#  {'year': 2012, 'title': 'The Dark Knight Rises'},
#  {'title': 'The First Man', 'year': 2011},
#  {'title': 'Pyaar Impossible!', 'year': 2010},
#  {'title': 'Jack the Giant Slayer', 'year': 2013},
#  {'title': 'Surviving Life (Theory and Practice)', 'year': 2010},
#  {'year': 2014, 'title': 'If I Stay'},
#  {'year': 2010, 'title': "I'm Still Here"},
#  {'title': 'Paper Birds', 'year': 2010},
#  {'title': 'Nanga Parbat', 'year': 2010},
#  {'title': "Ain't in It for My Health: A Film About Levon Helm", 'year': 2010},
#  {'title': 'Beasts of No Nation', 'year': 2015},
#  {'title': 'Main Street', 'year': 2010},
#  {'title': 'We Believed', 'year': 2010},
#  {'year': 2012, 'title': 'The Cold Light of Day'},
#  {'year': 2011, 'title': 'The Sitter'},
#  {'year': 2010, 'title': 'Miral'},
#  {'year': 2012, 'title': 'Cloud Atlas'},
#  {'year': 2014, 'title': 'This Is Where I Leave You'},
#  {'title': 'Made in Dagenham', 'year': 2010},
#  {'title': 'Kosmos', 'year': 2010},
#  {'title': 'Life Without Principle', 'year': 2011},
#  {'title': 'Coriolanus', 'year': 2011},
#  {'title': 'Karthik Calling Karthik', 'year': 2010},
#  {'year': 2012, 'title': 'Upside Down'},
#  {'title': 'Alois Nebel', 'year': 2011},
#  {'title': 'Prairie Love', 'year': 2011},
#  {'year': 2010, 'title': 'Inception'},
#  {'title': 'Grown Ups', 'year': 2010},
#  {'title': 'Gunless', 'year': 2010},
#  {'title': 'Jean Gentil', 'year': 2010},
#  {'title': 'Play', 'year': 2011},
#  {'title': 'When the Dragon Swallowed the Sun', 'year': 2010},
#  {'title': 'Bad Family', 'year': 2010},
#  {'title': 'Run Sister Run!', 'year': 2010},
#  {'title': 'Rebirth', 'year': 2011},
#  {'title': 'Pete Smalls Is Dead', 'year': 2010},
#  {'year': 2012, 'title': 'The Company You Keep'},
#  {'title': 'Flicka 2', 'year': 2010},
#  {'title': 'Hella W', 'year': 2011},
#  {'title': 'Ardor', 'year': 2014},
#  {'title': 'The Runway', 'year': 2010},
#  {'year': 2011, 'title': 'The Adjustment Bureau'},
#  {'year': 2010, 'title': 'Cop Out'},
#  {'title': 'Particle Fever', 'year': 2013},
#  {'title': 'The Other Guys', 'year': 2010},
#  {'title': 'A Somewhat Gentle Man', 'year': 2010},
#  {'title': 'Total Recall', 'year': 2012},
#  {'year': 2010, 'title': 'The Dead'},
#  {'year': 2010, 'title': 'Ip Man 2'},
#  {'title': 'Time Again', 'year': 2011},
#  {'year': 2011, 'title': 'Texas Killing Fields'},
#  {'year': 2011, 'title': 'We Bought a Zoo'},
#  {'title': 'Bless Me, Ultima', 'year': 2013},
#  {'title': 'Baseline', 'year': 2010},
#  {'title': 'The Final', 'year': 2010},
#  {'title': 'Marwencol', 'year': 2010},
#  {'title': 'Resistance', 'year': 2011},
#  {'year': 2010, 'title': 'Why Did I Get Married Too?'},
#  {'title': 'Run If You Can', 'year': 2010},
#  {'year': 2012, 'title': 'The Hunger Games'},
#  {'year': 2010, 'title': 'Marmaduke'},
#  {'year': 2015, 'title': 'Mad Max: Fury Road'},
#  {'year': 2013, 'title': 'Prisoners'},
#  {'title': 'Sex & Drugs & Rock & Roll', 'year': 2010},
#  {'year': 2012, 'title': 'Jesus Henry Christ'},
#  {'title': 'Aftershock', 'year': 2010},
#  {'title': 'Helena from the Wedding', 'year': 2010},
#  {'title': 'Once Upon a Time in Mumbai', 'year': 2010},
#  {'title': 'Erasing David', 'year': 2010},
#  {'title': 'When I Walk', 'year': 2013},
#  {'year': 2011, 'title': "Mr. Popper's Penguins"},
#  {'title': 'Twice Born', 'year': 2012},
#  {'year': 2012, 'title': 'Taken 2'},
#  {'title': 'Confucius', 'year': 2010},
#  {'title': 'The Day I Was Not Born', 'year': 2010},
#  {'year': 2012, 'title': 'Journey 2: The Mysterious Island'},
#  {'year': 2010, 'title': 'Yellowbrickroad'},
#  {'title': 'Earthling', 'year': 2010},
#  {'title': 'Thursday Till Sunday', 'year': 2012},
#  {'title': 'Transformers: Dark of the Moon', 'year': 2011},
#  {'title': "Winter's Bone", 'year': 2010},
#  {'title': 'Lost Boys: The Thirst', 'year': 2010},
#  {'year': 2010, 'title': 'Rare Exports: A Christmas Tale'},
#  {'year': 2011, 'title': 'Unknown'},
#  {'title': 'Black Venus', 'year': 2010},
#  {'title': '72 days', 'year': 2010},
#  {'title': 'Happy Feet 2', 'year': 2011},
#  {'title': 'Aurora', 'year': 2010},
#  {'year': 2010, 'title': 'Hesher'},
#  {'title': 'Come Undone', 'year': 2010},
#  {'title': 'Everything Will be Fine', 'year': 2010},
#  {'year': 2010, 'title': 'True Grit'},
#  {'year': 2010, 'title': 'Remember Me'},
#  {'title': 'The Bannen Way', 'year': 2010},
#  {'title': 'Celeste & Jesse Forever', 'year': 2012},
#  {'year': 2010, 'title': 'For Colored Girls'},
#  {'title': 'Loose Cannons', 'year': 2010},
#  {'title': 'Wrinkles', 'year': 2011},
#  {'title': 'Altitude', 'year': 2010},
#  {'year': 2011, 'title': 'The Moth Diaries'},
#  {'title': 'Just Wright', 'year': 2010},
#  {'title': 'The Stranger', 'year': 2010},
#  {'year': 2010, 'title': 'Twelve'},
#  {'title': 'The Father and the Foreigner', 'year': 2010},
#  {'year': 2013, 'title': 'Star Trek Into Darkness'},
#  {'year': 2014, 'title': 'Ride Along'},
#  {'title': 'Bloomington', 'year': 2010},
#  {'year': 2012, 'title': 'Men in Black 3'},
#  {'year': 2011, 'title': 'The Flowers of War'},
#  {'year': 2011, 'title': 'No Strings Attached'},
#  {'year': 2013, 'title': 'Riddick'},
#  {'title': 'Finnish Blood Swedish Heart', 'year': 2012},
#  {'year': 2011, 'title': 'Hop'},
#  {'year': 2011, 'title': 'The Hangover Part II'},
#  {'title': 'Bucky Larson: Born to Be a Star', 'year': 2011},
#  {'title': 'Sold', 'year': 2014},
#  {'year': 2011, 'title': 'The Best Exotic Marigold Hotel'},
#  {'year': 2011, 'title': 'Revenge of the Electric Car'},
#  {'year': 2013, 'title': 'Paranoia'},
#  {'year': 2010, 'title': 'You Again'},
#  {'title': 'Tracker', 'year': 2010},
#  {'title': 'Over Your Cities Grass Will Grow', 'year': 2010},
#  {'title': 'To Be King', 'year': 2012},
#  {'title': 'Immigration Tango', 'year': 2010},
#  {'year': 2010, 'title': 'Nanny McPhee Returns'},
#  {'title': 'The Youngest Son', 'year': 2010},
#  {'year': 2011, 'title': 'In Darkness'},
#  {'title': 'Torrente 4', 'year': 2011},
#  {'title': 'Among Wolves', 'year': 2010},
#  {'title': 'Beneath Hill 60', 'year': 2010},
#  {'title': 'I, Frankenstein', 'year': 2014},
#  {'title': 'Riverworld', 'year': 2010},
#  {'year': 2010, 'title': 'Somewhere'},
#  {'title': 'A Lonely Place to Die', 'year': 2011},
#  {'title': 'Torn', 'year': 2013},
#  {'year': 2010, 'title': "Barney's Version"},
#  {'title': 'The Infidel', 'year': 2010},
#  {'year': 2012, 'title': 'Chinese Zodiac'},
#  {'year': 2010, 'title': 'Predators'},
#  {'title': 'Senna', 'year': 2010},
#  {'year': 2010, 'title': 'True Legend'},
#  {'title': 'Black Nativity', 'year': 2013},
#  {'title': 'Skeletons', 'year': 2010},
#  {'year': 2013, 'title': 'Lovelace'},
#  {'year': 2013, 'title': 'HairBrained'},
#  {'title': 'The Human Race', 'year': 2013},
#  {'title': '3faltig', 'year': 2010},
#  {'title': 'Princess', 'year': 2010},
#  {'year': 2013, 'title': 'Hansel & Gretel: Witch Hunters'},
#  {'title': 'Africa United', 'year': 2010},
#  {'year': 2010, 'title': 'Small Town Murder Songs'},
#  {'title': 'Snowflake, the White Gorilla', 'year': 2011},
#  {'title': 'The Wolverine', 'year': 2013},
#  {'title': 'Big Miracle', 'year': 2012},
#  {'title': 'Kiss the Abyss', 'year': 2012},
#  {'year': 2014, 'title': 'Brick Mansions'},
#  {'title': 'The Pirates! Band of Misfits', 'year': 2012},
#  {'year': 2011, 'title': 'Arthur Christmas'},
#  {'title': 'Forget Me Not', 'year': 2010},
#  {'title': 'No Problem', 'year': 2010},
#  {'year': 2010, 'title': 'Another Year'},
#  {'year': 2010, 'title': 'Faster'},
#  {'title': '18 Years Later', 'year': 2010},
#  {'title': 'Canned Dreams', 'year': 2012},
#  {'title': 'Rules of Single Life', 'year': 2011},
#  {'title': 'Mumbai Diaries', 'year': 2010},
#  {'title': 'The Apparition', 'year': 2012},
#  {'title': 'Hubble 3D', 'year': 2010},
#  {'title': 'Tèèllè Pohjantèhden alla II', 'year': 2010},
#  {'title': 'R', 'year': 2010},
#  {'title': 'Hysteria', 'year': 2011},
#  {'title': 'Legacy: Black Ops', 'year': 2010},
#  {'title': '13 Assassins', 'year': 2010},
#  {'title': 'Lovers of Hate', 'year': 2010},
#  {'title': 'Rio', 'year': 2011},
#  {'title': 'Le mac', 'year': 2010},
#  {'title': 'Beyond', 'year': 2010},
#  {'year': 2011, 'title': 'Fright Night'},
#  {'title': 'One Kine Day', 'year': 2011},
#  {'year': 2010, 'title': 'Oranges and Sunshine'},
#  {'title': 'Charlie St. Cloud', 'year': 2010},
#  {'title': 'Guzaarish', 'year': 2010},
#  {'title': 'Perfect Sense', 'year': 2011},
#  {'year': 2012, 'title': 'Battleship'},
#  {'title': 'Pina', 'year': 2011},
#  {'title': 'Submarine', 'year': 2010},
#  {'year': 2011, 'title': 'This Must Be the Place'},
#  {'year': 2010, 'title': 'The American'},
#  {'title': 'Snow & Ashes', 'year': 2010},
#  {'title': 'The Zigzag Kid', 'year': 2012},
#  {'year': 2011, 'title': 'Martha Marcy May Marlene'},
#  {'title': 'The Solitude of Prime Numbers', 'year': 2010},
#  {'year': 2013, 'title': 'Under the Skin'},
#  {'year': 2010, 'title': 'The Way'},
#  {'title': 'Broken', 'year': 2012},
#  {'year': 2011, 'title': 'Salmon Fishing in the Yemen'},
#  {'year': 2014, 'title': 'Testament of Youth'},
#  {'title': 'Quartet', 'year': 2012},
#  {'year': 2010, 'title': '14 Blades'},
#  {'title': 'Reflexèes de um Liquidificador', 'year': 2010},
#  {'title': 'Vito', 'year': 2011},
#  {'title': 'Bruc, the Manhunt', 'year': 2010},
#  {'title': 'Hot Coffee', 'year': 2011},
#  {'year': 2011, 'title': 'Footnote'},
#  {'title': 'The Letters', 'year': 2014},
#  {'year': 2012, 'title': 'Rise of the Guardians'},
#  {'year': 2010, 'title': 'Ways to Live Forever'},
#  {'year': 2012, 'title': 'Prometheus'},
#  {'title': 'Between Two Fires', 'year': 2010},
#  {'title': 'A Marine Story', 'year': 2010},
#  {'title': 'Matching Jack', 'year': 2010},
#  {'title': 'Peepli (Live)', 'year': 2010},
#  {'title': 'StreetDance 3D', 'year': 2010},
#  {'year': 2011, 'title': 'Killer Elite'},
#  {'title': 'Open House', 'year': 2010},
#  {'title': 'If These Knishes Could Talk: The Story of the NY Accent',
#   'year': 2013},
#  {'year': 2011, 'title': 'Winnie the Pooh'},
#  {'title': 'Filth', 'year': 2013},
#  {'title': 'Days of Grace', 'year': 2011},
#  {'year': 2011, 'title': 'Roadie'},
#  {'title': 'Mooz-Lum', 'year': 2010},
#  {'title': 'The Boy Who Cried Werewolf', 'year': 2010},
#  {'title': 'Sensation', 'year': 2010},
#  {'title': 'On Tour', 'year': 2010},
#  {'title': 'The Poll Diaries', 'year': 2010},
#  {'title': 'The Pillars of the Earth', 'year': 2010},
#  {'title': "Devil's Playground", 'year': 2010},
#  {'title': 'Monsters University', 'year': 2013},
#  {'year': 2011, 'title': 'The Help'},
#  {'year': 2013, 'title': 'Gravity'},
#  {'title': 'Lapland Odyssey', 'year': 2010},
#  {'title': 'Beauty and the Paparazzo', 'year': 2010},
#  {'title': 'O que Hè de Novo no Amor?', 'year': 2011},
#  {'title': 'My Afternoons with Margueritte', 'year': 2010},
#  {'title': 'Happy Family', 'year': 2010},
#  {'title': 'Boy Wonder', 'year': 2010},
#  {'title': 'As If I Am Not There', 'year': 2010},
#  {'year': 2011, 'title': 'Goon'},
#  {'title': 'Legend of the Fist: The Return of Chen Zhen', 'year': 2010},
#  {'title': "No Man's Land", 'year': 2013},
#  {'title': 'Tomorrow, When the War Began', 'year': 2010},
#  {'year': 2013, 'title': 'The Conjuring'},
#  {'title': 'The Kings of Mykonos', 'year': 2010},
#  {'title': 'The Next Three Days', 'year': 2010},
#  {'title': 'Reign of Assassins', 'year': 2010},
#  {'title': 'Better This World', 'year': 2011},
#  {'year': 2011, 'title': 'Dream House'},
#  {'year': 2010, 'title': 'Letters to God'},
#  {'year': 2013, 'title': 'Big Sur'},
#  {'year': 2010, 'title': 'Outrage'},
#  {'year': 2012, 'title': 'The Odd Life of Timothy Green'},
#  {'year': 2010, 'title': 'Buried'},
#  {'year': 2013, 'title': 'The Grandmaster'},
#  {'year': 2013, 'title': 'All Is Bright'},
#  {'year': 2013, 'title': 'Decoding Annie Parker'},
#  {'year': 2011, 'title': 'Big Mommas: Like Father, Like Son'},
#  {'title': 'House of Last Things', 'year': 2013},
#  {'year': 2011, 'title': 'I Am Number Four'},
#  {'year': 2010, 'title': 'Stake Land'},
#  {'title': "You're So Cupid!", 'year': 2010},
#  {'title': 'Heartbreaker', 'year': 2010},
#  {'title': 'Die', 'year': 2010},
#  {'title': 'Red White & Blue', 'year': 2010},
#  {'title': 'The Italian Key', 'year': 2011},
#  {'title': 'Joy', 'year': 2010},
#  {'title': 'King of Triads', 'year': 2010},
#  {'year': 2010, 'title': 'Tucker and Dale vs. Evil'},
#  {'title': 'Cloudburst', 'year': 2011},
#  {'title': 'The First Beautiful Thing', 'year': 2010},
#  {'title': 'Astral City: A Spiritual Journey', 'year': 2010},
#  {'title': 'My Good Enemy', 'year': 2010},
#  {'title': 'What If...', 'year': 2010},
#  {'title': "At Ellen's Age", 'year': 2010},
#  {'year': 2010, 'title': 'MacGruber'},
#  {'year': 2010, 'title': 'Monsters'},
#  {'title': 'Oxygen', 'year': 2010},
#  {'title': 'The Violent Kind', 'year': 2010},
#  {'title': 'Mammuth', 'year': 2010},
#  {'year': 2010, 'title': 'Saw 3D: The Final Chapter'},
#  {'title': 'Space Battleship Yamato', 'year': 2010},
#  {'title': 'Amador', 'year': 2010},
#  {'title': 'Where the Road Meets the Sun', 'year': 2011},
#  {'title': 'Bitter Feast', 'year': 2010},
#  {'year': 2011, 'title': 'Cedar Rapids'},
#  {'year': 2012, 'title': 'Hyde Park on Hudson'},
#  {'year': 2011, 'title': 'Bridesmaids'},
#  {'title': 'Four Assassins', 'year': 2013},
#  {'year': 2011, 'title': 'Attack the Block'},
#  {'title': 'The High Cost of Living', 'year': 2010},
#  {'title': 'Polite People', 'year': 2011},
#  {'title': 'Cosmopolis', 'year': 2012},
#  {'year': 2010, 'title': 'Happythankyoumoreplease'},
#  {'year': 2012, 'title': 'The Lorax'},
#  {'title': 'Young Bruce Lee', 'year': 2010},
#  {'title': 'Logan', 'year': 2010},
#  {'title': 'Carbon Nation', 'year': 2010},
#  {'year': 2013, 'title': 'Oblivion'},
#  {'title': 'Spork', 'year': 2010},
#  {'title': 'At Middleton', 'year': 2013},
#  {'title': 'Hèroes', 'year': 2010},
#  {'title': 'The Trouble with Bliss', 'year': 2011},
#  {'title': '8: The Mormon Proposition', 'year': 2010},
#  {'title': 'Mr. Pip', 'year': 2012},
#  {'title': 'No God, No Master', 'year': 2013},
#  {'year': 2011, 'title': 'Red Riding Hood'},
#  {'year': 2010, 'title': 'Tamara Drewe'},
#  {'year': 2012, 'title': 'The Raven'},
#  {'year': 2013, 'title': 'What If'},
#  {'title': 'Drew: The Man Behind the Poster', 'year': 2013},
#  {'title': 'Zambezia', 'year': 2012},
#  {'title': 'Shuffle', 'year': 2011},
#  {'year': 2011, 'title': 'The Change-Up'},
#  {'year': 2014, 'title': 'The Lego Movie'},
#  {'title': 'Dive!', 'year': 2010},
#  {'year': 2012, 'title': 'The Iceman'},
#  {'title': 'Mildred Pierce', 'year': 2011},
#  {'title': 'Forgetting the Girl', 'year': 2012},
#  {'year': 2012, 'title': 'Nature Calls'},
#  {'title': 'Beauty & the Briefcase', 'year': 2010},
#  {'title': 'Future My Love', 'year': 2012},
#  {'title': 'The Tree', 'year': 2010},
#  {'year': 2012, 'title': 'Underworld: Awakening'},
#  {'title': 'The Paperboy', 'year': 2012},
#  {'title': 'Tropicèlia', 'year': 2012},
#  {'year': 2011, 'title': 'Restless'},
#  {'title': 'Ocean Heaven', 'year': 2010},
#  {'title': 'The Whisperer in Darkness', 'year': 2011},
#  {'title': 'Anjaana Anjaani', 'year': 2010},
#  {'title': 'Horrible Bosses', 'year': 2011},
#  {'title': 'Dooman River', 'year': 2010},
#  {'title': 'Private Romeo', 'year': 2011},
#  {'year': 2015, 'title': 'Fantastic Four'},
#  {'year': 2011, 'title': 'Drive Angry'},
#  {'title': "Nothing's All Bad", 'year': 2010},
#  {'title': 'Oliver Sherman', 'year': 2010},
#  {'title': 'Illègal', 'year': 2010},
#  {'title': 'Memoria de mis putas tristes', 'year': 2011},
#  {'title': 'The Sinking of the Laconia', 'year': 2010},
#  {'year': 2010, 'title': "The King's Speech"},
#  {'title': 'Road to Nowhere', 'year': 2010},
#  {'title': "Somebody's Hero", 'year': 2011},
#  {'title': 'Yelling to the Sky', 'year': 2011},
#  {'title': 'A Lot Like You', 'year': 2012},
#  {'title': 'Zettl', 'year': 2012},
#  {'title': '2012: Time for Change', 'year': 2010},
#  {'title': 'Smoorverliefd', 'year': 2010},
#  {'title': 'Haywire', 'year': 2011},
#  {'year': 2011, 'title': 'Cargo'},
#  {'title': 'Caterpillar', 'year': 2010},
#  {'title': 'Janie Jones', 'year': 2010},
#  {'title': 'The Wildest Dream', 'year': 2010},
#  {'title': "Genitori & figli:) - Agitare bene prima dell'uso", 'year': 2010},
#  {'title': 'La nostra vita', 'year': 2010},
#  {'title': 'School Is Over', 'year': 2010},
#  {'year': 2011, 'title': 'The Three Musketeers'},
#  {'title': 'Griff the Invisible', 'year': 2010},
#  {'title': 'Top Floor Left Wing', 'year': 2010},
#  {'title': 'Behind the Burly Q', 'year': 2010},
#  {'title': 'Third Star', 'year': 2010},
#  {'title': 'Behind Blue Skies', 'year': 2010},
#  {'title': 'Heathens and Thieves', 'year': 2012},
#  {'title': 'The Sunset Limited', 'year': 2011},
#  {'title': 'Bo', 'year': 2010},
#  {'title': 'The Chicago 8', 'year': 2011},
#  {'year': 2010, 'title': 'Super'},
#  {'title': 'Goblin', 'year': 2010},
#  {'title': 'Family Affair', 'year': 2010},
#  {'year': 2011, 'title': 'Sherlock Holmes: A Game of Shadows'},
#  {'title': 'Walking with the Enemy', 'year': 2013},
#  {'title': 'Being in the World', 'year': 2010},
#  {'title': 'The Lottery', 'year': 2010},
#  {'title': "A Beginner's Guide to Endings", 'year': 2010},
#  {'title': 'The Greatest Ears in Town: The Arif Mardin Story', 'year': 2010},
#  {'title': "Bi, Don't Be Afraid", 'year': 2010},
#  {'title': 'The Clink of Ice', 'year': 2010},
#  {'title': 'The Enemy', 'year': 2011},
#  {'title': 'The Host', 'year': 2013},
#  {'title': 'Sunlight Jr.', 'year': 2013},
#  {'title': 'Spy Kids: All the Time in the World in 4D', 'year': 2011},
#  {'title': 'Better Mus Come', 'year': 2010},
#  {'title': 'Some Dogs Bite', 'year': 2010},
#  {'title': 'Life 2.0', 'year': 2010},
#  {'year': 2010, 'title': "Meek's Cutoff"},
#  {'title': 'Agnosia', 'year': 2010},
#  {'title': "Love's Kitchen", 'year': 2011},
#  {'title': 'Gabi on the Roof in July', 'year': 2010},
#  {'title': 'A Quiet Life', 'year': 2010},
#  {'title': 'Anonymous', 'year': 2011},
#  {'year': 2010, 'title': 'Potiche'},
#  {'title': 'Win/Win', 'year': 2010},
#  {'title': 'Bes Sehir', 'year': 2010},
#  {'title': 'Love & Slaps', 'year': 2010},
#  {'title': "King's Road", 'year': 2010},
#  {'title': 'The Prize', 'year': 2011},
#  {'title': 'Magic Camp', 'year': 2012},
#  {'year': 2011, 'title': 'Gun Hill Road'},
#  {'title': 'The Caller', 'year': 2011},
#  {'title': 'Ay Lav Yu', 'year': 2010},
#  {'title': 'The Great Vazquez', 'year': 2010},
#  {'title': 'Tender Son: The Frankenstein Project', 'year': 2010},
#  {'title': 'Aglaya', 'year': 2012},
#  {'year': 2011, 'title': 'Melancholia'},
#  {'title': 'The Man from Nowhere', 'year': 2010},
#  {'title': 'Archipelago', 'year': 2010},
#  {'year': 2013, 'title': 'Horns'},
#  {'year': 2014, 'title': 'Exodus: Gods and Kings'},
#  {'title': 'Pregnancy Pact', 'year': 2010},
#  {'title': 'Route Irish', 'year': 2010},
#  {'title': 'Four Lovers', 'year': 2010},
#  {'title': 'Welcome to the South', 'year': 2010},
#  {'title': 'Basilicata Coast to Coast', 'year': 2010},
#  {'year': 2010, 'title': 'Trust'},
#  {'title': 'Trek Nation', 'year': 2010},
#  {'title': 'Ride the Divide', 'year': 2010},
#  {'year': 2010, 'title': 'Red Hill'},
#  {'title': 'Smitty', 'year': 2012},
#  {'title': 'The Disappearance of Eleanor Rigby: Him', 'year': 2013},
#  {'title': 'Byzantium', 'year': 2012},
#  {'year': 2010, 'title': 'Beginners'},
#  {'year': 2013, 'title': 'Line of Duty'},
#  {'year': 2013, 'title': 'Battle of the Year'},
#  {'year': 2010, 'title': 'Beautiful Boy'},
#  {'title': 'The Traveler', 'year': 2010},
#  {'title': 'Tab Hunter Confidential', 'year': 2015},
#  {'title': 'Shaolin', 'year': 2011},
#  {'title': 'Strange Powers: Stephin Merritt and the Magnetic Fields',
#   'year': 2010},
#  {'title': 'Beyond the Black Rainbow', 'year': 2010},
#  {'title': 'Verbo', 'year': 2011},
#  {'year': 2013, 'title': 'Elysium'},
#  {'year': 2013, 'title': 'Captain Phillips'},
#  {'title': 'Hope Springs', 'year': 2012},
#  {'title': 'Crave', 'year': 2012},
#  ...]

# %%
# Afficher les films joués par l'acteur "Tom Cruise", sortis après l'année 2000, en se limitant au titre du film et la liste des acteurs ?
pipeline = [
    {
        "$match": {
            "cast": "Tom Cruise",
            "year": {
                "$gt": 2000
            }
        }
    },
    {
        "$project": {
            "title": 1,
            "cast": 1,
            "year": 1,
            "_id": 0
        }
    },
    {
        "$sort": {
            "year": -1
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'cast': ['Tom Cruise', 'Emily Blunt', 'Brendan Gleeson', 'Bill Paxton'],
#   'title': 'Edge of Tomorrow',
#   'year': 2014},
#  {'year': 2013,
#   'title': 'Oblivion',
#   'cast': ['Tom Cruise',
#    'Morgan Freeman',
#    'Olga Kurylenko',
#    'Andrea Riseborough']},
#  {'year': 2012,
#   'title': 'Jack Reacher',
#   'cast': ['Tom Cruise', 'Rosamund Pike', 'Richard Jenkins', 'David Oyelowo']},
#  {'year': 2011,
#   'title': 'Mission: Impossible - Ghost Protocol',
#   'cast': ['Tom Cruise', 'Paula Patton', 'Simon Pegg', 'Jeremy Renner']},
#  {'year': 2010,
#   'title': 'Knight and Day',
#   'cast': ['Tom Cruise', 'Cameron Diaz', 'Peter Sarsgaard', 'Jordi Mollè']},
#  {'cast': ['Tom Cruise', 'Kenneth Branagh', 'Bill Nighy', 'Tom Wilkinson'],
#   'title': 'Valkyrie',
#   'year': 2008},
#  {'cast': ['Robert Redford', 'Meryl Streep', 'Tom Cruise', 'Michael Peèa'],
#   'title': 'Lions for Lambs',
#   'year': 2007},
#  {'year': 2006,
#   'title': 'Mission: Impossible III',
#   'cast': ['Tom Cruise',
#    'Philip Seymour Hoffman',
#    'Ving Rhames',
#    'Billy Crudup']},
#  {'year': 2005,
#   'title': 'War of the Worlds',
#   'cast': ['Tom Cruise', 'Dakota Fanning', 'Miranda Otto', 'Justin Chatwin']},
#  {'cast': ['Tom Cruise', 'Jamie Foxx', 'Jada Pinkett Smith', 'Mark Ruffalo'],
#   'title': 'Collateral',
#   'year': 2004},
#  {'year': 2003,
#   'title': 'The Last Samurai',
#   'cast': ['Ken Watanabe', 'Tom Cruise', 'William Atherton', 'Chad Lindberg']},
#  {'year': 2002,
#   'title': 'Minority Report',
#   'cast': ['Tom Cruise', 'Max von Sydow', 'Steve Harris', 'Neal McDonough']},
#  {'cast': ['Tom Cruise',
#    'James Arnold',
#    'Michael J. Bloomfield',
#    'Robert D. Cabana'],
#   'title': 'Space Station 3D',
#   'year': 2002},
#  {'year': 2001,
#   'title': 'Vanilla Sky',
#   'cast': ['Tom Cruise', 'Penèlope Cruz', 'Cameron Diaz', 'Kurt Russell']}]

# %%
#Afficher tous les détails du film de "Tom Cruise",sorti en 2014, sauf son fullplot
list(movies.find({"cast": "Tom Cruise", "year": 2014}, {'_id': 0, 'fullplot': 0}))
# Out:
# [{'plot': 'A military officer is brought into an alien war against an extraterrestrial enemy who can reset the day and know the future. When this officer is enabled with the same power, he teams up with a Special Forces warrior to try and end the war.',
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'runtime': 113,
#   'metacritic': 71,
#   'rated': 'PG-13',
#   'cast': ['Tom Cruise', 'Emily Blunt', 'Brendan Gleeson', 'Bill Paxton'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTc5OTk4MTM3M15BMl5BanBnXkFtZTgwODcxNjg3MDE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Edge of Tomorrow',
#   'languages': ['English'],
#   'released': datetime.datetime(2014, 6, 6, 0, 0),
#   'directors': ['Doug Liman'],
#   'writers': ['Christopher McQuarrie (screenplay)',
#    'Jez Butterworth (screenplay)',
#    'John-Henry Butterworth (screenplay)',
#    'Hiroshi Sakurazaka (novel)'],
#   'awards': {'wins': 12,
#    'nominations': 28,
#    'text': '12 wins & 28 nominations.'},
#   'lastupdated': '2015-08-22 00:03:12.767000000',
#   'year': 2014,
#   'imdb': {'rating': 7.9, 'votes': 357609, 'id': 1631867},
#   'countries': ['USA', 'Canada'],
#   'type': 'movie',
#   'num_mflix_comments': 0}]

# %%
#Chercher les films dans lesquels joue au moins un des acteurs suivants : Angelina Jolie, Brad Pitt
pipeline = [
    {
        "$match": {
            "$or": [
                {"cast": "Angelina Jolie"},
                {"cast": "Brad Pitt"}
            ]
        }
    },
    {
        "$project": {
            "title": 1,
            "cast": 1,
            "_id": 0
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'title': 'Cool World',
#   'cast': ['Kim Basinger', 'Gabriel Byrne', 'Brad Pitt', 'Michele Abrams']},
#  {'title': 'Johnny Suede',
#   'cast': ['Brad Pitt', 'Richard Boes', 'Cheryl Costa', 'Michael Luciano']},
#  {'title': 'A River Runs Through It',
#   'cast': ['Craig Sheffer', 'Brad Pitt', 'Tom Skerritt', 'Brenda Blethyn']},
#  {'title': 'Kalifornia',
#   'cast': ['Brad Pitt', 'Kathy Larson', 'David Milford', 'David Duchovny']},
#  {'title': 'Interview with the Vampire: The Vampire Chronicles',
#   'cast': ['Brad Pitt',
#    'Christian Slater',
#    'Virginia McCollam',
#    'John McConnell']},
#  {'title': 'Legends of the Fall',
#   'cast': ['Brad Pitt', 'Anthony Hopkins', 'Aidan Quinn', 'Julia Ormond']},
#  {'title': 'Se7en',
#   'cast': ['Morgan Freeman',
#    'Andrew Kevin Walker',
#    'Daniel Zacapa',
#    'Brad Pitt']},
#  {'cast': ['Dana Delany', 'Annabeth Gish', 'Angelina Jolie', 'Tina Majorino'],
#   'title': 'True Women'},
#  {'title': 'Meet Joe Black',
#   'cast': ['Brad Pitt', 'Anthony Hopkins', 'Claire Forlani', 'Jake Weber']},
#  {'cast': ['Brad Pitt', 'David Thewlis', 'BD Wong', 'Mako'],
#   'title': 'Seven Years in Tibet'},
#  {'title': 'Pushing Tin',
#   'cast': ['John Cusack',
#    'Billy Bob Thornton',
#    'Cate Blanchett',
#    'Angelina Jolie']},
#  {'cast': ['Angelina Jolie',
#    'Elizabeth Mitchell',
#    'Eric Michael Cole',
#    'Kylie Travis'],
#   'title': 'Gia'},
#  {'title': 'Fight Club',
#   'cast': ['Edward Norton', 'Brad Pitt', 'Helena Bonham Carter', 'Meat Loaf']},
#  {'title': 'The Bone Collector',
#   'cast': ['Denzel Washington',
#    'Angelina Jolie',
#    'Queen Latifah',
#    'Michael Rooker']},
#  {'cast': ['Angelina Jolie',
#    'Sean Connery',
#    'Gena Rowlands',
#    'Gillian Anderson'],
#   'title': 'Playing by Heart'},
#  {'cast': ['Angelina Jolie', 'Jon Voight', 'Iain Glen', 'Noah Taylor'],
#   'title': 'Lara Croft: Tomb Raider'},
#  {'title': 'Sinbad: Legend of the Seven Seas',
#   'cast': ['Brad Pitt',
#    'Catherine Zeta-Jones',
#    'Michelle Pfeiffer',
#    'Joseph Fiennes']},
#  {'title': 'Girl, Interrupted',
#   'cast': ['Winona Ryder',
#    'Angelina Jolie',
#    'Clea DuVall',
#    'Brittany Murphy']},
#  {'title': 'Gone in Sixty Seconds',
#   'cast': ['Nicolas Cage', 'Giovanni Ribisi', 'Angelina Jolie', 'T.J. Cross']},
#  {'cast': ['Benicio Del Toro', 'Dennis Farina', 'Vinnie Jones', 'Brad Pitt'],
#   'title': 'Snatch.'},
#  {'title': 'Original Sin',
#   'cast': ['Antonio Banderas',
#    'Angelina Jolie',
#    'Thomas Jane',
#    'Jack Thompson']},
#  {'cast': ['Brad Pitt', 'Julia Roberts', 'James Gandolfini', 'J.K. Simmons'],
#   'title': 'The Mexican'},
#  {'title': 'Spy Game',
#   'cast': ['Robert Redford',
#    'Brad Pitt',
#    'Catherine McCormack',
#    'Stephen Dillane']},
#  {'title': 'Life or Something Like It',
#   'cast': ['Angelina Jolie',
#    'Edward Burns',
#    'Tony Shalhoub',
#    'Christian Kane']},
#  {'cast': ['Angelina Jolie', 'Clive Owen', 'Teri Polo', 'Linus Roache'],
#   'title': 'Beyond Borders'},
#  {'title': 'Lara Croft Tomb Raider: The Cradle of Life',
#   'cast': ['Angelina Jolie', 'Gerard Butler', 'Ciarèn Hinds', 'Chris Barrie']},
#  {'title': 'The Good Shepherd',
#   'cast': ['Matt Damon', 'Angelina Jolie', 'Alec Baldwin', 'Tammy Blanchard']},
#  {'cast': ['Anthony Hopkins',
#    'David Bedella',
#    'Jessie Kamm',
#    'Angelina Jolie'],
#   'title': 'Alexander'},
#  {'title': "Ocean's Twelve",
#   'cast': ['Brad Pitt', 'Catherine Zeta-Jones', 'George Clooney', 'Ed Kross']},
#  {'title': 'Mr. & Mrs. Smith',
#   'cast': ['Brad Pitt', 'Angelina Jolie', 'Vince Vaughn', 'Adam Brody']},
#  {'title': 'Inglourious Basterds',
#   'cast': ['Brad Pitt', 'Mèlanie Laurent', 'Christoph Waltz', 'Eli Roth']},
#  {'title': 'Taking Lives',
#   'cast': ['Angelina Jolie',
#    'Ethan Hawke',
#    'Kiefer Sutherland',
#    'Gena Rowlands']},
#  {'title': 'The Curious Case of Benjamin Button',
#   'cast': ['Cate Blanchett',
#    'Brad Pitt',
#    'Julia Ormond',
#    'Faune Chambers Watkins']},
#  {'title': 'Kung Fu Panda',
#   'cast': ['Jack Black', 'Dustin Hoffman', 'Angelina Jolie', 'Ian McShane']},
#  {'cast': ['Brad Pitt',
#    'Mary-Louise Parker',
#    'Brooklynn Proulx',
#    'Dustin Bollinger'],
#   'title': 'The Assassination of Jesse James by the Coward Robert Ford'},
#  {'title': 'Babel',
#   'cast': ['Brad Pitt', 'Cate Blanchett', 'Mohamed Akhzam', 'Peter Wight']},
#  {'title': 'The Tree of Life',
#   'cast': ['Brad Pitt', 'Sean Penn', 'Jessica Chastain', 'Hunter McCracken']},
#  {'title': 'Wanted',
#   'cast': ['James McAvoy',
#    'Morgan Freeman',
#    'Angelina Jolie',
#    'Terence Stamp']},
#  {'title': "Ocean's Thirteen",
#   'cast': ['George Clooney', 'Brad Pitt', 'Matt Damon', 'Michael Mantell']},
#  {'cast': ['Brad Pitt',
#    'Mireille Enos',
#    'Daniella Kertesz',
#    'James Badge Dale'],
#   'title': 'World War Z'},
#  {'title': 'Changeling',
#   'cast': ['Angelina Jolie',
#    'Gattlin Griffith',
#    'Michelle Gunn',
#    'Michael Kelly']},
#  {'title': 'A Mighty Heart',
#   'cast': ['Dan Futterman',
#    'Angelina Jolie',
#    'Archie Panjabi',
#    'Mohammed Afzal']},
#  {'title': 'A Mighty Heart',
#   'cast': ['Dan Futterman',
#    'Angelina Jolie',
#    'Archie Panjabi',
#    'Mohammed Afzal']},
#  {'title': 'Burn After Reading',
#   'cast': ['George Clooney',
#    'Frances McDormand',
#    'Brad Pitt',
#    'John Malkovich']},
#  {'title': 'Salt',
#   'cast': ['Angelina Jolie',
#    'Liev Schreiber',
#    'Chiwetel Ejiofor',
#    'Daniel Olbrychski']},
#  {'title': 'Megamind',
#   'cast': ['Will Ferrell', 'Brad Pitt', 'Tina Fey', 'Jonah Hill']},
#  {'title': 'Moneyball',
#   'cast': ['Brad Pitt',
#    'Jonah Hill',
#    'Philip Seymour Hoffman',
#    'Robin Wright']},
#  {'title': 'The Tourist',
#   'cast': ['Johnny Depp', 'Angelina Jolie', 'Paul Bettany', 'Timothy Dalton']},
#  {'title': 'Kung Fu Panda 2',
#   'cast': ['Jack Black', 'Angelina Jolie', 'Dustin Hoffman', 'Gary Oldman']},
#  {'cast': ['Angelina Jolie',
#    'Pierce Brosnan',
#    'Jane Goodall',
#    'Dale Peterson'],
#   'title': "Jane's Journey"},
#  {'cast': ['Angelina Jolie',
#    'Elle Fanning',
#    'Sharlto Copley',
#    'Lesley Manville'],
#   'title': 'Maleficent'},
#  {'cast': ['Jack Black', 'Dustin Hoffman', 'Angelina Jolie', 'Seth Rogen'],
#   'title': 'Kung Fu Panda Holiday'},
#  {'title': 'Killing Them Softly',
#   'cast': ['Brad Pitt',
#    'Scoot McNairy',
#    'Ben Mendelsohn',
#    'James Gandolfini']},
#  {'cast': ['Brad Pitt', 'Scoot McNairy', 'Ben Mendelsohn', 'James Gandolfini'],
#   'title': 'Killing Them Softly'},
#  {'cast': ['Jack Black', 'Angelina Jolie', 'Dustin Hoffman', 'Seth Rogen'],
#   'title': 'Kung Fu Panda: Secrets of the Masters'},
#  {'cast': ['Brad Pitt', 'Shia LaBeouf', 'Logan Lerman', 'Michael Peèa'],
#   'title': 'Fury'}]

# %%
list(movies.find(
    {"$or":
         [{"cast": "Angelina Jolie"},
          {"cast": "Brad Pitt"}]},
    {"_id": 0, "cast": 1}))
# Out:
# [{'cast': ['Kim Basinger', 'Gabriel Byrne', 'Brad Pitt', 'Michele Abrams']},
#  {'cast': ['Brad Pitt', 'Richard Boes', 'Cheryl Costa', 'Michael Luciano']},
#  {'cast': ['Craig Sheffer', 'Brad Pitt', 'Tom Skerritt', 'Brenda Blethyn']},
#  {'cast': ['Brad Pitt', 'Kathy Larson', 'David Milford', 'David Duchovny']},
#  {'cast': ['Brad Pitt',
#    'Christian Slater',
#    'Virginia McCollam',
#    'John McConnell']},
#  {'cast': ['Brad Pitt', 'Anthony Hopkins', 'Aidan Quinn', 'Julia Ormond']},
#  {'cast': ['Morgan Freeman',
#    'Andrew Kevin Walker',
#    'Daniel Zacapa',
#    'Brad Pitt']},
#  {'cast': ['Dana Delany', 'Annabeth Gish', 'Angelina Jolie', 'Tina Majorino']},
#  {'cast': ['Brad Pitt', 'Anthony Hopkins', 'Claire Forlani', 'Jake Weber']},
#  {'cast': ['Brad Pitt', 'David Thewlis', 'BD Wong', 'Mako']},
#  {'cast': ['John Cusack',
#    'Billy Bob Thornton',
#    'Cate Blanchett',
#    'Angelina Jolie']},
#  {'cast': ['Angelina Jolie',
#    'Elizabeth Mitchell',
#    'Eric Michael Cole',
#    'Kylie Travis']},
#  {'cast': ['Edward Norton', 'Brad Pitt', 'Helena Bonham Carter', 'Meat Loaf']},
#  {'cast': ['Denzel Washington',
#    'Angelina Jolie',
#    'Queen Latifah',
#    'Michael Rooker']},
#  {'cast': ['Angelina Jolie',
#    'Sean Connery',
#    'Gena Rowlands',
#    'Gillian Anderson']},
#  {'cast': ['Angelina Jolie', 'Jon Voight', 'Iain Glen', 'Noah Taylor']},
#  {'cast': ['Brad Pitt',
#    'Catherine Zeta-Jones',
#    'Michelle Pfeiffer',
#    'Joseph Fiennes']},
#  {'cast': ['Winona Ryder',
#    'Angelina Jolie',
#    'Clea DuVall',
#    'Brittany Murphy']},
#  {'cast': ['Nicolas Cage', 'Giovanni Ribisi', 'Angelina Jolie', 'T.J. Cross']},
#  {'cast': ['Benicio Del Toro', 'Dennis Farina', 'Vinnie Jones', 'Brad Pitt']},
#  {'cast': ['Antonio Banderas',
#    'Angelina Jolie',
#    'Thomas Jane',
#    'Jack Thompson']},
#  {'cast': ['Brad Pitt', 'Julia Roberts', 'James Gandolfini', 'J.K. Simmons']},
#  {'cast': ['Robert Redford',
#    'Brad Pitt',
#    'Catherine McCormack',
#    'Stephen Dillane']},
#  {'cast': ['Angelina Jolie',
#    'Edward Burns',
#    'Tony Shalhoub',
#    'Christian Kane']},
#  {'cast': ['Angelina Jolie', 'Clive Owen', 'Teri Polo', 'Linus Roache']},
#  {'cast': ['Angelina Jolie', 'Gerard Butler', 'Ciarèn Hinds', 'Chris Barrie']},
#  {'cast': ['Matt Damon', 'Angelina Jolie', 'Alec Baldwin', 'Tammy Blanchard']},
#  {'cast': ['Anthony Hopkins',
#    'David Bedella',
#    'Jessie Kamm',
#    'Angelina Jolie']},
#  {'cast': ['Brad Pitt', 'Catherine Zeta-Jones', 'George Clooney', 'Ed Kross']},
#  {'cast': ['Brad Pitt', 'Angelina Jolie', 'Vince Vaughn', 'Adam Brody']},
#  {'cast': ['Brad Pitt', 'Mèlanie Laurent', 'Christoph Waltz', 'Eli Roth']},
#  {'cast': ['Angelina Jolie',
#    'Ethan Hawke',
#    'Kiefer Sutherland',
#    'Gena Rowlands']},
#  {'cast': ['Cate Blanchett',
#    'Brad Pitt',
#    'Julia Ormond',
#    'Faune Chambers Watkins']},
#  {'cast': ['Jack Black', 'Dustin Hoffman', 'Angelina Jolie', 'Ian McShane']},
#  {'cast': ['Brad Pitt',
#    'Mary-Louise Parker',
#    'Brooklynn Proulx',
#    'Dustin Bollinger']},
#  {'cast': ['Brad Pitt', 'Cate Blanchett', 'Mohamed Akhzam', 'Peter Wight']},
#  {'cast': ['Brad Pitt', 'Sean Penn', 'Jessica Chastain', 'Hunter McCracken']},
#  {'cast': ['James McAvoy',
#    'Morgan Freeman',
#    'Angelina Jolie',
#    'Terence Stamp']},
#  {'cast': ['George Clooney', 'Brad Pitt', 'Matt Damon', 'Michael Mantell']},
#  {'cast': ['Brad Pitt',
#    'Mireille Enos',
#    'Daniella Kertesz',
#    'James Badge Dale']},
#  {'cast': ['Angelina Jolie',
#    'Gattlin Griffith',
#    'Michelle Gunn',
#    'Michael Kelly']},
#  {'cast': ['Dan Futterman',
#    'Angelina Jolie',
#    'Archie Panjabi',
#    'Mohammed Afzal']},
#  {'cast': ['Dan Futterman',
#    'Angelina Jolie',
#    'Archie Panjabi',
#    'Mohammed Afzal']},
#  {'cast': ['George Clooney',
#    'Frances McDormand',
#    'Brad Pitt',
#    'John Malkovich']},
#  {'cast': ['Angelina Jolie',
#    'Liev Schreiber',
#    'Chiwetel Ejiofor',
#    'Daniel Olbrychski']},
#  {'cast': ['Will Ferrell', 'Brad Pitt', 'Tina Fey', 'Jonah Hill']},
#  {'cast': ['Brad Pitt',
#    'Jonah Hill',
#    'Philip Seymour Hoffman',
#    'Robin Wright']},
#  {'cast': ['Johnny Depp', 'Angelina Jolie', 'Paul Bettany', 'Timothy Dalton']},
#  {'cast': ['Jack Black', 'Angelina Jolie', 'Dustin Hoffman', 'Gary Oldman']},
#  {'cast': ['Angelina Jolie',
#    'Pierce Brosnan',
#    'Jane Goodall',
#    'Dale Peterson']},
#  {'cast': ['Angelina Jolie',
#    'Elle Fanning',
#    'Sharlto Copley',
#    'Lesley Manville']},
#  {'cast': ['Jack Black', 'Dustin Hoffman', 'Angelina Jolie', 'Seth Rogen']},
#  {'cast': ['Brad Pitt',
#    'Scoot McNairy',
#    'Ben Mendelsohn',
#    'James Gandolfini']},
#  {'cast': ['Brad Pitt',
#    'Scoot McNairy',
#    'Ben Mendelsohn',
#    'James Gandolfini']},
#  {'cast': ['Jack Black', 'Angelina Jolie', 'Dustin Hoffman', 'Seth Rogen']},
#  {'cast': ['Brad Pitt', 'Shia LaBeouf', 'Logan Lerman', 'Michael Peèa']}]

# %%
#Chercher les films dont on ne trouve aucun acteur de la liste suivante: Sandra Bullock,Tom Hanks,Julia Roberts,Kevin Spacey,George Clooney
pipeline = [
    {
        "$match": {
            "$and": [
                {"cast": {"$ne": "Sandra Bullock"}},
                {"cast": {"$ne": "Tom Hanks"}},
                {"cast": {"$ne": "Julia Roberts"}},
                {"cast": {"$ne": "Kevin Spacey"}},
                {"cast": {"$ne": "George Clooney"}}
            ]
        }
    },
    {
        "$project": {
            "title": 1,
            "cast": 1,
            "_id": 0
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'cast': ['A.C. Abadie',
#    "Gilbert M. 'Broncho Billy' Anderson",
#    'George Barnes',
#    'Justus D. Barnes'],
#   'title': 'The Great Train Robbery'},
#  {'cast': ['Frank Powell',
#    'Grace Henderson',
#    'James Kirkwood',
#    'Linda Arvidson'],
#   'title': 'A Corner in Wheat'},
#  {'cast': ['Winsor McCay'],
#   'title': 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics'},
#  {'cast': ['Jane Gail', 'Ethel Grandin', 'William H. Turner', 'Matt Moore'],
#   'title': 'Traffic in Souls'},
#  {'cast': ['Winsor McCay', 'George McManus', 'Roy L. McCardell'],
#   'title': 'Gertie the Dinosaur'},
#  {'cast': ['Stanley Hunt',
#    'Sarah Constance Smith Hunt',
#    'Mrs. George Walkus',
#    "Paddy 'Malid"],
#   'title': 'In the Land of the Head Hunters'},
#  {'cast': ['Pearl White', 'Crane Wilbur', 'Paul Panzer', 'Edward Josè'],
#   'title': 'The Perils of Pauline'},
#  {'cast': ['George Beban', 'Clara Williams', 'J. Frank Burke', 'Leo Willis'],
#   'title': 'The Italian'},
#  {'cast': ['John McCann', 'James A. Marcus', 'Maggie Weston', 'Harry McCoy'],
#   'title': 'Regeneration'},
#  {'cast': ['Howard C. Hickman', 'Enid Markey', 'Lola May', 'Kate Bruce'],
#   'title': 'Civilization'},
#  {'cast': ['Tyrone Power Sr.', 'Helen Riaume', 'Marie Walcamp', 'Cora Drew'],
#   'title': 'Where Are My Children?'},
#  {'cast': ['Mary Pickford',
#    'Madlaine Traverse',
#    'Charles Wellesley',
#    'Gladys Fairbanks'],
#   'title': 'The Poor Little Rich Girl'},
#  {'cast': ['Douglas Fairbanks',
#    'Eileen Percy',
#    'Calvert Carter',
#    'Charles Stevens'],
#   'title': 'Wild and Woolly'},
#  {'cast': ['Tula Belle', 'Robin Macdougall', 'Edwin E. Reed', 'Emma Lowry'],
#   'title': 'The Blue Bird'},
#  {'cast': ['Harold Lloyd',
#    'Mildred Davis',
#    "'Snub' Pollard",
#    'Peggy Cartwright'],
#   'title': 'From Hand to Mouth'},
#  {'cast': ['Harold Lloyd', 'Roy Brooks', 'Mildred Davis', 'Wallace Howe'],
#   'title': 'High and Dizzy'},
#  {'cast': ['Buster Keaton', 'Sybil Seely'], 'title': 'One Week'},
#  {'cast': ['Edward Jobson',
#    'Beulah Booker',
#    'Edward Connelly',
#    'Edward Alexander'],
#   'title': 'The Saphead'},
#  {'cast': ['Lon Chaney', 'Leatrice Joy', 'John Bowers', 'Hardee Kirkland'],
#   'title': 'The Ace of Hearts'},
#  {'cast': ['Pomeroy Cannon',
#    'Josef Swickard',
#    'Bridgetta Clark',
#    'Rudolph Valentino'],
#   'title': 'The Four Horsemen of the Apocalypse'},
#  {'cast': ['Lois Wilson',
#    'Milton Sills',
#    'Theodore Roberts',
#    'Helen Ferguson'],
#   'title': 'Miss Lulu Bett'},
#  {'cast': ['Harold Lloyd', 'Mildred Davis', 'Anna Mae Bilson'],
#   'title': 'Now or Never'},
#  {'cast': ['Richard Barthelmess',
#    'Gladys Hulette',
#    'Walter P. Lewis',
#    'Ernest Torrence'],
#   'title': "Tol'able David"},
#  {'cast': ['Rudolph Christians', 'Miss DuPont', 'Maude George', 'Mae Busch'],
#   'title': 'Foolish Wives'},
#  {'cast': ['Mitchell Lewis', 'Alla Nazimova', 'Rose Dione', 'Earl Schenck'],
#   'title': 'Salomè'},
#  {'cast': ['Wallace Beery', 'Sam De Grasse', 'Enid Bennett', 'Paul Dickey'],
#   'title': 'Robin Hood'},
#  {'cast': ['Buster Keaton', 'Margaret Leahy', 'Wallace Beery', 'Joe Roberts'],
#   'title': 'Three Ages'},
#  {'cast': ['Edna Purviance', 'Clarence Geldart', 'Carl Miller', 'Lydia Knott'],
#   'title': 'A Woman of Paris: A Drama of Fate'},
#  {'cast': ['Lon Chaney', 'Norma Shearer', 'John Gilbert', 'Ruth King'],
#   'title': 'He Who Gets Slapped'},
#  {'title': 'The Iron Horse',
#   'cast': ["George O'Brien",
#    'Madge Bellamy',
#    'Charles Edward Bull',
#    'Cyril Chadwick']},
#  {'cast': ['George Ali', 'Esther Ralston', 'Cyril Chadwick', 'Mary Brian'],
#   'title': 'Peter Pan'},
#  {'cast': ['Douglas Fairbanks',
#    'Snitz Edwards',
#    'Charles Belcher',
#    'Julanne Johnston'],
#   'title': 'The Thief of Bagdad'},
#  {'cast': ['Frank Mayo',
#    'Virginia Valli',
#    'Ford Sterling',
#    'Nigel De Brulier'],
#   'title': 'Wild Oranges'},
#  {'cast': ['Betty Compson', 'Clive Brook', 'Henry Victor', 'A.B. Imeson'],
#   'title': 'White Shadows'},
#  {'cast': ['Rin Tin Tin', 'Nanette', 'Charles Farrell', 'June Marlowe'],
#   'title': 'Clash of the Wolves'},
#  {'cast': ['Merian C. Cooper',
#    'Ernest B. Schoedsack',
#    'Marguerite Harrison',
#    'Haidar Khan'],
#   'title': "Grass: A Nation's Battle for Life"},
#  {'cast': ['Ronald Colman', 'May McAvoy', 'Bert Lytell', 'Irene Rich'],
#   'title': "Lady Windermere's Fan"},
#  {'cast': ['Ronald Colman', 'Neil Hamilton', 'Ralph Forbes', 'Alice Joyce'],
#   'title': 'Beau Geste'},
#  {'cast': ['Billie Dove', 'Tempe Pigott', 'Donald Crisp', 'Sam De Grasse'],
#   'title': 'The Black Pirate'},
#  {'cast': ['Colleen Moore', 'Lloyd Hughes', 'Vera Lewis', 'Doris Baker'],
#   'title': 'Ella Cinders'},
#  {'cast': ['Harold Lloyd', 'Jobyna Ralston', 'Noah Young', 'Jim Mason'],
#   'title': "For Heaven's Sake"},
#  {'cast': ['Rudolph Valentino',
#    'Vilma Bènky',
#    'George Fawcett',
#    'Montagu Love'],
#   'title': 'The Son of the Sheik'},
#  {'cast': ['Harry Langdon',
#    'Priscilla Bonner',
#    'Gertrude Astor',
#    'William V. Mong'],
#   'title': 'The Strong Man'},
#  {'cast': ['Clara Bow',
#    'Antonio Moreno',
#    'William Austin',
#    'Priscilla Bonner'],
#   'title': 'It'},
#  {'cast': ['Albert Dieudonnè',
#    'Vladimir Roudenko',
#    'Edmond Van Daèle',
#    'Alexandre Koubitzky'],
#   'title': 'Napoleon'},
#  {'cast': ['Nancy Nash', 'Earle Foxe', 'Grant Withers', 'Lydia Yeamans Titus'],
#   'title': 'Upstream'},
#  {'cast': ['Clara Bow',
#    "Charles 'Buddy' Rogers",
#    'Richard Arlen',
#    'Jobyna Ralston'],
#   'title': 'Wings'},
#  {'cast': ['Margaret Mann', 'James Hall', 'Charles Morton', 'Ralph Bushman'],
#   'title': 'Four Sons'},
#  {'cast': ['Lon Chaney',
#    'Bernard Siegel',
#    'Loretta Young',
#    'Cissy Fitzgerald'],
#   'title': 'Laugh, Clown, Laugh'},
#  {'cast': ['Valèry Inkijinoff',
#    'I. Dedintsev',
#    'Aleksandr Chistyakov',
#    'Viktor Tsoppi'],
#   'title': 'Storm Over Asia'},
#  {'cast': ['Janet Gaynor',
#    'Charles Farrell',
#    'Natalie Kingston',
#    'Henry Armetta'],
#   'title': 'Street Angel'},
#  {'cast': ['Walt Disney'], 'title': 'Steamboat Willie'},
#  {'cast': ['Erich von Stroheim', 'Fay Wray', 'Matthew Betz', 'Zasu Pitts'],
#   'title': 'The Wedding March'},
#  {'cast': ['Helen Morgan', 'Joan Peers', 'Fuller Mellish Jr.', 'Jack Cameron'],
#   'title': 'Applause'},
#  {'cast': ['Albert Steinrèck',
#    'Else Heller',
#    'Gustav Frèhlich',
#    'Betty Amann'],
#   'title': 'Asphalt'},
#  {'cast': ['Charles King', 'Anita Page', 'Bessie Love'],
#   'title': 'The Broadway Melody'},
#  {'cast': ['George Arliss', 'Doris Lloyd', 'David Torrence', 'Joan Bennett'],
#   'title': 'Disraeli'},
#  {'cast': ['Daniel L. Haynes',
#    'Nina Mae McKinney',
#    'William Fountaine',
#    'Harry Gray'],
#   'title': 'Hallelujah'},
#  {'cast': ['Warner Baxter', 'Edmund Lowe', 'Dorothy Burgess'],
#   'title': 'In Old Arizona'},
#  {'cast': ['Gloria Swanson', 'Walter Byron', 'Seena Owen'],
#   'title': 'Queen Kelly'},
#  {'cast': ['Chester Morris',
#    'Wallace Beery',
#    'Lewis Stone',
#    'Robert Montgomery'],
#   'title': 'The Big House'},
#  {'cast': ['John Wayne',
#    'Marguerite Churchill',
#    'El Brendel',
#    'Tully Marshall'],
#   'title': 'The Big Trail'},
#  {'cast': ['Harry Baur', 'Paule Andral', 'Jackie Monnier', 'Jean Bradin'],
#   'title': 'David Golder'},
#  {'cast': ['Norma Shearer',
#    'Chester Morris',
#    'Conrad Nagel',
#    'Robert Montgomery'],
#   'title': 'The Divorcee'},
#  {'cast': ['Ronald Colman',
#    'Frederick Kerr',
#    'Loretta Young',
#    'David Torrence'],
#   'title': 'The Devil to Pay!'},
#  {'cast': ['Paul Whiteman', 'John Boles', 'Laura La Plante', 'Jeanette Loff'],
#   'title': 'King of Jazz'},
#  {'cast': ['Edward G. Robinson',
#    'Douglas Fairbanks Jr.',
#    'Glenda Farrell',
#    'William Collier Jr.'],
#   'title': 'Little Caesar'},
#  {'cast': ['Kenneth MacKenna',
#    'Frank Albertson',
#    'J. Farrell MacDonald',
#    'Warren Hymer'],
#   'title': 'Men Without Women'},
#  {'cast': ['Gary Cooper',
#    'Marlene Dietrich',
#    'Adolphe Menjou',
#    'Ullrich Haupt'],
#   'title': 'Morocco'},
#  {'cast': ['Greta Garbo', 'Lewis Stone', 'Gavin Gordon', 'Elliott Nugent'],
#   'title': 'Romance'},
#  {'cast': ['Fritz Kampers',
#    'Gustav Diessl',
#    'Hans-Joachim Mèbis',
#    'Claus Clausen'],
#   'title': 'Westfront 1918'},
#  {'cast': ['Stepan Shkurat',
#    'Semyon Svashenko',
#    'Yuliya Solntseva',
#    'Yelena Maksimova'],
#   'title': 'Earth'},
#  {'cast': ['James Dunn', 'Sally Eilers', 'Minna Gombell'],
#   'title': 'Bad Girl'},
#  {'cast': ['Wallace Beery', 'Jackie Cooper', 'Irene Rich', 'Roscoe Ates'],
#   'title': 'The Champ'},
#  {'cast': ['Richard Dix', 'Irene Dunne', 'Estelle Taylor', "Nance O'Neil"],
#   'title': 'Cimarron'},
#  {'cast': ['Virginia Cherrill',
#    'Florence Lee',
#    'Harry Myers',
#    'Al Ernest Garcia'],
#   'title': 'City Lights'},
#  {'cast': ['Marlene Dietrich',
#    'Victor McLaglen',
#    'Gustav von Seyffertitz',
#    'Warner Oland'],
#   'title': 'Dishonored'},
#  {'cast': ['Bela Lugosi', 'Helen Chandler', 'David Manners', 'Dwight Frye'],
#   'title': 'Dracula'},
#  {'cast': ['Norma Shearer',
#    'Leslie Howard',
#    'Lionel Barrymore',
#    'Clark Gable'],
#   'title': 'A Free Soul'},
#  {'cast': ['Alfred Lunt', 'Lynn Fontanne', 'Roland Young', 'Zasu Pitts'],
#   'title': 'The Guardsman'},
#  {'cast': ['Adolphe Menjou',
#    "Pat O'Brien",
#    'Mary Brian',
#    'Edward Everett Horton'],
#   'title': 'The Front Page'},
#  {'cast': ['Alexander Granach',
#    'Fritz Kampers',
#    'Ernst Busch',
#    'Elisabeth Wendt'],
#   'title': 'Comradeship'},
#  {'cast': ['Emilia Unda',
#    'Dorothea Wieck',
#    'Hedwig Schlichter',
#    'Hertha Thiele'],
#   'title': 'Mèdchen in Uniform'},
#  {'cast': ['Albert Prèjean', 'Florelle', 'Gaston Modot', 'Margo Lion'],
#   'title': "L'opèra de quat'sous"},
#  {'cast': ['James Cagney', 'Jean Harlow', 'Edward Woods', 'Joan Blondell'],
#   'title': 'The Public Enemy'},
#  {'cast': ['Helen Hayes', 'Lewis Stone', 'Neil Hamilton', 'Robert Young'],
#   'title': 'The Sin of Madelon Claudet'},
#  {'cast': ['Jackie Cooper', 'Robert Coogan', 'Mitzi Green', 'Jackie Searl'],
#   'title': 'Skippy'},
#  {'cast': ['Matahi', 'Anne Chevalier', 'Bill Bambridge', 'Hitu'],
#   'title': 'Tabu: A Story of the South Seas'},
#  {'cast': ['Henri Marchand', 'Raymond Cordy', 'Rolla France', 'Paul Ollivier'],
#   'title': 'è Nous la Libertè'},
#  {'cast': ['Leni Riefenstahl',
#    'Mathias Wieman',
#    'Beni Fèhrer',
#    'Max Holzboer'],
#   'title': 'The Blue Light'},
#  {'cast': ['Lionel Barrymore',
#    'Nancy Carroll',
#    'Phillips Holmes',
#    'Louise Carter'],
#   'title': 'Broken Lullaby'},
#  {'cast': ['James Cagney', 'Joan Blondell', 'Ann Dvorak', 'Eric Linden'],
#   'title': 'The Crowd Roars'},
#  {'cast': ['Fredric March', 'Miriam Hopkins', 'Rose Hobart', 'Holmes Herbert'],
#   'title': 'Dr. Jekyll and Mr. Hyde'},
#  {'cast': ['Barbara Stanwyck',
#    'Adolphe Menjou',
#    'Ralph Bellamy',
#    'Dorothy Peterson'],
#   'title': 'Forbidden'},
#  {'cast': ['Greta Garbo', 'John Barrymore', 'Joan Crawford', 'Wallace Beery'],
#   'title': 'Grand Hotel'},
#  {'cast': ['Jan Kiepura', 'Magda Schneider', 'Fritz Schulz', 'Otto Wallburg'],
#   'title': 'The Song of Night'},
#  {'cast': ['Maurice Chevalier',
#    'Jeanette MacDonald',
#    'Charles Ruggles',
#    'Charles Butterworth'],
#   'title': 'Love Me Tonight'},
#  {'cast': ['Harold Lloyd',
#    'Constance Cummings',
#    'Kenneth Thomson',
#    'Louise Closser Hale'],
#   'title': 'Movie Crazy'},
#  {'cast': ['Stan Laurel', 'Oliver Hardy'], 'title': 'The Music Box'},
#  {'cast': ['Charles Laughton',
#    "Maureen O'Sullivan",
#    'Dorothy Peterson',
#    'Verree Teasdale'],
#   'title': 'Payment Deferred'},
#  {'cast': ['Harry Baur', 'Robert Lynen', 'Louis Gauthier', 'Simone Aubry'],
#   'title': 'The Red Head'},
#  {'cast': ['Clark Gable', 'Jean Harlow', 'Gene Raymond', 'Mary Astor'],
#   'title': 'Red Dust'},
#  {'cast': ['Paul Muni', 'Ann Dvorak', 'Karen Morley', 'Osgood Perkins'],
#   'title': 'Scarface'},
#  {'cast': ['Marlene Dietrich', 'Clive Brook', 'Anna May Wong', 'Warner Oland'],
#   'title': 'Shanghai Express'},
#  {'cast': ['Norma Shearer', 'Fredric March', 'Leslie Howard', 'O.P. Heggie'],
#   'title': "Smilin' Through"},
#  {'cast': ['Johnny Weissmuller',
#    'Neil Hamilton',
#    'C. Aubrey Smith',
#    "Maureen O'Sullivan"],
#   'title': 'Tarzan the Ape Man'},
#  {'cast': ['Edward G. Robinson',
#    'Vivienne Osborne',
#    'Guy Kibbee',
#    'Preston Foster'],
#   'title': 'Two Seconds'},
#  {'cast': ['Miriam Hopkins',
#    'Kay Francis',
#    'Herbert Marshall',
#    'Charles Ruggles'],
#   'title': 'Trouble in Paradise'},
#  {'cast': ['Barbara Stanwyck',
#    'George Brent',
#    'Donald Cook',
#    'Alphonse Ethier'],
#   'title': 'Baby Face'},
#  {'cast': ['Diana Wynyard', 'Clive Brook', "Una O'Connor", 'Herbert Mundin'],
#   'title': 'Cavalcade'},
#  {'cast': ['Takeshi Sakamoto', 'Nobuko Fushimi', 'Den Obinata', 'Chèko Iida'],
#   'title': 'Dekigokoro'},
#  {'cast': ['The Marx Brothers', 'Groucho Marx', 'Harpo Marx', 'Chico Marx'],
#   'title': 'Duck Soup'},
#  {'cast': ['Edgar Dearing', 'Peter Freuchen', 'Edward Hearn', 'Lotus Long'],
#   'title': 'Eskimo'},
#  {'cast': ['James Cagney', 'Joan Blondell', 'Ruby Keeler', 'Dick Powell'],
#   'title': 'Footlight Parade'},
#  {'cast': ['Dolores del Rio', 'Gene Raymond', 'Raul Roulien', 'Ginger Rogers'],
#   'title': 'Flying Down to Rio'},
#  {'cast': ['Paul Robeson',
#    'Dudley Digges',
#    'Frank H. Wilson',
#    'Fredi Washington'],
#   'title': 'The Emperor Jones'},
#  {'cast': ['Marion Davies', 'Bing Crosby', "Fifi D'Orsay", 'Stuart Erwin'],
#   'title': 'Going Hollywood'},
#  {'cast': ['Spencer Tracy', 'Colleen Moore', 'Ralph Morgan', 'Helen Vinson'],
#   'title': 'The Power and the Glory'},
#  {'cast': ['Charles Laughton',
#    'Robert Donat',
#    'Franklin Dyall',
#    'Miles Mander'],
#   'title': 'The Private Life of Henry VIII.'},
#  {'cast': ['Greta Garbo', 'John Gilbert', 'Ian Keith', 'Lewis Stone'],
#   'title': 'Queen Christina'},
#  {'cast': ['Mae West', 'Cary Grant', 'Owen Moore', 'Gilbert Roland'],
#   'title': 'She Done Him Wrong'},
#  {'cast': ['Stan Laurel', 'Oliver Hardy', 'Charley Chase', 'Mae Busch'],
#   'title': 'Sons of the Desert'},
#  {'cast': ['Robert Armstrong', 'Helen Mack', 'Frank Reicher', 'John Marston'],
#   'title': 'The Son of Kong'},
#  {'cast': ['Janet Gaynor', 'Will Rogers', 'Lew Ayres', 'Sally Eilers'],
#   'title': 'State Fair'},
#  {'cast': ['Billy Bletcher', 'Pinto Colvig', 'Dorothy Compton', 'Mary Moder'],
#   'title': 'Three Little Pigs'},
#  {'cast': ['John Barrymore', 'Myrna Loy', 'Reginald Mason', 'Jobyna Howland'],
#   'title': 'Topaze'},
#  {'cast': ['Frankie Darro',
#    'Edwin Phillips',
#    'Rochelle Hudson',
#    'Dorothy Coonan Wellman'],
#   'title': 'Wild Boys of the Road'},
#  {'cast': ['Loretta Young', 'Gene Raymond', 'O.P. Heggie', 'Wally Albright'],
#   'title': 'Zoo in Budapest'},
#  {'cast': ['Norma Shearer',
#    'Fredric March',
#    'Charles Laughton',
#    "Maureen O'Sullivan"],
#   'title': 'The Barretts of Wimpole Street'},
#  {'cast': ['Boris Karloff', 'Bela Lugosi', 'David Manners', 'Julie Bishop'],
#   'title': 'The Black Cat'},
#  {'cast': ['Warner Baxter', 'Myrna Loy', 'Walter Connolly', 'Helen Vinson'],
#   'title': 'Broadway Bill'},
#  {'cast': ['Boris Babochkin',
#    'Leonid Kmit',
#    'Varvara Myasnikova',
#    'Boris Blinov'],
#   'title': 'Chapayev'},
#  {'cast': ['Joan Blondell', 'Dick Powell', 'Ruby Keeler', 'Zasu Pitts'],
#   'title': 'Dames'},
#  {'cast': ['Fred Astaire',
#    'Ginger Rogers',
#    'Alice Brady',
#    'Edward Everett Horton'],
#   'title': 'The Gay Divorcee'},
#  {'title': 'Le grand jeu',
#   'cast': ['Marie Bell',
#    'Pierre Richard-Willm',
#    'Charles Vanel',
#    'Georges Pitoèff']},
#  {'cast': ['Claudette Colbert',
#    'Warren William',
#    'Rochelle Hudson',
#    'Ned Sparks'],
#   'title': 'Imitation of Life'},
#  {'cast': ['W.C. Fields',
#    'Kathleen Howard',
#    'Jean Rouverol',
#    'Julian Madison'],
#   'title': "It's a Gift"},
#  {'cast': ['Adolphe Menjou',
#    'Shirley Temple',
#    'Dorothy Dell',
#    'Charles Bickford'],
#   'title': 'Little Miss Marker'},
#  {'cast': ['Victor McLaglen',
#    'Boris Karloff',
#    'Wallace Ford',
#    'Reginald Denny'],
#   'title': 'The Lost Patrol'},
#  {'cast': ["Colman 'Tiger' King",
#    'Maggie Dirrane',
#    'Michael Dirrane',
#    'Pat Mullin'],
#   'title': 'Man of Aran'},
#  {'cast': ['Madeleine Renaud',
#    'Suzanne Desprès',
#    'Gaby Triquet',
#    'Maximilienne'],
#   'title': 'Maria Chapdelaine'},
#  {'cast': ['Leslie Banks', 'Edna Best', 'Peter Lorre', 'Frank Vosper'],
#   'title': 'The Man Who Knew Too Much'},
#  {'cast': ['Harry Baur', 'Charles Vanel', 'Paul Azaès', 'Max Dearly'],
#   'title': 'Les Misèrables'},
#  {'cast': ['Paula Wessely',
#    'Anton Walbrook',
#    'Peter Petersen',
#    'Walter Janssen'],
#   'title': 'Masquerade in Vienna'},
#  {'cast': ['Grace Moore', 'Tullio Carminati', 'Lyle Talbot', 'Mona Barrie'],
#   'title': 'One Night of Love'},
#  {'cast': ['Isa Miranda',
#    'Memo Benassi',
#    'Tatyana Pavlova',
#    'Friedrich Benfer'],
#   'title': "Everybody's Woman"},
#  {'cast': ['Charles Blavette',
#    'Celia Montalvèn',
#    'èdouard Delmont',
#    'Max Dalban'],
#   'title': 'Toni'},
#  {'cast': ['Adolf Hitler', 'Max Amann', 'Martin Bormann', 'Walter Buch'],
#   'title': 'Triumph of the Will'},
#  {'cast': ['John Barrymore',
#    'Carole Lombard',
#    'Walter Connolly',
#    'Roscoe Karns'],
#   'title': 'Twentieth Century'},
#  {'cast': ['Leonid Utyosov',
#    'Lyubov Orlova',
#    'Mariya Strelkova',
#    'Yelena Tyapkina'],
#   'title': 'Moscow Laughs'},
#  {'cast': ['Wallace Beery', 'Leo Carrillo', 'Fay Wray', 'Donald Cook'],
#   'title': 'Viva Villa!'},
#  {'cast': ['Madeleine Carroll',
#    'Franchot Tone',
#    'Reginald Denny',
#    'Sig Ruman'],
#   'title': 'The World Moves On'},
#  {'cast': ['Al Jolson', 'Kay Francis', 'Dolores del Rio', 'Ricardo Cortez'],
#   'title': 'Wonder Bar'},
#  {'cast': ['Greta Garbo',
#    'Fredric March',
#    'Freddie Bartholomew',
#    "Maureen O'Sullivan"],
#   'title': 'Anna Karenina'},
#  {'cast': ['Clarence Nash'], 'title': 'The Band Concert'},
#  {'cast': ['Katharine Hepburn',
#    'Fred MacMurray',
#    'Fred Stone',
#    'Evelyn Venable'],
#   'title': 'Alice Adams'},
#  {'cast': ['Paul Muni', 'Karen Morley', 'William Gargan', 'Barton MacLane'],
#   'title': 'Black Fury'},
#  {'cast': ['Jack Benny', 'Eleanor Powell', 'Robert Taylor', 'Una Merkel'],
#   'title': 'Broadway Melody of 1936'},
#  {'cast': ['Clark Gable', 'Jean Harlow', 'Wallace Beery', 'Lewis Stone'],
#   'title': 'China Seas'},
#  {'cast': ['Shirley Temple', 'John Boles', 'Rochelle Hudson', 'Jane Darwell'],
#   'title': 'Curly Top'},
#  {'cast': ['Spencer Tracy',
#    'Claire Trevor',
#    'Henry B. Walthall',
#    'Alan Dinehart'],
#   'title': "Dante's Inferno"},
#  {'cast': ['Edna May Oliver',
#    'Elizabeth Allan',
#    'Jessie Ralph',
#    'Harry Beresford'],
#   'title': 'David Copperfield'},
#  {'cast': ['Fredric March',
#    'Merle Oberon',
#    'Herbert Marshall',
#    'Janet Beecher'],
#   'title': 'The Dark Angel'},
#  {'title': 'The Devil Is a Woman',
#   'cast': ['Marlene Dietrich',
#    'Lionel Atwill',
#    'Edward Everett Horton',
#    'Alison Skipworth']},
#  {'cast': ['Maurice Chevalier', 'Merle Oberon', 'Ann Sothern', 'Eric Blore'],
#   'title': 'Folies Bergère de Paris'},
#  {'cast': ['Claudette Colbert',
#    'Fred MacMurray',
#    'Ray Milland',
#    'C. Aubrey Smith'],
#   'title': 'The Gilded Lily'},
#  {'cast': ['Robert Donat',
#    'Jean Parker',
#    'Eugene Pallette',
#    'Elsa Lanchester'],
#   'title': 'The Ghost Goes West'},
#  {'cast': ['Dick Powell', 'Adolphe Menjou', 'Gloria Stuart', 'Alice Brady'],
#   'title': 'Gold Diggers of 1935'},
#  {'cast': ['Victor McLaglen',
#    'Heather Angel',
#    'Preston Foster',
#    'Margot Grahame'],
#   'title': 'The Informer'},
#  {'cast': ['Franèoise Rosay', 'Andrè Alerme', 'Jean Murat', 'Louis Jouvet'],
#   'title': 'Carnival in Flanders'},
#  {'cast': ['Ian Hunter', 'Verree Teasdale', 'Hobart Cavanaugh', 'Dick Powell'],
#   'title': "A Midsummer Night's Dream"},
#  {'cast': ['Fredric March',
#    'Charles Laughton',
#    'Cedric Hardwicke',
#    'Rochelle Hudson'],
#   'title': 'Les Misèrables'},
#  {'cast': ['Jeanette MacDonald',
#    'Nelson Eddy',
#    'Frank Morgan',
#    'Elsa Lanchester'],
#   'title': 'Naughty Marietta'},
#  {'cast': ['Groucho Marx', 'Chico Marx', 'Harpo Marx', 'Kitty Carlisle'],
#   'title': 'A Night at the Opera'},
#  {'cast': ['Vladimir Konstantinov', 'Ivan Yudin', 'Shaolin Santiago'],
#   'title': 'The New Gulliver'},
#  {'cast': ['Irene Dunne', 'Fred Astaire', 'Ginger Rogers', 'Randolph Scott'],
#   'title': 'Roberta'},
#  {'cast': ['Seymour Hicks',
#    'Donald Calthrop',
#    'Robert Cochran',
#    'Mary Glynne'],
#   'title': 'Scrooge'},
#  {'cast': ['Helen Gahagan', 'Randolph Scott', 'Helen Mack', 'Nigel Bruce'],
#   'title': 'She'},
#  {'cast': ['Fred Astaire',
#    'Ginger Rogers',
#    'Edward Everett Horton',
#    'Erik Rhodes'],
#   'title': 'Top Hat'},
#  {'cast': ['Sachiko Chiba',
#    'Yuriko Hanabusa',
#    'Toshiko Itè',
#    'Setsuko Horikoshi'],
#   'title': 'Wife! Be Like a Rose!'},
#  {'cast': ['Gary Cooper', 'Anna Sten', 'Ralph Bellamy', 'Helen Vinson'],
#   'title': 'The Wedding Night'},
#  {'cast': ['Billy Bletcher', 'Purv Pullen', 'Martha Wentworth'],
#   'title': 'Who Killed Cock Robin?'},
#  {'cast': ['Fredric March',
#    'Olivia de Havilland',
#    'Donald Woods',
#    'Anita Louise'],
#   'title': 'Anthony Adverse'},
#  {'cast': ['Jean Gabin', 'Suzy Prim', 'Louis Jouvet', 'Jany Holt'],
#   'title': 'The Lower Depths'},
#  {'cast': ['Maurice Chevalier',
#    'Betty Stockfeld',
#    'Margaret Lockwood',
#    'Desmond Tester'],
#   'title': 'The Beloved Vagabond'},
#  {'cast': ['Humphrey Bogart',
#    'Dick Foran',
#    "Erin O'Brien-Moore",
#    'Ann Sheridan'],
#   'title': 'Black Legion'},
#  {'cast': ['Errol Flynn',
#    'Olivia de Havilland',
#    'Patric Knowles',
#    'Henry Stephenson'],
#   'title': 'The Charge of the Light Brigade'},
#  {'cast': ['Edward Arnold', 'Joel McCrea', 'Frances Farmer', 'Walter Brennan'],
#   'title': 'Come and Get It'},
#  {'cast': ['Walter Huston', 'Ruth Chatterton', 'Paul Lukas', 'Mary Astor'],
#   'title': 'Dodsworth'},
#  {'cast': ['Fred Astaire',
#    'Ginger Rogers',
#    'Randolph Scott',
#    'Harriet Hilliard'],
#   'title': 'Follow the Fleet'},
#  {'cast': ['Buster Crabbe',
#    'Jean Rogers',
#    'Charles Middleton',
#    'Priscilla Lawson'],
#   'title': 'Flash Gordon'},
#  {'cast': ['Isuzu Yamada',
#    'Yèko Umemura',
#    'Benkei Shiganoya',
#    'Eitarè Shindè'],
#   'title': 'Sisters of the Gion'},
#  {'cast': ['Marlene Dietrich',
#    'Charles Boyer',
#    'Tilly Losch',
#    'Basil Rathbone'],
#   'title': 'The Garden of Allah'},
#  {'cast': ['Rex Ingram',
#    'Oscar Polk',
#    "Eddie 'Rochester' Anderson",
#    'Frank H. Wilson'],
#   'title': 'The Green Pastures'},
#  {'cast': ['Boris Karloff', 'Bela Lugosi', 'Frances Drake', 'Frank Lawton'],
#   'title': 'The Invisible Ray'},
#  {'cast': ['Luis Trenker',
#    'Viktoria von Ballasko',
#    'Werner Kunig',
#    'Karli Zwingmann'],
#   'title': 'Der Kaiser von Kalifornien'},
#  {'cast': ['Freddie Bartholomew',
#    'Madeleine Carroll',
#    'Guy Standing',
#    'Tyrone Power'],
#   'title': "Lloyd's of London"},
#  {'cast': ['Katharine Hepburn',
#    'Fredric March',
#    'Florence Eldridge',
#    'Douglas Walton'],
#   'title': 'Mary of Scotland'},
#  {'title': 'Modern Times',
#   'cast': ['Charles Chaplin',
#    'Paulette Goddard',
#    'Henry Bergman',
#    'Tiny Sandford']},
#  {'cast': ['Charles Boyer',
#    'Danielle Darrieux',
#    'Marthe Règnier',
#    'Yolande Laffon'],
#   'title': 'Mayerling'},
#  {'cast': ['Gary Cooper', 'Jean Arthur', 'George Bancroft', 'Lionel Stander'],
#   'title': 'Mr. Deeds Goes to Town'},
#  {'cast': ['Lou Fleischer', 'Jack Mercer', 'Mae Questel', 'Gus Wickie'],
#   'title': 'Popeye the Sailor Meets Sindbad the Sailor'},
#  {'cast': ['Warner Baxter',
#    'Gloria Stuart',
#    'Claude Gillingwater',
#    'Arthur Byron'],
#   'title': 'The Prisoner of Shark Island'},
#  {'cast': ['Charles Laughton',
#    'Gertrude Lawrence',
#    'Elsa Lanchester',
#    'Edward Chapman'],
#   'title': 'Rembrandt'},
#  {'cast': ['Franèoise Rosay', 'Magda Sonja', 'George Graves', 'Jim Gèrald'],
#   'title': 'The Robber Symphony'},
#  {'cast': ['Sacha Guitry',
#    'Marguerite Moreno',
#    'Jacqueline Delubac',
#    'Roger Duchesne'],
#   'title': 'The Story of a Cheat'},
#  {'cast': ['Norma Shearer',
#    'Leslie Howard',
#    'John Barrymore',
#    'Edna May Oliver'],
#   'title': 'Romeo and Juliet'},
#  {'cast': ['Willy Birgel',
#    'Lil Dagover',
#    'Mèria Tasnèdi Fekete',
#    'Maria Koppenhèfer'],
#   'title': 'Final Accord'},
#  {'cast': ['Miriam Hopkins',
#    'Merle Oberon',
#    'Joel McCrea',
#    'Catherine Doucet'],
#   'title': 'These Three'},
#  {'cast': ['Irene Dunne',
#    'Melvyn Douglas',
#    'Thomas Mitchell',
#    'Thurston Hall'],
#   'title': 'Theodora Goes Wild'},
#  {'cast': ['Binnie Barnes', 'Charles Winninger', 'Alice Brady', 'Ray Milland'],
#   'title': 'Three Smart Girls'},
#  {'cast': ['Sylvia Sidney', 'Fred MacMurray', 'Henry Fonda', 'Fred Stone'],
#   'title': 'The Trail of the Lonesome Pine'},
#  {'cast': ['Lyubov Orlova',
#    'Evgeniya Melnikova',
#    'Vladimir Volodin',
#    'Sergei Stolyarov'],
#   'title': 'Tsirk'},
#  {'cast': ['Greta Garbo',
#    'Robert Taylor',
#    'Lionel Barrymore',
#    'Elizabeth Allan'],
#   'title': 'Camille'},
#  {'cast': ['Freddie Bartholomew',
#    'Spencer Tracy',
#    'Lionel Barrymore',
#    'Melvyn Douglas'],
#   'title': 'Captains Courageous'},
#  {'cast': ['Fred Astaire', 'George Burns', 'Gracie Allen', 'Joan Fontaine'],
#   'title': 'A Damsel in Distress'},
#  {'cast': ['Anna May Wong',
#    'Charles Bickford',
#    'Buster Crabbe',
#    'Cecil Cunningham'],
#   'title': 'Daughter of Shanghai'},
#  {'cast': ['Sabu', 'W.E. Holloway', 'Walter Hudd', 'Allan Jeayes'],
#   'title': 'Elephant Boy'},
#  {'cast': ['John Laurie', 'Belle Chrystall', 'Eric Berry', 'Kitty Kirwan'],
#   'title': 'The Edge of the World'},
#  {'cast': ['Paul Muni', 'Luise Rainer', 'Walter Connolly', 'Tilly Losch'],
#   'title': 'The Good Earth'},
#  {'cast': ['Fernandel',
#    'Orane Demazis',
#    'Marguerite Moreno',
#    'èdouard Delmont'],
#   'title': 'Harvest'},
#  {'cast': ['Dorothy Lamour', 'Jon Hall', 'Mary Astor', 'C. Aubrey Smith'],
#   'title': 'The Hurricane'},
#  {'cast': ['Tyrone Power', 'Alice Faye', 'Don Ameche', 'Alice Brady'],
#   'title': 'In Old Chicago'},
#  {'cast': ['Edward G. Robinson',
#    'Bette Davis',
#    'Humphrey Bogart',
#    'Wayne Morris'],
#   'title': 'Kid Galahad'},
#  {'title': 'Children in the Wind',
#   'cast': ['Reikichi Kawamura',
#    'Mitsuko Yoshikawa',
#    'Masao Hayama',
#    'Tomio Aoki']},
#  {'cast': ['Boris Shchukin',
#    'Nikolai Okhlopkov',
#    'Vasili Vanin',
#    'Nikolai Svobodin'],
#   'title': 'Lenin in October'},
#  {'cast': ['Victor Moore', 'Beulah Bondi', 'Fay Bainter', 'Thomas Mitchell'],
#   'title': 'Make Way for Tomorrow'},
#  {'cast': ['Bette Davis', 'Humphrey Bogart', 'Lola Lane', 'Isabel Jewell'],
#   'title': 'Marked Woman'},
#  {'cast': ['Merle Tottenham',
#    'Kathleen Harrison',
#    'Dame May Whitty',
#    'Rosalind Russell'],
#   'title': 'Night Must Fall'},
#  {'cast': ['Deanna Durbin',
#    'Leopold Stokowski',
#    'Adolphe Menjou',
#    'Alice Brady'],
#   'title': 'One Hundred Men and a Girl'},
#  {'cast': ['Jacqueline Delubac',
#    'Sacha Guitry',
#    'Lyn Harding',
#    'Renèe Saint-Cyr'],
#   'title': 'The Pearls of the Crown'},
#  {'cast': ['Errol Flynn',
#    'Claude Rains',
#    'Henry Stephenson',
#    'Barton MacLane'],
#   'title': 'The Prince and the Pauper'},
#  {'cast': ['Ronald Colman',
#    'Madeleine Carroll',
#    'C. Aubrey Smith',
#    'Raymond Massey'],
#   'title': 'The Prisoner of Zenda'},
#  {'cast': ['Fred Astaire',
#    'Ginger Rogers',
#    'Edward Everett Horton',
#    'Eric Blore'],
#   'title': 'Shall We Dance'},
#  {'cast': ['Roy Atwell',
#    'Stuart Buchanan',
#    'Adriana Caselotti',
#    'Hall Johnson Choir'],
#   'title': 'Snow White and the Seven Dwarfs'},
#  {'cast': ['Katharine Hepburn',
#    'Ginger Rogers',
#    'Adolphe Menjou',
#    'Gail Patrick'],
#   'title': 'Stage Door'},
#  {'cast': ['Claude Rains', 'Gloria Dickson', 'Edward Norris', 'Otto Kruger'],
#   'title': "They Won't Forget"},
#  {'cast': ['Harry Baur', 'Marie Bell', 'Pierre Blanchar', 'Fernandel'],
#   'title': 'Dance Program'},
#  {'cast': ['Bing Crosby', 'Bob Burns', 'Martha Raye', 'Shirley Ross'],
#   'title': 'Waikiki Wedding'},
#  {'cast': ['Emil Jannings',
#    'Friedrich Kayèler',
#    'Max Gèlstorff',
#    'Lina Carstens'],
#   'title': 'Der zerbrochene Krug'},
#  {'cast': ['Zarah Leander', 'Willy Birgel', 'Edwin Jèrgensen', 'Carola Hèhn'],
#   'title': 'To New Shores'},
#  {'title': 'The Adventures of Robin Hood',
#   'cast': ['Errol Flynn',
#    'Olivia de Havilland',
#    'Basil Rathbone',
#    'Claude Rains']},
#  {'cast': ['May Robson', 'Walter Brennan', 'Victor Jory', 'David Holt'],
#   'title': 'The Adventures of Tom Sawyer'},
#  {'cast': ['James Cagney', "Pat O'Brien", 'Humphrey Bogart', 'Ann Sheridan'],
#   'title': 'Angels with Dirty Faces'},
#  {'cast': ['Tyrone Power', 'Alice Faye', 'Don Ameche', 'Ethel Merman'],
#   'title': "Alexander's Ragtime Band"},
#  {'cast': ['W.C. Fields', 'Martha Raye', 'Dorothy Lamour', 'Shirley Ross'],
#   'title': 'The Big Broadcast of 1938'},
#  {'cast': ['Katharine Hepburn',
#    'Cary Grant',
#    'Charles Ruggles',
#    'Walter Catlett'],
#   'title': 'Bringing Up Baby'},
#  {'cast': ['Spencer Tracy', 'Mickey Rooney', 'Henry Hull', 'Leslie Fenton'],
#   'title': 'Boys Town'},
#  {'cast': ['Fred Astaire', 'Ginger Rogers', 'Ralph Bellamy', 'Luella Gear'],
#   'title': 'Carefree'},
#  {'cast': ['Robert Donat',
#    'Rosalind Russell',
#    'Ralph Richardson',
#    'Rex Harrison'],
#   'title': 'The Citadel'},
#  {'cast': ['Gary Cooper', 'Merle Oberon', 'Patsy Kelly', 'Walter Brennan'],
#   'title': 'The Cowboy and the Lady'},
#  {'cast': ['Aleksei Lyarsky',
#    'Varvara Massalitinova',
#    'Mikhail Troyanovsky',
#    'Elizaveta Alekseeva'],
#   'title': 'The Childhood of Maxim Gorky'},
#  {'cast': ['Sabu', 'Raymond Massey', 'Roger Livesey', 'Valerie Hobson'],
#   'title': 'Drums'},
#  {'cast': ['Claude Rains', 'Jeffrey Lynn', 'John Garfield', 'Frank McHugh'],
#   'title': 'Four Daughters'},
#  {'cast': ['Luise Rainer', 'Fernand Gravey', 'Miliza Korjus', 'Hugh Herbert'],
#   'title': 'The Great Waltz'},
#  {'cast': ['Annabella', 'Jean-Pierre Aumont', 'Louis Jouvet', 'Arletty'],
#   'title': 'Hotel du Nord'},
#  {'cast': ['Bette Davis', 'Henry Fonda', 'George Brent', 'Margaret Lindsay'],
#   'title': 'Jezebel'},
#  {'cast': ['Margaret Lockwood',
#    'Michael Redgrave',
#    'Paul Lukas',
#    'Dame May Whitty'],
#   'title': 'The Lady Vanishes'},
#  {'cast': ['Mickey Rooney', 'Lewis Stone', 'Fay Holden', 'Cecilia Parker'],
#   'title': 'Love Finds Andy Hardy'},
#  {'cast': ['Anne Shirley', 'Edward Ellis', 'Lee Bowman', 'William Henry'],
#   'title': 'A Man to Remember'},
#  {'cast': ['Norma Shearer', 'Tyrone Power', 'John Barrymore', 'Robert Morley'],
#   'title': 'Marie Antoinette'},
#  {'cast': ['Anne Shirley', 'Ruby Keeler', 'James Ellison', 'Fay Bainter'],
#   'title': "Mother Carey's Chickens"},
#  {'cast': ['David Albritton', 'Arvo Askola', 'Jack Beresford', 'Erwin Blask'],
#   'title': 'Olympia Part One: Festival of the Nations'},
#  {'cast': ['Sheigo Arai', 'Jack Beresford', 'Ralf Berzsenyi', 'Ferenc Csèk'],
#   'title': 'Olympia Part Two: Festival of Beauty'},
#  {'cast': ['Walter Huston', 'James Stewart', 'Beulah Bondi', 'Guy Kibbee'],
#   'title': 'Of Human Hearts'},
#  {'cast': ['Jean Gabin', 'Michel Simon', 'Michèle Morgan', 'Pierre Brasseur'],
#   'title': 'Port of Shadows'},
#  {'cast': ['Danielle Darrieux',
#    'Douglas Fairbanks Jr.',
#    'Mischa Auer',
#    'Louis Hayward'],
#   'title': 'The Rage of Paris'},
#  {'cast': ['Jeanette MacDonald', 'Nelson Eddy', 'Frank Morgan', 'Ray Bolger'],
#   'title': 'Sweethearts'},
#  {'cast': ['Clark Gable', 'Myrna Loy', 'Spencer Tracy', 'Lionel Barrymore'],
#   'title': 'Test Pilot'},
#  {'cast': ['Robert Taylor',
#    'Margaret Sullavan',
#    'Franchot Tone',
#    'Robert Young'],
#   'title': 'Three Comrades'},
#  {'cast': ['Joseph Cotten',
#    'Virginia Nicolson',
#    'Edgar Barrier',
#    'Arlene Francis'],
#   'title': 'Too Much Johnson'},
#  {'cast': ['Charles Laughton',
#    'Elsa Lanchester',
#    'Robert Newton',
#    'Tyrone Guthrie'],
#   'title': 'The Beachcomber'},
#  {'cast': ['Igor Ilyinsky',
#    'Vladimir Volodin',
#    'Pavel Olenev',
#    'Sergei Antimonov'],
#   'title': 'Volga - Volga'},
#  {'cast': ['Claude Rains', 'Fay Bainter', 'Jackie Cooper', 'Bonita Granville'],
#   'title': 'White Banners'},
#  {'cast': ['Jean Arthur',
#    'Lionel Barrymore',
#    'James Stewart',
#    'Edward Arnold'],
#   'title': "You Can't Take It With You"},
#  {'cast': ['Sylvia Sidney',
#    'George Raft',
#    'Robert Cummings',
#    'Barton MacLane'],
#   'title': 'You and Me'},
#  {'cast': ['Ginger Rogers', 'James Stewart', 'James Ellison', 'Beulah Bondi'],
#   'title': 'Vivacious Lady'},
#  {'cast': ['Edward G. Robinson',
#    'Francis Lederer',
#    'George Sanders',
#    'Paul Lukas'],
#   'title': 'Confessions of a Nazi Spy'},
#  {'cast': ['Bette Davis',
#    'George Brent',
#    'Humphrey Bogart',
#    'Geraldine Fitzgerald'],
#   'title': 'Dark Victory'},
#  {'cast': ['Marlene Dietrich',
#    'James Stewart',
#    'Mischa Auer',
#    'Charles Winninger'],
#   'title': 'Destry Rides Again'},
#  {'cast': ['Victor Francen',
#    'Michel Simon',
#    'Louis Jouvet',
#    'Madeleine Ozeray'],
#   'title': 'La fin du jour'},
#  {'cast': ['John Clements',
#    'Ralph Richardson',
#    'C. Aubrey Smith',
#    'June Duprez'],
#   'title': 'The Four Feathers'},
#  {'cast': ['Thomas Mitchell',
#    "Barbara O'Neil",
#    'Vivien Leigh',
#    'Evelyn Keyes'],
#   'title': 'Gone with the Wind'},
#  {'cast': ['Cary Grant',
#    'Victor McLaglen',
#    'Douglas Fairbanks Jr.',
#    'Sam Jaffe'],
#   'title': 'Gunga Din'},
#  {'cast': ['Greta Garbo', 'Melvyn Douglas', 'Ina Claire', 'Bela Lugosi'],
#   'title': 'Ninotchka'},
#  {'cast': ['Burgess Meredith',
#    'Betty Field',
#    'Lon Chaney Jr.',
#    'Charles Bickford'],
#   'title': 'Of Mice and Men'},
#  {'cast': ['Myrna Loy', 'Tyrone Power', 'George Brent', 'Brenda Joyce'],
#   'title': 'The Rains Came'},
#  {'cast': ['Nora Gregor', 'Paulette Dubost', 'Mila Parèly', 'Odette Talazac'],
#   'title': 'The Rules of the Game'},
#  {'cast': ['Michael Redgrave',
#    'Margaret Lockwood',
#    'Emlyn Williams',
#    'Nancy Price'],
#   'title': 'The Stars Look Down'},
#  {'cast': ['Conrad Veidt',
#    'Sebastian Shaw',
#    'Valerie Hobson',
#    'Marius Goring'],
#   'title': 'The Spy in Black'},
#  {'cast': ['Fred Astaire',
#    'Ginger Rogers',
#    'Edna May Oliver',
#    'Walter Brennan'],
#   'title': 'The Story of Vernon and Irene Castle'},
#  {'cast': ['Maurice Schwartz',
#    'Miriam Riselle',
#    'Rebecca Weintraub',
#    'Paula Lubelski'],
#   'title': 'Tevya'},
#  {'cast': ['Marina Ladynina',
#    'Nikolay Kryuchkov',
#    'Boris Andreyev',
#    'Stepan Kayukov'],
#   'title': 'Traktoristy'},
#  {'cast': ['Aleksei Lyarsky',
#    'Irina Zarubina',
#    'Varvara Massalitinova',
#    'Ye. Lilina'],
#   'title': 'On His Own'},
#  {'title': 'The Wizard of Oz',
#   'cast': ['Judy Garland', 'Frank Morgan', 'Ray Bolger', 'Bert Lahr']},
#  {'cast': ['Merle Oberon', 'Laurence Olivier', 'David Niven', 'Flora Robson'],
#   'title': 'Wuthering Heights'},
#  {'cast': ['Shètarè Hanayagi',
#    'Kèkichi Takada',
#    'Gonjurè Kawarazaki',
#    'Kakuko Mori'],
#   'title': 'Zangiku monogatari'},
#  {'cast': ['Henry Fonda', 'Alice Brady', 'Marjorie Weaver', 'Arleen Whelan'],
#   'title': 'Young Mr. Lincoln'},
#  {'cast': ['Fosco Giachetti', 'Mireille Balin', 'Marèa Denis', 'Rafael Calvo'],
#   'title': 'The Siege of the Alcazar'},
#  {'cast': ['Claudette Colbert',
#    'Ray Milland',
#    "Dennis O'Keefe",
#    'Walter Abel'],
#   'title': 'Arise, My Love'},
#  {'cast': ['W.C. Fields', 'Cora Witherspoon', 'Una Merkel', 'Evelyn Del Rio'],
#   'title': 'The Bank Dick'},
#  {'cast': ['Billy Lee', 'Cordell Hickman', 'Richard Lane', 'Lester Matthews'],
#   'title': 'The Biscuit Eater'},
#  {'cast': ['Boris Karloff', 'Bela Lugosi', 'Stanley Ridges', 'Anne Nagel'],
#   'title': 'Black Friday'},
#  {'cast': ["Maureen O'Hara",
#    'Louis Hayward',
#    'Lucille Ball',
#    'Virginia Field'],
#   'title': 'Dance, Girl, Dance'},
#  {'title': 'Dots'},
#  {'cast': ['Don Ameche',
#    'Betty Grable',
#    'Carmen Miranda',
#    'Charlotte Greenwood'],
#   'title': 'Down Argentine Way'},
#  {'cast': ['Leopold Stokowski', 'Deems Taylor'], 'title': 'Fantasia'},
#  {'cast': ['Charles Chaplin',
#    'Jack Oakie',
#    'Reginald Gardiner',
#    'Henry Daniell'],
#   'title': 'The Great Dictator'},
#  {'cast': ['Cary Grant', 'Rosalind Russell', 'Ralph Bellamy', 'Gene Lockhart'],
#   'title': 'His Girl Friday'},
#  {'cast': ['Ferdinand Marian',
#    'Kristina Sèderbaum',
#    'Heinrich George',
#    'Werner Krauss'],
#   'title': 'Jud Sèè'},
#  {'cast': ['Ginger Rogers',
#    'Dennis Morgan',
#    'James Craig',
#    'Eduardo Ciannelli'],
#   'title': 'Kitty Foyle'},
#  {'cast': ["Pat O'Brien", 'Gale Page', 'Ronald Reagan', 'Donald Crisp'],
#   'title': 'Knute Rockne All American'},
#  {'cast': ['Bette Davis',
#    'Herbert Marshall',
#    'James Stephenson',
#    'Frieda Inescort'],
#   'title': 'The Letter'},
#  {'cast': ['John Wayne', 'Thomas Mitchell', 'Ian Hunter', 'Barry Fitzgerald'],
#   'title': 'The Long Voyage Home'},
#  {'cast': ['Tyrone Power',
#    'Linda Darnell',
#    'Basil Rathbone',
#    'Gale Sondergaard'],
#   'title': 'The Mark of Zorro'},
#  {'cast': ['Gary Cooper',
#    'Madeleine Carroll',
#    'Paulette Goddard',
#    'Preston Foster'],
#   'title': 'North West Mounted Police'},
#  {'cast': ['Mel Blanc', 'Don Brodie', 'Walter Catlett', 'Marion Darlington'],
#   'title': 'Pinocchio'},
#  {'cast': ['Margaret Sullavan',
#    'James Stewart',
#    'Frank Morgan',
#    'Joseph Schildkraut'],
#   'title': 'The Shop Around the Corner'},
#  {'cast': ['Mickey Rooney',
#    'Judy Garland',
#    'Paul Whiteman and Orchestra',
#    'June Preisser'],
#   'title': 'Strike Up the Band'},
#  {'cast': ['Gary Cooper', 'Walter Brennan', 'Doris Davenport', 'Fred Stone'],
#   'title': 'The Westerner'},
#  {'cast': ['Tyrone Power', 'Linda Darnell', 'Rita Hayworth', 'Alla Nazimova'],
#   'title': 'Blood and Sand'},
#  {'title': 'The Blood of Jesus',
#   'cast': ['Cathryn Caviness',
#    'Spencer Williams',
#    'Juanita Riley',
#    'Reather Hardeman']},
#  {'cast': ['Greer Garson', 'Walter Pidgeon', 'Felix Bressart', 'Marsha Hunt'],
#   'title': 'Blossoms in the Dust'},
#  {'cast': ['Joseph Cotten',
#    'Dorothy Comingore',
#    'Agnes Moorehead',
#    'Ruth Warrick'],
#   'title': 'Citizen Kane'},
#  {'cast': ['Edward Arnold', 'Walter Huston', 'Jane Darwell', 'Simone Simon'],
#   'title': 'The Devil and Daniel Webster'},
#  {'cast': ['James Baskett', 'Herman Bing', 'Billy Bletcher', 'Edward Brophy'],
#   'title': 'Dumbo'},
#  {'cast': ['Raimu', 'Fernandel', 'Josette Day', 'Line Noro'],
#   'title': "The Well-Digger's Daughter"},
#  {'cast': ['Robert Montgomery',
#    'Evelyn Keyes',
#    'Claude Rains',
#    'Rita Johnson'],
#   'title': 'Here Comes Mr. Jordan'},
#  {'cast': ['Ida Lupino', 'Humphrey Bogart', 'Alan Curtis', 'Arthur Kennedy'],
#   'title': 'High Sierra'},
#  {'cast': ['Walter Pidgeon', "Maureen O'Hara", 'Anna Lee', 'Donald Crisp'],
#   'title': 'How Green Was My Valley'},
#  {'cast': ['Robert J. Flaherty'], 'title': 'The Land'},
#  {'cast': ['Bette Davis',
#    'Herbert Marshall',
#    'Teresa Wright',
#    'Richard Carlson'],
#   'title': 'The Little Foxes'},
#  {'cast': ['Deborah Kerr', 'Clifford Evans', 'George Carney', 'Mary Merrall'],
#   'title': 'Love on the Dole'},
#  {'cast': ['Wendy Hiller', 'Rex Harrison', 'Robert Morley', 'Robert Newton'],
#   'title': 'Major Barbara'},
#  {'cast': ['Bette Davis', 'Ann Sheridan', 'Monty Woolley', 'Richard Travis'],
#   'title': 'The Man Who Came to Dinner'},
#  {'cast': ['Augusto Basso', 'Elena'], 'title': 'The White Ship'},
#  {'cast': ['Allan Jeayes',
#    'Peter Gawthorne',
#    'Ernest Butcher',
#    'Ben Williams'],
#   'title': "'Pimpernel' Smith"},
#  {'cast': ['Bing Crosby', 'Bob Hope', 'Dorothy Lamour', 'Una Merkel'],
#   'title': 'Road to Zanzibar'},
#  {'cast': ['Edward G. Robinson',
#    'Ida Lupino',
#    'John Garfield',
#    'Alexander Knox'],
#   'title': 'The Sea Wolf'},
#  {'cast': ['Gary Cooper', 'Walter Brennan', 'Joan Leslie', 'George Tobias'],
#   'title': 'Sergeant York'},
#  {'cast': ['Marina Ladynina',
#    'Vladimir Zeldin',
#    'Nikolay Kryuchkov',
#    'N. Kitayev'],
#   'title': 'They Met in Moscow'},
#  {'cast': ['Vivien Leigh', 'Laurence Olivier', 'Alan Mowbray', 'Sara Allgood'],
#   'title': 'That Hamilton Woman'},
#  {'cast': ['Ginger Rogers',
#    'George Murphy',
#    'Alan Marshal',
#    'Burgess Meredith'],
#   'title': 'Tom Dick and Harry'},
#  {'cast': ['Mieko Takamine', 'Shin Saburi', 'Hideo Fujino', 'Ayako Katsuragi'],
#   'title': 'The Brothers and Sisters of the Toda Family'},
#  {'cast': ['Greta Garbo',
#    'Melvyn Douglas',
#    'Constance Bennett',
#    'Roland Young'],
#   'title': 'Two-Faced Woman'},
#  {'cast': ['Lon Chaney Jr.',
#    'Claude Rains',
#    'Warren William',
#    'Ralph Bellamy'],
#   'title': 'The Wolf Man'},
#  {'cast': ['Humphrey Bogart',
#    'Mary Astor',
#    'Sydney Greenstreet',
#    'Charles Halton'],
#   'title': 'Across the Pacific'},
#  {'cast': ['Hardie Albright',
#    'Stan Alexander',
#    'Bobette Audrey',
#    'Peter Behn'],
#   'title': 'Bambi'},
#  {'cast': ['Tyrone Power',
#    "Maureen O'Hara",
#    'Laird Cregar',
#    'Thomas Mitchell'],
#   'title': 'The Black Swan'},
#  {'cast': ['Humphrey Bogart',
#    'Ingrid Bergman',
#    'Paul Henreid',
#    'Claude Rains'],
#   'title': 'Casablanca'},
#  {'cast': ['Simone Simon', 'Kent Smith', 'Tom Conway', 'Jane Randolph'],
#   'title': 'Cat People'},
#  {'title': 'People on the Alps',
#   'cast': ['Alice Szellay',
#    'Jènos Gèrbe',
#    'Pèterke Ferency',
#    'Jèzsef Bihari']},
#  {'title': 'Der groèe Kènig',
#   'cast': ['Otto Gebèhr',
#    'Kristina Sèderbaum',
#    'Gustav Frèhlich',
#    'Hans Nielsen']},
#  {'cast': ['Ida Lupino', 'Dennis Morgan', 'Joan Leslie', 'Jack Carson'],
#   'title': 'The Hard Way'},
#  {'cast': ['Bing Crosby',
#    'Fred Astaire',
#    'Marjorie Reynolds',
#    'Virginia Dale'],
#   'title': 'Holiday Inn'},
#  {'cast': ['Sabu', 'Joseph Calleia', 'John Qualen', 'Frank Puglia'],
#   'title': 'Jungle Book'},
#  {'cast': ['Robert Young', 'Laraine Day', 'Fay Bainter', 'Nigel Bruce'],
#   'title': 'Journey for Margaret'},
#  {'cast': ['Joseph Cotten', 'Dolores Costello', 'Anne Baxter', 'Tim Holt'],
#   'title': 'The Magnificent Ambersons'},
#  {'cast': ['Henry Fonda', 'Olivia de Havilland', 'Joan Leslie', 'Jack Carson'],
#   'title': 'The Male Animal'},
#  {'cast': ['Ginger Rogers', 'Ray Milland', 'Rita Johnson', 'Robert Benchley'],
#   'title': 'The Major and the Minor'},
#  {'cast': ['George Sanders', 'Herbert Marshall', 'Doris Dudley', 'Eric Blore'],
#   'title': 'The Moon and Sixpence'},
#  {'cast': ['Greer Garson',
#    'Walter Pidgeon',
#    'Teresa Wright',
#    'Dame May Whitty'],
#   'title': 'Mrs. Miniver'},
#  {'cast': ['Rita Hayworth', 'Victor Mature', 'John Sutton', 'Carole Landis'],
#   'title': 'My Gal Sal'},
#  {'cast': ['Clara Calamai',
#    'Massimo Girotti',
#    'Dhia Cristiani',
#    'Elio Marcuzzo'],
#   'title': 'Ossessione'},
#  {'cast': ['Godfrey Tearle', 'Eric Portman', 'Hugh Williams', 'Bernard Miles'],
#   'title': 'One of Our Aircraft Is Missing'},
#  {'cast': ['Monty Woolley', 'Roddy McDowall', 'Anne Baxter', 'Otto Preminger'],
#   'title': 'The Pied Piper'},
#  {'cast': ['Victor Bulwer-Lytton',
#    'Kai-Shek Chiang',
#    'Walter Darrè',
#    'Otto Dietrich'],
#   'title': 'Prelude to War'},
#  {'cast': ['Gary Cooper', 'Teresa Wright', 'Babe Ruth', 'Walter Brennan'],
#   'title': 'The Pride of the Yankees'},
#  {'cast': ['Ronald Colman', 'Greer Garson', 'Philip Dorn', 'Susan Peters'],
#   'title': 'Random Harvest'},
#  {'cast': ['Priscilla Lane', 'Robert Cummings', 'Otto Kruger', 'Alan Baxter'],
#   'title': 'Saboteur'},
#  {'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#   'title': 'Kate & Leopold'},
#  {'cast': ['Tyrone Power',
#    'Joan Fontaine',
#    'Thomas Mitchell',
#    'Henry Stephenson'],
#   'title': 'This Above All'},
#  {'cast': ['Carole Lombard', 'Jack Benny', 'Robert Stack', 'Felix Bressart'],
#   'title': 'To Be or Not to Be'},
#  {'cast': ['Brian Donlevy',
#    'Macdonald Carey',
#    'Robert Preston',
#    'William Bendix'],
#   'title': 'Wake Island'},
#  {'cast': ['Spencer Tracy',
#    'Katharine Hepburn',
#    'Fay Bainter',
#    'Reginald Owen'],
#   'title': 'Woman of the Year'},
#  {'cast': ['James Cagney', 'Joan Leslie', 'Walter Huston', 'Richard Whorf'],
#   'title': 'Yankee Doodle Dandy'},
#  {'cast': ['John Ridgely', 'Gig Young', 'Arthur Kennedy', 'Charles Drake'],
#   'title': 'Air Force'},
#  {'cast': ['Robert Taylor', 'George Murphy', 'Thomas Mitchell', 'Lloyd Nolan'],
#   'title': 'Bataan'},
#  {'cast': ['Ethel Waters',
#    "Eddie 'Rochester' Anderson",
#    'Lena Horne',
#    'Louis Armstrong'],
#   'title': 'Cabin in the Sky'},
#  {'cast': ['Harold Alexander',
#    'Winston Churchill',
#    'Adolf Hitler',
#    'Bernard L. Montgomery'],
#   'title': 'Desert Victory'},
#  {'cast': ['Alice Faye', 'Carmen Miranda', 'Phil Baker', 'Benny Goodman'],
#   'title': "The Gang's All Here"},
#  {'cast': ['Richard Dix', 'Russell Wade', 'Edith Barrett', 'Ben Bard'],
#   'title': 'The Ghost Ship'},
#  {'cast': ['Brian Donlevy', 'Walter Brennan', 'Anna Lee', 'Gene Lockhart'],
#   'title': 'Hangmen Also Die!'},
#  {'cast': ['Alice Faye', 'John Payne', 'Jack Oakie', 'Lynn Bari'],
#   'title': 'Hello Frisco, Hello'},
#  {'cast': ['James Ellison', 'Frances Dee', 'Tom Conway', 'Edith Barrett'],
#   'title': 'I Walked with a Zombie'},
#  {'cast': ['Monty Woolley', 'Gracie Fields', 'Laird Cregar', "Una O'Connor"],
#   'title': 'Holy Matrimony'},
#  {'cast': ['Roddy McDowall',
#    'Donald Crisp',
#    'Dame May Whitty',
#    'Edmund Gwenn'],
#   'title': 'Lassie Come Home'},
#  {'cast': ['James McKechnie',
#    'Neville Mapp',
#    'Vincent Holman',
#    'Roger Livesey'],
#   'title': 'The Life and Death of Colonel Blimp'},
#  {'cast': ["Dennis O'Keefe", 'Margo', 'Jean Brooks', 'Isabel Jewell'],
#   'title': 'The Leopard Man'},
#  {'cast': ['Maya Deren', 'Alexander Hammid'],
#   'title': 'Meshes of the Afternoon'},
#  {'cast': ['Stanley Wray',
#    'Robert Morgan',
#    'James A. Verinis',
#    'Robert J. Hanson'],
#   'title': 'The Memphis Belle: A Story of a Flying Fortress'},
#  {'cast': ['Jean Arthur', 'Joel McCrea', 'Charles Coburn', 'Richard Gaines'],
#   'title': 'The More the Merrier'},
#  {'cast': ['Nelson Eddy', 'Susanna Foster', 'Claude Rains', 'Edgar Barrier'],
#   'title': 'Phantom of the Opera'},
#  {'cast': ['John Huston', 'Walter Huston', 'Milton Ashkin', 'Lyle A. Bean'],
#   'title': 'Report from the Aleutians'},
#  {'cast': ['Fred Shields', 'Josè Oliveira'], 'title': 'Saludos Amigos'},
#  {'cast': ['Tom Conway', 'Jean Brooks', 'Isabel Jewell', 'Kim Hunter'],
#   'title': 'The Seventh Victim'},
#  {'cast': ['Teresa Wright',
#    'Joseph Cotten',
#    'Macdonald Carey',
#    'Henry Travers'],
#   'title': 'Shadow of a Doubt'},
#  {'cast': ['Claudette Colbert',
#    'Paulette Goddard',
#    'Veronica Lake',
#    'George Reeves'],
#   'title': 'So Proudly We Hail!'},
#  {'cast': ['Jennifer Jones',
#    'Charles Bickford',
#    'Vincent Price',
#    'Lee J. Cobb'],
#   'title': 'The Song of Bernadette'},
#  {'cast': ['Lena Horne',
#    'Bill Robinson',
#    'Cab Calloway and His Cotton Club Orchestra',
#    'Katherine Dunham and Her Troupe'],
#   'title': 'Stormy Weather'},
#  {'cast': ['George Murphy', 'Joan Leslie', 'George Tobias', 'Alan Hale'],
#   'title': 'This Is the Army'},
#  {'cast': ['Alexander de Seversky', 'Art Baker', 'Billy Mitchell'],
#   'title': 'Victory Through Air Power'},
#  {'cast': ['Bette Davis',
#    'Paul Lukas',
#    'Geraldine Fitzgerald',
#    'Lucile Watson'],
#   'title': 'Watch on the Rhine'},
#  {'cast': ['Ion Antonescu',
#    'Nikolai Cherkasov',
#    'Anthony Eden',
#    'Hermann Gèring'],
#   'title': 'The Battle of Russia'},
#  {'cast': ['Simone Simon', 'Kent Smith', 'Jane Randolph', 'Ann Carter'],
#   'title': 'The Curse of the Cat People'},
#  {'cast': ['Fred MacMurray',
#    'Barbara Stanwyck',
#    'Edward G. Robinson',
#    'Porter Hall'],
#   'title': 'Double Indemnity'},
#  {'cast': ['Charles Boyer', 'Joseph J. Clark', 'Dixie Kiefer', 'G.E. Lowe'],
#   'title': 'The Fighting Lady'},
#  {'cast': ['Myrna Loy', 'Fredric March', 'Dana Andrews', 'Teresa Wright'],
#   'title': 'The Best Years of Our Lives'},
#  {'cast': ['Charles Boyer',
#    'Ingrid Bergman',
#    'Joseph Cotten',
#    'Dame May Whitty'],
#   'title': 'Gaslight'},
#  {'cast': ['Bing Crosby', 'Barry Fitzgerald', 'Frank McHugh', 'James Brown'],
#   'title': 'Going My Way'},
#  {'cast': ['Eddie Bracken',
#    'Ella Raines',
#    'Raymond Walburn',
#    'William Demarest'],
#   'title': 'Hail the Conquering Hero'},
#  {'cast': ['Stig Jèrrel',
#    'Alf Kjellin',
#    'Mai Zetterling',
#    'Olof Winnerstrand'],
#   'title': 'Torment'},
#  {'cast': ['Gene Tierney', 'Dana Andrews', 'Clifton Webb', 'Vincent Price'],
#   'title': 'Laura'},
#  {'cast': ['Tallulah Bankhead',
#    'William Bendix',
#    'Walter Slezak',
#    'Mary Anderson'],
#   'title': 'Lifeboat'},
#  {'cast': ['Judy Garland', "Margaret O'Brien", 'Mary Astor', 'Lucille Bremer'],
#   'title': 'Meet Me in St. Louis'},
#  {'cast': ['Dolores del Rio',
#    'Pedro Armendèriz',
# ...
#   'title': 'The Miracle of Marcelino'},
#  {'cast': ['Gèrard Philipe',
#    'Valerie Hobson',
#    'Joan Greenwood',
#    'Margaret Johnston'],
#   'title': 'Lovers, Happy Lovers!'},
#  {'cast': ['Jane Wyman', 'Rock Hudson', 'Agnes Moorehead', 'Otto Kruger'],
#   'title': 'Magnificent Obsession'},
#  {'cast': ['Fernandel', 'Franèoise Arnoul', 'Andrex', 'Michel Ardan'],
#   'title': 'The Sheep Has Five Legs'},
#  {'cast': ['Mieko Takamine', 'Hideko Takamine', 'Keiko Kishi', 'Yoshiko Kuga'],
#   'title': 'The Garden of Women'},
#  {'cast': ['Silvana Mangano',
#    'Sophia Loren',
#    'Eduardo De Filippo',
#    'Paolo Stoppa'],
#   'title': 'The Gold of Naples'},
#  {'title': 'Fear',
#   'cast': ['Ingrid Bergman',
#    'Mathias Wieman',
#    'Renate Mannhardt',
#    'Kurt Kreuger']},
#  {'cast': ['Vittorio De Sica',
#    'Gina Lollobrigida',
#    'Marisa Merlini',
#    'Roberto Risso'],
#   'title': 'Frisky'},
#  {'cast': ['Judy Holliday', 'Jack Lemmon', 'Jack Carson', 'Kim Novak'],
#   'title': 'Phffft'},
#  {'title': 'Rear Window',
#   'cast': ['James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter']},
#  {'cast': ['Gèrard Philipe',
#    'Danielle Darrieux',
#    'Antonella Lualdi',
#    'Jean Mercure'],
#   'title': 'Rouge et noir'},
#  {'cast': ['Will Geer', 'David Wolfe', 'Mervin Williams', 'David Sarvis'],
#   'title': 'Salt of the Earth'},
#  {'cast': ['Columba Domènguez',
#    'Miguel Torruco',
#    'Joaquèn Cordero',
#    'Jaime Fernèndez'],
#   'title': 'The River and Death'},
#  {'cast': ['Howard Keel', 'Jeff Richards', 'Russ Tamblyn', 'Tommy Rall'],
#   'title': 'Seven Brides for Seven Brothers'},
#  {'cast': ['Gunvor Sandkvist',
#    'Matti Oravisto',
#    'Toivo Mèkelè',
#    'Paavo Hukkinen'],
#   'title': 'Scarlet Week'},
#  {'cast': ['Faten Hamama', 'Omar Sharif', 'Zaki Rostom', 'Farid Shawqi'],
#   'title': 'Siraa Fil-Wadi'},
#  {'cast': ['Judy Garland', 'James Mason', 'Jack Carson', 'Charles Bickford'],
#   'title': 'A Star Is Born'},
#  {'cast': ['Dick Powell', 'Debbie Reynolds', 'Anne Francis', 'Glenda Farrell'],
#   'title': 'Susan Slept Here'},
#  {'cast': ['James Whitmore', 'Edmund Gwenn', 'Joan Weldon', 'James Arness'],
#   'title': 'Them!'},
#  {'cast': ['Ethel Merman', "Donald O'Connor", 'Marilyn Monroe', 'Dan Dailey'],
#   'title': "There's No Business Like Show Business"},
#  {'cast': ['Jeff Morrow', 'Faith Domergue', 'Rex Reason', 'Lance Fuller'],
#   'title': 'This Island Earth'},
#  {'cast': ['Vasiliy Merkurev',
#    'Boris Chirkov',
#    'Aleksandr Borisov',
#    'Aleksei Gribov'],
#   'title': 'True Friends'},
#  {'cast': ['Winston Hibler'], 'title': 'The Vanishing Prairie'},
#  {'cast': ['Setsuko Hara', 'Sè Yamamura', 'Ken Uehara', 'Yèko Sugi'],
#   'title': 'Sound of the Mountain'},
#  {'cast': ['Eleonora Rossi Drago',
#    'Gabriele Ferzetti',
#    'Franco Fabrizi',
#    'Valentina Cortese'],
#   'title': 'Le amiche'},
#  {'cast': ['Spencer Tracy', 'Robert Ryan', 'Anne Francis', 'Dean Jagger'],
#   'title': 'Bad Day at Black Rock'},
#  {'cast': ['Glenn Ford', 'Anne Francis', 'Louis Calhern', 'Margaret Hayes'],
#   'title': 'Blackboard Jungle'},
#  {'cast': ['Jack Palance', 'Ida Lupino', 'Wendell Corey', 'Jean Hagen'],
#   'title': 'The Big Knife'},
#  {'title': 'Blinkity Blank'},
#  {'cast': ['Broderick Crawford',
#    'Giulietta Masina',
#    'Richard Basehart',
#    'Franco Fabrizi'],
#   'title': 'Il Bidone'},
#  {'cast': ['Gary Cooper', 'Charles Bickford', 'Ralph Bellamy', 'Rod Steiger'],
#   'title': 'The Court-Martial of Billy Mitchell'},
#  {'cast': ['Fred Astaire', 'Leslie Caron', 'Terry Moore', 'Thelma Ritter'],
#   'title': 'Daddy Long Legs'},
#  {'cast': ['Humphrey Bogart',
#    'Fredric March',
#    'Arthur Kennedy',
#    'Martha Scott'],
#   'title': 'The Desperate Hours'},
#  {'cast': ['Dirk Bogarde',
#    'Brenda de Banzie',
#    'Brigitte Bardot',
#    'James Robertson Justice'],
#   'title': 'Doctor at Sea'},
#  {'title': 'Devdas',
#   'cast': ['Dilip Kumar', 'Vyjayanthimala', 'Motilal', 'Suchitra Sen']},
#  {'cast': ['Deborah Kerr', 'Van Johnson', 'John Mills', 'Peter Cushing'],
#   'title': 'The End of the Affair'},
#  {'cast': ['Julie Harris', 'James Dean', 'Raymond Massey', 'Burl Ives'],
#   'title': 'East of Eden'},
#  {'cast': ['Miroslava', 'Ernesto Alonso', 'Rita Macedo', 'Ariadna Welter'],
#   'title': 'The Criminal Life of Archibaldo de la Cruz'},
#  {'cast': ['Stewart Granger', 'Jean Simmons', 'Bill Travers', 'Belinda Lee'],
#   'title': 'Footsteps in the Fog'},
#  {'cast': ['Michèle Morgan', 'Gèrard Philipe', 'Jean Desailly', 'Pierre Dux'],
#   'title': 'The Grand Maneuver'},
#  {'cast': ['Michèle Morgan', 'Gèrard Philipe', 'Jean Desailly', 'Pierre Dux'],
#   'title': 'The Grand Maneuver'},
#  {'cast': ['Marlon Brando', 'Jean Simmons', 'Frank Sinatra', 'Vivian Blaine'],
#   'title': 'Guys and Dolls'},
#  {'cast': ['Toshirè Mifune',
#    'Takashi Shimura',
#    'Minoru Chiaki',
#    'Eiko Miyoshi'],
#   'title': 'I Live in Fear: Record of a Living Being'},
#  {'cast': ['Susan Hayward', 'Richard Conte', 'Eddie Albert', 'Jo Van Fleet'],
#   'title': "I'll Cry Tomorrow"},
#  {'cast': ['Antonella Lualdi',
#    'Franco Interlenghi',
#    'Sergio Raimondi',
#    'Valeria Moriconi'],
#   'title': 'Wild Love'},
#  {'cast': ['Gene Kelly', 'Dan Dailey', 'Cyd Charisse', 'Dolores Gray'],
#   'title': "It's Always Fair Weather"},
#  {'cast': ['Glenn Ford', 'Eleanor Parker', 'Roger Moore', 'Cecil Kellaway'],
#   'title': 'Interrupted Melody'},
#  {'cast': ['Rosalie Kunoth-Monks',
#    'Robert Tudawali',
#    'Betty Suttor',
#    'Paul Reynall'],
#   'title': 'Jedda the Uncivilized'},
#  {'cast': ['Celia Johnson', 'Diana Dors', 'David Kossoff', 'Joe Robinson'],
#   'title': 'A Kid for Two Farthings'},
#  {'cast': ['Ralph Meeker', 'Albert Dekker', 'Paul Stewart', 'Juano Hernandez'],
#   'title': 'Kiss Me Deadly'},
#  {'cast': ['Burt Lancaster', 'Dianne Foster', 'Diana Lynn', 'John McIntire'],
#   'title': 'The Kentuckian'},
#  {'cast': ['Peggy Lee', 'Larry Roberts', 'Bill Baucom', 'Verna Felton'],
#   'title': 'Lady and the Tramp'},
#  {'cast': ['Alec Guinness', 'Cecil Parker', 'Herbert Lom', 'Peter Sellers'],
#   'title': 'The Ladykillers'},
#  {'cast': ['Tyrone Power', "Maureen O'Hara", 'Robert Francis', 'Donald Crisp'],
#   'title': 'The Long Gray Line'},
#  {'cast': ['Richard Todd', 'Jean Peters', 'Marjorie Rambeau', 'Jill Esmond'],
#   'title': 'A Man Called Peter'},
#  {'cast': ['Doris Day', 'James Cagney', 'Cameron Mitchell', 'Robert Keith'],
#   'title': 'Love Me or Leave Me'},
#  {'cast': ['Frank Sinatra', 'Eleanor Parker', 'Kim Novak', 'Arnold Stang'],
#   'title': 'The Man with the Golden Arm'},
#  {'cast': ['Esther Minciotti',
#    'Augusta Ciolli',
#    'Joe Mantell',
#    'Karen Steele'],
#   'title': 'Marty'},
#  {'title': "La 'Moara cu noroc'",
#   'cast': ['Constantin Codrescu', 'Geo Barton', 'Ioana Bulca', 'Colea Rautu']},
#  {'cast': ['Gordon MacRae',
#    'Gloria Grahame',
#    'Gene Nelson',
#    'Charlotte Greenwood'],
#   'title': 'Oklahoma!'},
#  {'title': 'The Night of the Hunter',
#   'cast': ['Robert Mitchum',
#    'Shelley Winters',
#    'Lillian Gish',
#    'James Gleason']},
#  {'cast': ['Noriko Arita', 'Chishè Ryè', 'Haruko Sugimura', 'Takahiro Tamura'],
#   'title': 'She Was Like a Wild Chrysanthemum'},
#  {'cast': ['Olivia de Havilland',
#    'Robert Mitchum',
#    'Frank Sinatra',
#    'Gloria Grahame'],
#   'title': 'Not as a Stranger'},
#  {'cast': ['Bill Roberts'], 'title': 'One Froggy Evening'},
#  {'cast': ['William Holden', 'Kim Novak', 'Betty Field', 'Susan Strasberg'],
#   'title': 'Picnic'},
#  {'cast': ['Jack Webb', 'Janet Leigh', "Edmond O'Brien", 'Peggy Lee'],
#   'title': "Pete Kelly's Blues"},
#  {'cast': ['Alec Guinness',
#    'Jack Hawkins',
#    'Wilfrid Lawson',
#    'Kenneth Griffith'],
#   'title': 'The Prisoner'},
#  {'cast': ['James Dean', 'Natalie Wood', 'Sal Mineo', 'Jim Backus'],
#   'title': 'Rebel Without a Cause'},
#  {'cast': ['Nargis', 'Nadira', 'Raj Kapoor', 'Nemo'], 'title': 'Shree 420'},
#  {'cast': ['Marilyn Monroe', 'Tom Ewell', 'Evelyn Keyes', 'Sonny Tufts'],
#   'title': 'The Seven Year Itch'},
#  {'cast': ['Romy Schneider', 'Karlheinz Bèhm', 'Magda Schneider', 'Uta Franz'],
#   'title': 'Sissi'},
#  {'cast': ['Ulla Jacobsson',
#    'Eva Dahlbeck',
#    'Harriet Andersson',
#    'Margit Carlqvist'],
#   'title': 'Smiles of a Summer Night'},
#  {'cast': ['Melina Mercouri',
#    'Giorgos Foundas',
#    'Alekos Alexandrakis',
#    'Hristina Kalogerikou'],
#   'title': 'Stella'},
#  {'cast': ['Narutoshi Hayashi',
#    'Raizè Ichikawa',
#    'Tatsuya Ishiguro',
#    'Michiyo Kogure'],
#   'title': 'Taira Clan Saga'},
#  {'cast': ['James Stewart', 'June Allyson', 'Frank Lovejoy', 'Barry Sullivan'],
#   'title': 'Strategic Air Command'},
#  {'cast': ['Frank Sinatra', 'Debbie Reynolds', 'David Wayne', 'Celeste Holm'],
#   'title': 'The Tender Trap'},
#  {'cast': ['Cary Grant',
#    'Grace Kelly',
#    'Jessie Royce Landis',
#    'John Williams'],
#   'title': 'To Catch a Thief'},
#  {'cast': ['Glenn Ford', 'Dorothy McGuire', 'Arthur Kennedy', 'John Hodiak'],
#   'title': 'Trial'},
#  {'cast': ['Kosti Klemelè',
#    'Heikki Savolainen',
#    'Reino Tolvanen',
#    'Veikko Sinisalo'],
#   'title': 'The Unknown Soldier'},
#  {'cast': ['Edmund Gwenn',
#    'John Forsythe',
#    'Mildred Natwick',
#    'Mildred Dunnock'],
#   'title': 'The Trouble with Harry'},
#  {'cast': ['Hideko Takamine',
#    'Masayuki Mori',
#    'Mariko Okada',
#    'Isao Yamagata'],
#   'title': 'Floating Clouds'},
#  {'cast': ['Glenn Ford',
#    'Barbara Stanwyck',
#    'Edward G. Robinson',
#    'Dianne Foster'],
#   'title': 'The Violent Men'},
#  {'cast': ['Machiko Kyè', 'Masayuki Mori', 'Sè Yamamura', 'Eitarè Shindè'],
#   'title': 'Yèkihi'},
#  {'cast': ['Machiko Kyè', 'Ayako Wakao', 'Michiyo Kogure', 'Aiko Mimasu'],
#   'title': 'Street of Shame'},
#  {'cast': ['Jack Palance', 'Eddie Albert', 'Lee Marvin', 'Robert Strauss'],
#   'title': 'Attack'},
#  {'title': 'Aparajito',
#   'cast': ['Kamala Adhikari',
#    'Lalchand Banerjee',
#    'Kali Bannerjee',
#    'Kanu Bannerjee']},
#  {'title': 'Around the World in Eighty Days',
#   'cast': ['David Niven', 'Cantinflas', 'Finlay Currie', 'Robert Morley']},
#  {'cast': ['Pascal Lamorisse',
#    'Georges Sellier',
#    'Vladimir Popov',
#    'Paul Perey'],
#   'title': 'The Red Balloon'},
#  {'cast': ['Nancy Kelly', 'Patty McCormack', 'Henry Jones', 'Eileen Heckart'],
#   'title': 'The Bad Seed'},
#  {'cast': ['Joan Crawford', 'Cliff Robertson', 'Vera Miles', 'Lorne Greene'],
#   'title': 'Autumn Leaves'},
#  {'cast': ['Karl Malden', 'Carroll Baker', 'Eli Wallach', 'Mildred Dunnock'],
#   'title': 'Baby Doll'},
#  {'cast': ['David Kossoff', 'Alfie Bass', 'Alan Tilvern'],
#   'title': 'The Bespoke Overcoat'},
#  {'cast': ['Ava Gardner', 'Stewart Granger', 'Bill Travers', 'Abraham Sofaer'],
#   'title': 'Bhowani Junction'},
#  {'cast': ['Diana Dors', 'Yvonne Mitchell', 'Michael Craig', 'Marie Ney'],
#   'title': 'Blonde Sinner'},
#  {'cast': ['Cantinflas',
#    'Manola Saavedra',
#    'Flor Silvestre',
#    'Paquito Fernèndez'],
#   'title': "Raquel's Shoeshiner"},
#  {'cast': ['Michel Ray',
#    'Rodolfo Hoyos Jr.',
#    'Elsa Cèrdenas',
#    'Carlos Navarro'],
#   'title': 'The Brave One'},
#  {'cast': ['Marilyn Monroe', 'Don Murray', "Arthur O'Connell", 'Betty Field'],
#   'title': 'Bus Stop'},
#  {'cast': ['Edmund Gwenn',
#    'Valentina Cortese',
#    'Juan Calvo',
#    'Franco Fabrizi'],
#   'title': 'The Rocket from Calabuch'},
#  {'cast': ['Betsy Blair', 'Josè Suèrez', 'Yves Massard', 'Luis Peèa'],
#   'title': 'Main Street'},
#  {'cast': ['Gordon MacRae',
#    'Shirley Jones',
#    'Cameron Mitchell',
#    'Barbara Ruick'],
#   'title': 'Carousel'},
#  {'cast': ['Bette Davis',
#    'Ernest Borgnine',
#    'Debbie Reynolds',
#    'Barry Fitzgerald'],
#   'title': 'The Catered Affair'},
#  {'cast': ['Zygmunt Kestowicz',
#    'Adolf Chronicki',
#    'Emil Karewicz',
#    'Ignacy Machowski'],
#   'title': 'Cien'},
#  {'title': 'Come Back, Africa',
#   'cast': ['Zacharia Mgabi', 'Vinah Bendile', 'Miriam Makeba', 'Lewis Nkosi']},
#  {'cast': ['Danny Kaye', 'Glynis Johns', 'Basil Rathbone', 'Angela Lansbury'],
#   'title': 'The Court Jester'},
#  {'cast': ['Leo Gorcey', 'Huntz Hall', 'Mary Castle', 'Don Haggerty'],
#   'title': 'Crashing Las Vegas'},
#  {'cast': ['Elsa Martinelli',
#    'Gabriele Ferzetti',
#    'Walter Chiari',
#    'Liliana Bonfatti'],
#   'title': 'Donatella'},
#  {'cast': ['Antonio Vilar', 'Rubèn Rojo', 'Luis Peèa', 'Mario Berriatèa'],
#   'title': 'Embajadores en el infierno'},
#  {'cast': ['Brigitte Bardot',
#    'Curd Jèrgens',
#    'Jean-Louis Trintignant',
#    'Jane Marken'],
#   'title': '...And God Created Woman'},
#  {'cast': ['Tyrone Power', 'Kim Novak', 'Victoria Shaw', 'James Whitmore'],
#   'title': 'The Eddy Duchin Story'},
#  {'cast': ['Walter Pidgeon',
#    'Anne Francis',
#    'Leslie Nielsen',
#    'Warren Stevens'],
#   'title': 'Forbidden Planet'},
#  {'cast': ['Fess Parker', 'Jeffrey Hunter', 'Jeff York', 'John Lupton'],
#   'title': 'The Great Locomotive Chase'},
#  {'cast': ['Jacqueline Sassard',
#    'Raf Mattioli',
#    'Sylva Koscina',
#    'Raf Vallone'],
#   'title': 'Guendalina'},
#  {'cast': ['Maria Schell',
#    'Franèois Pèrier',
#    'Jany Holt',
#    'Mathilde Casadesus'],
#   'title': 'Gervaise'},
#  {'cast': ['Josè Ferrer', 'Dean Jagger', 'Keenan Wynn', 'Julie London'],
#   'title': 'The Great Man'},
#  {'cast': ['Elizabeth Taylor', 'Rock Hudson', 'James Dean', 'Carroll Baker'],
#   'title': 'Giant'},
#  {'cast': ['Heinz Rèhmann',
#    'Martin Held',
#    'Hannelore Schroth',
#    'Willy A. Kleinau'],
#   'title': 'The Captain from Kèpenick'},
#  {'cast': ['Bing Crosby', 'Grace Kelly', 'Frank Sinatra', 'Celeste Holm'],
#   'title': 'High Society'},
#  {'cast': ['Kevin McCarthy', 'Dana Wynter', 'Larry Gates', 'King Donovan'],
#   'title': 'Invasion of the Body Snatchers'},
#  {'cast': ['Gene Kelly',
#    'Igor Youskevitch',
#    'Claire Sombert',
#    'Tamara Toumanova'],
#   'title': 'Invitation to the Dance'},
#  {'cast': ['Deborah Kerr', 'Yul Brynner', 'Rita Moreno', 'Martin Benson'],
#   'title': 'The King and I'},
#  {'cast': ['Kirk Douglas', 'Anthony Quinn', 'James Donald', 'Pamela Brown'],
#   'title': 'Lust for Life'},
#  {'cast': ['James Stewart', 'Doris Day', 'Brenda de Banzie', 'Bernard Miles'],
#   'title': 'The Man Who Knew Too Much'},
#  {'cast': ['Gregory Peck', 'Jennifer Jones', 'Fredric March', 'Marisa Pavan'],
#   'title': 'The Man in the Gray Flannel Suit'},
#  {'cast': ['Clifton Webb',
#    'Gloria Grahame',
#    'Robert Flemyng',
#    'Josephine Griffin'],
#   'title': 'The Man Who Never Was'},
#  {'cast': ['Dan Dailey', 'Cyd Charisse', 'Agnes Moorehead', 'Lili Darvas'],
#   'title': 'Meet Me in Las Vegas'},
#  {'cast': ['Frèdèric Dumas',
#    'Albert Falco',
#    'Jacques-Yves Cousteau',
#    'Franèois Saout'],
#   'title': 'The Silent World'},
#  {'cast': ['Kinuyo Tanaka', 'Isuzu Yamada', 'Hideko Takamine', 'Mariko Okada'],
#   'title': 'Flowing'},
#  {'cast': ['Curd Jèrgens', 'Folco Lulli', 'Lea Padovani', 'Paul Frankeur'],
#   'title': 'An Eye for an Eye'},
#  {'cast': ['Pablo Picasso'], 'title': 'Le mystère Picasso'},
#  {'cast': ['Burt Lancaster',
#    'Katharine Hepburn',
#    'Wendell Corey',
#    'Lloyd Bridges'],
#   'title': 'The Rainmaker'},
#  {'cast': ['John Wayne', 'Jeffrey Hunter', 'Vera Miles', 'Ward Bond'],
#   'title': 'The Searchers'},
#  {'cast': ['Winston Hibler'], 'title': 'Secrets of Life'},
#  {'cast': ['Alberto Sordi',
#    'Sandra Milo',
#    'Nino Manfredi',
#    'Madeleine Fischer'],
#   'title': 'The Bachelor'},
#  {'cast': ['Romy Schneider',
#    'Karlheinz Bèhm',
#    'Magda Schneider',
#    'Gustav Knuth'],
#   'title': 'Sissi: The Young Empress'},
#  {'cast': ['Eva Dahlbeck',
#    'Harriet Andersson',
#    'Bibi Andersson',
#    'Bjèrn Bjelfvenstam'],
#   'title': 'Last Pair Out'},
#  {'cast': ['Randolph Scott', 'Gail Russell', 'Lee Marvin', 'Walter Reed'],
#   'title': 'Seven Men from Now'},
#  {'cast': ['Judy Holliday', 'Paul Douglas', 'Fred Clark', 'John Williams'],
#   'title': 'The Solid Gold Cadillac'},
#  {'cast': ['Paul Newman', 'Pier Angeli', 'Everett Sloane', 'Eileen Heckart'],
#   'title': 'Somebody Up There Likes Me'},
#  {'cast': ['Dirk Bogarde', 'Jon Whiteley', 'Michael Hordern', 'Cyril Cusack'],
#   'title': 'The Spanish Gardener'},
#  {'cast': ['Izolda Izvitskaya',
#    'Oleg Strizhenov',
#    'Nikolay Kryuchkov',
#    'Nikolai Dupak'],
#   'title': 'The Forty-first'},
#  {'cast': ['Deborah Kerr', 'John Kerr', 'Leif Erickson', 'Edward Andrews'],
#   'title': 'Tea and Sympathy'},
#  ...]

# %%
# Lister les films parus en 2016 ou avec qui ont gagné 100 awards
pipeline = [
    {
        "$match": {
            "$or": [
                {"year": 2016},
                {"awards.wins": {"$gte": 100}}
            ]
        }
    },
    {
        "$project": {
            "title": 1,
            "_id": 0
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'title': 'Titanic'},
#  {'title': 'The Lord of the Rings: The Fellowship of the Ring'},
#  {'title': 'The Lord of the Rings: The Return of the King'},
#  {'title': 'The Lord of the Rings: The Two Towers'},
#  {'title': 'American Beauty'},
#  {'title': 'Crouching Tiger, Hidden Dragon'},
#  {'title': 'Far from Heaven'},
#  {'title': 'Lost in Translation'},
#  {'title': 'Inglourious Basterds'},
#  {'title': 'Sideways'},
#  {'title': 'Brokeback Mountain'},
#  {'title': 'The Departed'},
#  {'title': 'Lincoln'},
#  {'title': "Pan's Labyrinth"},
#  {'title': 'Juno'},
#  {'title': 'The Dark Knight'},
#  {'title': 'There Will Be Blood'},
#  {'title': 'No Country for Old Men'},
#  {'title': 'The Tree of Life'},
#  {'title': 'The Hurt Locker'},
#  {'title': 'Precious'},
#  {'title': 'Black Swan'},
#  {'title': 'Slumdog Millionaire'},
#  {'title': 'Boyhood'},
#  {'title': 'Precious'},
#  {'title': 'Up in the Air'},
#  {'title': 'The Social Network'},
#  {'title': 'Inception'},
#  {'title': 'Gravity'},
#  {'title': "The King's Speech"},
#  {'title': 'The Master'},
#  {'title': 'Gravity'},
#  {'title': 'The Artist'},
#  {'title': 'Zero Dark Thirty'},
#  {'title': 'Her'},
#  {'title': '12 Years a Slave'},
#  {'title': 'Beasts of the Southern Wild'},
#  {'title': 'The Grand Budapest Hotel'},
#  {'title': 'The Grand Budapest Hotel'},
#  {'title': 'Birdman: Or (The Unexpected Virtue of Ignorance)'},
#  {'title': 'The Masked Saint'}]

# %%
# Lister les films parus après 2010 et dans lesquels l'un de ces acteurs a joué Sandra Bullock,Tom Hanks,Julia Roberts,Kevin Spacey,George Clooney
pipeline = [
    {
        "$match": {
            "$and": [
                {"year": {"$gt": 2010}},
                {"cast": {"$in": ["Sandra Bullock", "Tom Hanks", "Julia Roberts", "Kevin Spacey", "George Clooney"]}}
            ]
        }
    },
    {
        "$project": {
            "title": 1,
            "cast": 1,
            "_id": 0
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'cast': ['Tom Hanks', 'Thomas Horn', 'Sandra Bullock', 'Zoe Caldwell'],
#   'title': 'Extremely Loud & Incredibly Close'},
#  {'cast': ['Kevin Spacey', 'Daniel Wu', 'Beibi Gong', 'Ni Yan'],
#   'title': 'Inseparable'},
#  {'title': 'The Descendants',
#   'cast': ['George Clooney',
#    'Shailene Woodley',
#    'Amara Miller',
#    'Nick Krause']},
#  {'cast': ['Ryan Gosling',
#    'George Clooney',
#    'Philip Seymour Hoffman',
#    'Paul Giamatti'],
#   'title': 'The Ides of March'},
#  {'title': 'August: Osage County',
#   'cast': ['Meryl Streep', 'Julia Roberts', 'Chris Cooper', 'Ewan McGregor']},
#  {'title': 'Cloud Atlas',
#   'cast': ['Tom Hanks', 'Halle Berry', 'Jim Broadbent', 'Hugo Weaving']},
#  {'title': 'Gravity',
#   'cast': ['Sandra Bullock',
#    'George Clooney',
#    'Ed Harris',
#    'Orto Ignatiussen']},
#  {'cast': ['Jason Bateman', 'Steve Wiebe', 'Kevin Spacey', 'Charlie Day'],
#   'title': 'Horrible Bosses'},
#  {'title': 'Captain Phillips',
#   'cast': ['Tom Hanks',
#    'Catherine Keener',
#    'Barkhad Abdi',
#    'Barkhad Abdirahman']},
#  {'cast': ['Tom Hanks', 'Sarah Mahoney', 'Roxana Ortega', 'Randall Park'],
#   'title': 'Larry Crowne'},
#  {'title': 'Gravity',
#   'cast': ['Sandra Bullock',
#    'George Clooney',
#    'Ed Harris',
#    'Orto Ignatiussen']},
#  {'cast': ['Kevin Spacey', 'Paul Bettany', 'Jeremy Irons', 'Zachary Quinto'],
#   'title': 'Margin Call'},
#  {'cast': ['Julia Roberts', 'Lily Collins', 'Armie Hammer', 'Nathan Lane'],
#   'title': 'Mirror Mirror'},
#  {'title': 'The Ides of March',
#   'cast': ['Ryan Gosling',
#    'George Clooney',
#    'Philip Seymour Hoffman',
#    'Paul Giamatti']},
#  {'cast': ['George Clooney',
#    'Hugh Laurie',
#    'Britt Robertson',
#    'Raffey Cassidy'],
#   'title': 'Tomorrowland'},
#  {'cast': ['Emma Thompson',
#    'Tom Hanks',
#    'Annie Rose Buckley',
#    'Colin Farrell'],
#   'title': 'Saving Mr. Banks'},
#  {'cast': ['George Clooney', 'Matt Damon', 'Bill Murray', 'Cate Blanchett'],
#   'title': 'The Monuments Men'},
#  {'cast': ['Tom Hanks', 'Regen Wilson', 'Billy Campbell', 'Jesse Johnson'],
#   'title': 'Killing Lincoln'},
#  {'cast': ['Sandra Bullock',
#    'Melissa McCarthy',
#    'Demian Bichir',
#    'Marlon Wayans'],
#   'title': 'The Heat'},
#  {'cast': ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Carl Weathers'],
#   'title': 'Toy Story of Terror'},
#  {'cast': ['Tom Hanks', 'Tim Allen', 'Kristen Schaal', 'Kevin McKidd'],
#   'title': 'Toy Story That Time Forgot'}]

# %%
#Combien de films a comme director Clint Eastwood 
pipeline = [
    {
        "$match": {
            "directors": "Clint Eastwood"
        }
    },
    {
        "$count": "count"
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'count': 27}]

# %%
#Combien de films a comme director Clint Eastwood 
movies.count_documents({"directors": "Clint Eastwood"})
# Out:
# 27

# %%
#set comments variables comments
comments = mflix.comments

# %%
#retrieves list movies id de Client Estwood
list_films = list(movies.find({"directors": "Clint Eastwood"}, {"_id": 1}).distinct('_id'))
# list_films

# %%
#De la liste précédente et dans la collection comments de la BDD sample_mflix, combien de films ont été commentés
pipeline = [
    {
        "$match": {
            "movie_id": {
                "$in": list_films
            }
        }
    },
    {
        "$count": "Client Estwood commented movie nb"
    }
]
list(comments.aggregate(pipeline))
# Out:
# [{'Client Estwood commented movie nb': 9}]

# %%
#Combien de films ont eu la note "PG-13" (indice : clé "rated") ? Afficher le 1er document ?
#Faire une projection dessus pour se limiter aux infos suivantes : _id, title, rated, year, writers et actors ? 
#Afficher de nouveau ces dernières infos sans l'_id ?
pipeline = [
    {
        "$match": {
            "rated": "PG-13"
        }
    },
    {
        "$project": {
            "_id": 0,
            "title": 1,
            "rated": 1,
            "year": 1,
            "writers": 1,
            "actors": 1
        }
    },
    {
        "$limit": 1
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'rated': 'PG-13',
#   'title': 'Wings',
#   'writers': ['John Monk Saunders (story)',
#    'Hope Loring (screenplay)',
#    'Louis D. Lighton (screenplay)',
#    'Julian Johnson (titles)'],
#   'year': 1927}]

# %%
#Trouver les films ayant la note "PG-13" et produits en 2009 ?
pipeline = [
    {
        "$match": {
            "rated": "PG-13",
            "year": 2009,
        }
    },
    {
        "$project": {
            "_id": 1,
            'year': 1
        }
    }
]
len(list(movies.aggregate(pipeline)))
# Out:
# 100

# %%
#Combien de films ont comme sous-clé "meter" de la clé "tomatoes" égale à 100 ?
pipeline = [
    {
        "$match": {
            "tomatoes.viewer.meter": {
                "$gte": 100,
                "$exists": True
            }
        }
    },
    {
        "$project": {
            "tomatoes": 1
        }
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'_id': ObjectId('573a1391f29313caabcd952a'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 17, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 1, 49)}},
#  {'_id': ObjectId('573a1392f29313caabcd99e3'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 119, 'meter': 100},
#    'production': 'Paramount Pictures',
#    'lastUpdated': datetime.datetime(2015, 8, 9, 18, 15, 6)}},
#  {'_id': ObjectId('573a1392f29313caabcd9b68'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 150, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 3, 18, 40, 4)}},
#  {'_id': ObjectId('573a1392f29313caabcd9c4c'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 104, 'meter': 100},
#    'dvd': datetime.datetime(2009, 2, 24, 0, 0),
#    'production': 'Divisa Home Video',
#    'lastUpdated': datetime.datetime(2015, 9, 1, 18, 51, 7)}},
#  {'_id': ObjectId('573a1392f29313caabcda653'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 49, 'meter': 100},
#    'production': 'Amkino Corporation',
#    'lastUpdated': datetime.datetime(2015, 8, 22, 18, 45, 12)}},
#  {'_id': ObjectId('573a1392f29313caabcdb231'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 128, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 1, 18, 48, 56)}},
#  {'_id': ObjectId('573a1392f29313caabcdb571'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 8, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 13, 18, 10, 36)}},
#  {'_id': ObjectId('573a1392f29313caabcdbb45'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 99, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 51, 58)}},
#  {'_id': ObjectId('573a1393f29313caabcdbef1'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 75, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 27, 19, 40, 23)}},
#  {'_id': ObjectId('573a1393f29313caabcdd74c'),
#   'tomatoes': {'viewer': {'rating': 4.6, 'numReviews': 63, 'meter': 100},
#    'dvd': datetime.datetime(2003, 10, 21, 0, 0),
#    'production': 'Azteca Films Inc.',
#    'lastUpdated': datetime.datetime(2015, 9, 14, 18, 2, 3)}},
#  {'_id': ObjectId('573a1393f29313caabcdd89b'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 32, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 2, 18, 0, 31)}},
#  {'_id': ObjectId('573a1393f29313caabcddba9'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 25, 'meter': 100},
#    'dvd': datetime.datetime(1999, 9, 21, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 6, 14, 19, 6, 33)}},
#  {'_id': ObjectId('573a1393f29313caabcde1f8'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 44, 'meter': 100},
#    'production': 'Paramount Pictures',
#    'lastUpdated': datetime.datetime(2015, 8, 20, 19, 21, 2)}},
#  {'_id': ObjectId('573a1393f29313caabcde2c4'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 30, 'meter': 100},
#    'dvd': datetime.datetime(2003, 6, 17, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 9, 18, 6, 23)}},
#  {'_id': ObjectId('573a1393f29313caabcde367'),
#   'tomatoes': {'viewer': {'rating': 2.9, 'numReviews': 9, 'meter': 100},
#    'fresh': 1,
#    'critic': {'numReviews': 1},
#    'rotten': 0,
#    'lastUpdated': datetime.datetime(2015, 3, 21, 19, 5, 20)}},
#  {'_id': ObjectId('573a1393f29313caabcde3ca'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 38, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 21, 19, 4, 32)}},
#  {'_id': ObjectId('573a1394f29313caabcdf31f'),
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 49, 'meter': 100},
#    'production': 'Scott Entertainment',
#    'lastUpdated': datetime.datetime(2015, 8, 17, 18, 44, 4)}},
#  {'_id': ObjectId('573a1394f29313caabcdf913'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 14, 'meter': 100},
#    'dvd': datetime.datetime(2006, 6, 20, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 25, 36)}},
#  {'_id': ObjectId('573a1394f29313caabce0309'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 16, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 2, 18, 33, 18)}},
#  {'_id': ObjectId('573a1394f29313caabce0dff'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 9, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 41, 24)}},
#  {'_id': ObjectId('573a1394f29313caabce0e60'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 29, 'meter': 100},
#    'dvd': datetime.datetime(1992, 9, 9, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 21, 19, 23, 32)}},
#  {'_id': ObjectId('573a1394f29313caabce0fd3'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 69, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 20, 19, 23)}},
#  {'_id': ObjectId('573a1395f29313caabce109d'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 71, 'meter': 100},
#    'production': '20th Century Fox Film Corporation',
#    'lastUpdated': datetime.datetime(2015, 9, 11, 18, 44, 56)}},
#  {'_id': ObjectId('573a1395f29313caabce10ef'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 152, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 5, 22, 18, 25, 13)}},
#  {'_id': ObjectId('573a1395f29313caabce1117'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 60, 'meter': 100},
#    'dvd': datetime.datetime(2003, 4, 22, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 5, 15, 18, 56, 17)}},
#  {'_id': ObjectId('573a1395f29313caabce14a2'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 45, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 27, 18, 4, 38)}},
#  {'_id': ObjectId('573a1395f29313caabce15c1'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 7, 'meter': 100},
#    'dvd': datetime.datetime(2010, 4, 20, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 6, 27, 18, 56, 17)}},
#  {'_id': ObjectId('573a1395f29313caabce1751'),
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 133, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 25, 19, 45, 14)}},
#  {'_id': ObjectId('573a1395f29313caabce18c9'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 26, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 15, 19, 11, 56)}},
#  {'_id': ObjectId('573a1395f29313caabce1a3d'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 67, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 43, 48)}},
#  {'_id': ObjectId('573a1395f29313caabce1a81'),
#   'tomatoes': {'viewer': {'rating': 4.7, 'numReviews': 9, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 1, 19, 18, 45)}},
#  {'_id': ObjectId('573a1395f29313caabce1da5'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 12, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 18, 19, 31, 20)}},
#  {'_id': ObjectId('573a1395f29313caabce1e45'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 22, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 5, 6, 18, 22, 31)}},
#  {'_id': ObjectId('573a1395f29313caabce1f3b'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 167, 'meter': 100},
#    'dvd': datetime.datetime(1994, 10, 26, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 6, 18, 3, 17)}},
#  {'_id': ObjectId('573a1395f29313caabce210e'),
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 64, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 14, 22, 12, 53)}},
#  {'_id': ObjectId('573a1395f29313caabce2468'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 15, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 10, 42)}},
#  {'_id': ObjectId('573a1395f29313caabce2547'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 388, 'meter': 100},
#    'dvd': datetime.datetime(2006, 6, 27, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 22, 19, 17, 30)}},
#  {'_id': ObjectId('573a1395f29313caabce28ce'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 16, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 11, 18, 32, 46)}},
#  {'_id': ObjectId('573a1395f29313caabce2c6c'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 210, 'meter': 100},
#    'production': 'Medusa Distribuzione',
#    'lastUpdated': datetime.datetime(2015, 8, 11, 18, 59, 31)}},
#  {'_id': ObjectId('573a1395f29313caabce3246'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 10, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 21, 18, 27, 12)}},
#  {'_id': ObjectId('573a1395f29313caabce328c'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 118, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 17, 19, 19, 44)}},
#  {'_id': ObjectId('573a1395f29313caabce32f3'),
#   'tomatoes': {'viewer': {'rating': 2.0, 'numReviews': 17, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 18, 19, 14, 43)}},
#  {'_id': ObjectId('573a1396f29313caabce34b2'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 63, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 15, 19, 23, 50)}},
#  {'_id': ObjectId('573a1396f29313caabce379d'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 90, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 20, 17, 13, 53)}},
#  {'_id': ObjectId('573a1396f29313caabce3b2a'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 29, 'meter': 100},
#    'dvd': datetime.datetime(2005, 11, 15, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 57, 55)}},
#  {'_id': ObjectId('573a1396f29313caabce3b86'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 32, 'meter': 100},
#    'dvd': datetime.datetime(2000, 1, 11, 0, 0),
#    'production': 'Universal',
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 58, 48)}},
#  {'_id': ObjectId('573a1396f29313caabce3bd3'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 57, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 15, 18, 1, 8)}},
#  {'_id': ObjectId('573a1396f29313caabce3c39'),
#   'tomatoes': {'viewer': {'rating': 4.6, 'numReviews': 9, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 25, 8)}},
#  {'_id': ObjectId('573a1396f29313caabce3c54'),
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 27, 'meter': 100},
#    'production': 'Indie Crush',
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 32, 53)}},
#  {'_id': ObjectId('573a1396f29313caabce3f96'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 48, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 13, 19, 19, 24)}},
#  {'_id': ObjectId('573a1396f29313caabce4145'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 31, 'meter': 100},
#    'production': 'MCA Universal Home Video',
#    'lastUpdated': datetime.datetime(2015, 8, 23, 16, 21, 58)}},
#  {'_id': ObjectId('573a1396f29313caabce4439'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 36, 'meter': 100},
#    'dvd': datetime.datetime(2006, 6, 27, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 12, 17, 21, 4)}},
#  {'_id': ObjectId('573a1396f29313caabce44b1'),
#   'tomatoes': {'viewer': {'rating': 4.6, 'numReviews': 51, 'meter': 100},
#    'production': 'New Yorker Films',
#    'lastUpdated': datetime.datetime(2015, 6, 12, 19, 13, 33)}},
#  {'_id': ObjectId('573a1396f29313caabce457e'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 182, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 14, 18, 39, 59)}},
#  {'_id': ObjectId('573a1396f29313caabce49e6'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 27, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 21, 18, 16, 6)}},
#  {'_id': ObjectId('573a1396f29313caabce4b4e'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 74, 'meter': 100},
#    'dvd': datetime.datetime(2007, 9, 11, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 5, 6, 19, 20, 23)}},
#  {'_id': ObjectId('573a1396f29313caabce4b89'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 363, 'meter': 100},
#    'dvd': datetime.datetime(2004, 8, 17, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 10, 18, 55, 7)}},
#  {'_id': ObjectId('573a1396f29313caabce52cb'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 59, 'meter': 100},
#    'dvd': datetime.datetime(2004, 8, 3, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 5, 7, 18, 26, 53)}},
#  {'_id': ObjectId('573a1396f29313caabce5500'),
#   'tomatoes': {'viewer': {'rating': 4.6, 'numReviews': 26, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 25, 20, 50, 14)}},
#  {'_id': ObjectId('573a1396f29313caabce56c2'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 39, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 10, 18, 18, 56)}},
#  {'_id': ObjectId('573a1397f29313caabce5cc0'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 54, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 14, 21, 42, 13)}},
#  {'_id': ObjectId('573a1397f29313caabce5da3'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 15, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 17, 19, 33, 26)}},
#  {'_id': ObjectId('573a1397f29313caabce62a3'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 61, 'meter': 100},
#    'dvd': datetime.datetime(2003, 3, 18, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 13, 18, 12, 6)}},
#  {'_id': ObjectId('573a1397f29313caabce62fb'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 13, 'meter': 100},
#    'dvd': datetime.datetime(1996, 8, 23, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 11, 18, 39, 47)}},
#  {'_id': ObjectId('573a1397f29313caabce6310'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 25, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 5, 2, 28, 32)}},
#  {'_id': ObjectId('573a1397f29313caabce6390'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 59, 'meter': 100},
#    'production': 'Rumson Film Distributors',
#    'lastUpdated': datetime.datetime(2015, 8, 13, 19, 40, 8)}},
#  {'_id': ObjectId('573a1397f29313caabce641a'),
#   'tomatoes': {'viewer': {'rating': 4.7, 'numReviews': 28, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 10, 19, 1, 31)}},
#  {'_id': ObjectId('573a1397f29313caabce6724'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 47, 'meter': 100},
#    'dvd': datetime.datetime(2006, 3, 21, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 31, 18, 20, 39)}},
#  {'_id': ObjectId('573a1397f29313caabce677a'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 33, 'meter': 100},
#    'dvd': datetime.datetime(2003, 9, 16, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 16, 17, 44, 56)}},
#  {'_id': ObjectId('573a1397f29313caabce691b'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 7, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 1, 18, 19, 29)}},
#  {'_id': ObjectId('573a1397f29313caabce69f9'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 47, 'meter': 100},
#    'dvd': datetime.datetime(2008, 2, 19, 0, 0),
#    'production': 'Acorn Media',
#    'lastUpdated': datetime.datetime(2015, 8, 15, 19, 19, 32)}},
#  {'_id': ObjectId('573a1397f29313caabce6e15'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 28, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 13, 17, 12, 31)}},
#  {'_id': ObjectId('573a1397f29313caabce71a0'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 71, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 57, 52)}},
#  {'_id': ObjectId('573a1397f29313caabce72d7'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 5, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 18, 19, 21, 20)}},
#  {'_id': ObjectId('573a1397f29313caabce736c'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 67, 'meter': 100},
#    'dvd': datetime.datetime(2006, 12, 12, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 17, 18, 42, 10)}},
#  {'_id': ObjectId('573a1397f29313caabce7717'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 54, 'meter': 100},
#    'dvd': datetime.datetime(2006, 12, 19, 0, 0),
#    'production': 'Vides Cinematografica',
#    'lastUpdated': datetime.datetime(2015, 9, 1, 19, 11, 24)}},
#  {'_id': ObjectId('573a1397f29313caabce79b4'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 9, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 5, 30, 19, 22, 7)}},
#  {'_id': ObjectId('573a1397f29313caabce7d5b'),
#   'tomatoes': {'viewer': {'rating': 4.7, 'numReviews': 37, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 7, 49)}},
#  {'_id': ObjectId('573a1397f29313caabce7d98'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 14, 'meter': 100},
#    'dvd': datetime.datetime(1990, 8, 3, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 3, 19, 24, 14)}},
#  {'_id': ObjectId('573a1397f29313caabce7de2'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 54, 'meter': 100},
#    'dvd': datetime.datetime(2006, 3, 7, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 31, 19, 1, 30)}},
#  {'_id': ObjectId('573a1397f29313caabce7df0'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 64, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 52, 15)}},
#  {'_id': ObjectId('573a1397f29313caabce7eec'),
#   'tomatoes': {'viewer': {'rating': 4.8, 'numReviews': 6, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 13, 17, 46, 27)}},
#  {'_id': ObjectId('573a1397f29313caabce7f3d'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 14, 'meter': 100},
#    'dvd': datetime.datetime(2003, 9, 16, 0, 0),
#    'production': 'Live Home Video',
#    'lastUpdated': datetime.datetime(2015, 8, 7, 19, 6, 20)}},
#  {'_id': ObjectId('573a1397f29313caabce7fa0'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 61, 'meter': 100},
#    'dvd': datetime.datetime(2008, 1, 15, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 6, 13, 18, 42, 18)}},
#  {'_id': ObjectId('573a1397f29313caabce7fc8'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 301, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 3, 19, 18, 22)}},
#  {'_id': ObjectId('573a1397f29313caabce8779'),
#   'tomatoes': {'viewer': {'rating': 4.3, 'numReviews': 10, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 17, 19, 32, 43)}},
#  {'_id': ObjectId('573a1397f29313caabce8896'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 49, 'meter': 100},
#    'dvd': datetime.datetime(2007, 10, 2, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 1, 2, 3, 32, 51)}},
#  {'_id': ObjectId('573a1397f29313caabce8943'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 92, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 14, 18, 21, 25)}},
#  {'_id': ObjectId('573a1398f29313caabcea40a'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 642, 'meter': 100},
#    'dvd': datetime.datetime(2005, 3, 1, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 3, 20, 19, 29, 27)}},
#  {'_id': ObjectId('573a1398f29313caabcea4ee'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 24, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 27, 19, 1, 7)}},
#  {'_id': ObjectId('573a1398f29313caabcea550'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 37, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 11, 18, 36, 29)}},
#  {'_id': ObjectId('573a1398f29313caabcea573'),
#   'tomatoes': {'viewer': {'rating': 4.3, 'numReviews': 42, 'meter': 100},
#    'dvd': datetime.datetime(2008, 10, 27, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 13, 18, 49, 41)}},
#  {'_id': ObjectId('573a1398f29313caabcea774'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 16, 'meter': 100},
#    'production': 'Union Gènèrale Cinèmatographique',
#    'lastUpdated': datetime.datetime(2015, 6, 10, 19, 14, 35)}},
#  {'_id': ObjectId('573a1398f29313caabcead09'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 51, 'meter': 100},
#    'dvd': datetime.datetime(1999, 10, 5, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 4, 25, 18, 11, 3)}},
#  {'_id': ObjectId('573a1398f29313caabceb0aa'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 6, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 30, 3)}},
#  {'_id': ObjectId('573a1398f29313caabceb28b'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 276, 'meter': 100},
#    'production': 'Gaumont British Picture Co.',
#    'lastUpdated': datetime.datetime(2015, 8, 18, 18, 19, 59)}},
#  {'_id': ObjectId('573a1398f29313caabceb4d6'),
#   'tomatoes': {'viewer': {'rating': 4.8, 'numReviews': 4, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 30, 18, 50, 8)}},
#  {'_id': ObjectId('573a1398f29313caabceb928'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 56, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 11, 19, 23, 3)}},
#  {'_id': ObjectId('573a1398f29313caabceb939'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 23, 'meter': 100},
#    'dvd': datetime.datetime(1997, 6, 3, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 5, 6, 19, 43, 15)}},
#  {'_id': ObjectId('573a1398f29313caabcebb69'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 18, 'meter': 100},
#    'dvd': datetime.datetime(1991, 10, 16, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 14, 18, 44, 44)}},
#  {'_id': ObjectId('573a1398f29313caabcebfc4'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 92, 'meter': 100},
#    'dvd': datetime.datetime(2006, 1, 10, 0, 0),
#    'production': 'Turner Home Entertainment',
#    'lastUpdated': datetime.datetime(2015, 9, 10, 18, 40, 30)}},
#  {'_id': ObjectId('573a1399f29313caabcec20a'),
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 72, 'meter': 100},
#    'dvd': datetime.datetime(1991, 7, 25, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 2, 19, 29, 22)}},
#  {'_id': ObjectId('573a1399f29313caabcec355'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 36, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 34, 38)}},
#  {'_id': ObjectId('573a1399f29313caabcec3c6'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 36, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 34, 38)}},
#  {'_id': ObjectId('573a1399f29313caabcec649'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 30, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 2, 19, 40, 58)}},
#  {'_id': ObjectId('573a1399f29313caabcec87e'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 8, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 2, 19, 49, 17)}},
#  {'_id': ObjectId('573a1399f29313caabcec97b'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 11, 'meter': 100},
#    'dvd': datetime.datetime(1994, 8, 24, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 5, 26, 18, 7, 31)}},
#  {'_id': ObjectId('573a1399f29313caabcec9aa'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 64, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 11, 18, 2, 13)}},
#  {'_id': ObjectId('573a1399f29313caabced220'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 37, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 12, 35)}},
#  {'_id': ObjectId('573a1399f29313caabced4eb'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 94, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 21, 36)}},
#  {'_id': ObjectId('573a1399f29313caabced584'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 71, 'meter': 100},
#    'dvd': datetime.datetime(2003, 4, 24, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 7, 32)}},
#  {'_id': ObjectId('573a1399f29313caabced72c'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 59, 'meter': 100},
#    'website': 'http://www.madragoafilmes.pt/oultimomergulho/',
#    'production': 'Madragoa Filmes',
#    'lastUpdated': datetime.datetime(2015, 9, 16, 19, 25, 46)}},
#  {'_id': ObjectId('573a1399f29313caabced8e7'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 127, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 31, 34)}},
#  {'_id': ObjectId('573a1399f29313caabceda49'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 5, 'meter': 100},
#    'dvd': datetime.datetime(1997, 3, 11, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 20, 19, 3, 35)}},
#  {'_id': ObjectId('573a1399f29313caabcedd7a'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 6, 'meter': 100},
#    'dvd': datetime.datetime(1996, 8, 27, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 44, 3)}},
#  {'_id': ObjectId('573a1399f29313caabcedfce'),
#   'tomatoes': {'viewer': {'rating': 4.7, 'numReviews': 93, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 51, 30)}},
#  {'_id': ObjectId('573a1399f29313caabcedfcf'),
#   'tomatoes': {'viewer': {'rating': 4.7, 'numReviews': 93, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 51, 30)}},
#  {'_id': ObjectId('573a1399f29313caabcee058'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 62, 'meter': 100},
#    'dvd': datetime.datetime(2003, 6, 10, 0, 0),
#    'production': 'PM Home Video',
#    'lastUpdated': datetime.datetime(2015, 7, 21, 19, 41, 59)}},
#  {'_id': ObjectId('573a1399f29313caabcee098'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 13, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 54, 47)}},
#  {'_id': ObjectId('573a1399f29313caabcee3c8'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 39, 'meter': 100},
#    'dvd': datetime.datetime(2005, 3, 15, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 1, 3, 7, 36, 53)}},
#  {'_id': ObjectId('573a1399f29313caabcee781'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 44, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 5, 25, 18, 57, 55)}},
#  {'_id': ObjectId('573a1399f29313caabceeb27'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 2, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 10, 5, 27)}},
#  {'_id': ObjectId('573a1399f29313caabceed4e'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 73, 'meter': 100},
#    'dvd': datetime.datetime(2007, 3, 27, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 44, 7)}},
#  {'_id': ObjectId('573a139af29313caabcef078'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 11, 'meter': 100},
#    'dvd': datetime.datetime(1998, 3, 10, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 4, 19, 18, 45, 16)}},
#  {'_id': ObjectId('573a139af29313caabcef559'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 11, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 7, 18, 1, 38)}},
#  {'_id': ObjectId('573a139af29313caabcef7da'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 70, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 20, 18, 28, 19)}},
#  {'_id': ObjectId('573a139af29313caabcef938'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 42, 'meter': 100},
#    'production': 'MTI Home Video',
#    'lastUpdated': datetime.datetime(2015, 1, 23, 18, 24, 11)}},
#  {'_id': ObjectId('573a139af29313caabcefd66'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 50, 'meter': 100},
#    'dvd': datetime.datetime(2005, 5, 31, 0, 0),
#    'production': 'Dreams Come True Productions',
#    'lastUpdated': datetime.datetime(2015, 9, 3, 18, 23, 5)}},
#  {'_id': ObjectId('573a139af29313caabcf0145'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 77, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 2, 19, 27, 24)}},
#  {'_id': ObjectId('573a139af29313caabcf0157'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 77, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 2, 19, 27, 24)}},
#  {'_id': ObjectId('573a139af29313caabcf0239'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 74, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 7, 18, 52, 58)}},
#  {'_id': ObjectId('573a139af29313caabcf0346'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 397, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 29, 18, 58, 51)}},
#  {'_id': ObjectId('573a139af29313caabcf0895'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 75, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 5, 7, 18, 20, 24)}},
#  {'_id': ObjectId('573a139af29313caabcf0b50'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 120, 'meter': 100},
#    'dvd': datetime.datetime(2008, 6, 24, 0, 0),
#    'production': 'Docurama',
#    'lastUpdated': datetime.datetime(2015, 7, 27, 18, 11, 44)}},
#  {'_id': ObjectId('573a139af29313caabcf0c16'),
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 80, 'meter': 100},
#    'dvd': datetime.datetime(1998, 1, 1, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 23, 18, 14, 5)}},
#  {'_id': ObjectId('573a139af29313caabcf0c18'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 18, 'meter': 100},
#    'dvd': datetime.datetime(1998, 12, 15, 0, 0),
#    'critic': {'rating': 6.7, 'numReviews': 12, 'meter': 67},
#    'lastUpdated': datetime.datetime(2015, 6, 18, 19, 42, 13),
#    'rotten': 4,
#    'production': 'Sony Pictures Home Entertainment',
#    'fresh': 8}},
#  {'_id': ObjectId('573a139af29313caabcf0ca5'),
#   'tomatoes': {'viewer': {'rating': 4.8, 'numReviews': 30, 'meter': 100},
#    'production': 'Criterion Collection',
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 6, 50)}},
#  {'_id': ObjectId('573a139af29313caabcf0d69'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 6, 'meter': 100},
#    'dvd': datetime.datetime(2001, 6, 12, 0, 0),
#    'critic': {'numReviews': 3},
#    'lastUpdated': datetime.datetime(2015, 1, 9, 21, 2, 30),
#    'rotten': 0,
#    'fresh': 3}},
#  {'_id': ObjectId('573a139af29313caabcf0e5c'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 50, 'meter': 100},
#    'dvd': datetime.datetime(2004, 4, 13, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 10, 19, 9, 51)}},
#  {'_id': ObjectId('573a139af29313caabcf0ee7'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 40, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 12, 17, 12, 12)}},
#  {'_id': ObjectId('573a139af29313caabcf1a32'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 18, 'meter': 100},
#    'dvd': datetime.datetime(1998, 12, 15, 0, 0),
#    'critic': {'rating': 6.7, 'numReviews': 12, 'meter': 67},
#    'lastUpdated': datetime.datetime(2015, 6, 18, 19, 42, 13),
#    'rotten': 4,
#    'production': 'Sony Pictures Home Entertainment',
#    'fresh': 8}},
#  {'_id': ObjectId('573a139af29313caabcf1dd7'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 179, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 28, 18, 16, 29)}},
#  {'_id': ObjectId('573a139bf29313caabcf2559'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 49, 'meter': 100},
#    'dvd': datetime.datetime(1998, 1, 1, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 13, 18, 23, 3)}},
#  {'_id': ObjectId('573a139bf29313caabcf2998'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 616, 'meter': 100},
#    'dvd': datetime.datetime(2001, 1, 23, 0, 0),
#    'critic': {'rating': 6.9, 'numReviews': 14, 'meter': 71},
#    'lastUpdated': datetime.datetime(2015, 6, 6, 18, 48, 18),
#    'rotten': 4,
#    'fresh': 10}},
#  {'_id': ObjectId('573a139bf29313caabcf2d8e'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 115, 'meter': 100},
#    'dvd': datetime.datetime(2004, 3, 2, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 14, 18, 49, 17)}},
#  {'_id': ObjectId('573a139bf29313caabcf32b0'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 70, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 20, 18, 28, 19)}},
#  {'_id': ObjectId('573a139bf29313caabcf341f'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 179, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 28, 18, 16, 29)}},
#  {'_id': ObjectId('573a139bf29313caabcf3d20'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 7, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 11, 19, 57, 37)}},
#  {'_id': ObjectId('573a139bf29313caabcf48ed'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 22, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 55, 33)}},
#  {'_id': ObjectId('573a139bf29313caabcf4d59'),
#   'tomatoes': {'viewer': {'rating': 4.6, 'numReviews': 55, 'meter': 100},
#    'dvd': datetime.datetime(2007, 10, 23, 0, 0),
#    'critic': {'rating': 6.6, 'numReviews': 6, 'meter': 83},
#    'lastUpdated': datetime.datetime(2015, 5, 19, 19, 10, 58),
#    'rotten': 1,
#    'fresh': 5}},
#  {'_id': ObjectId('573a139bf29313caabcf5013'),
#   'tomatoes': {'viewer': {'rating': 4.3, 'numReviews': 55, 'meter': 100},
#    'dvd': datetime.datetime(2005, 10, 18, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 31, 18, 21, 37)}},
#  {'_id': ObjectId('573a139cf29313caabcf5872'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 46, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 23, 18, 19, 41)}},
#  {'_id': ObjectId('573a139cf29313caabcf6b91'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 84, 'meter': 100},
#    'dvd': datetime.datetime(2008, 4, 1, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 38)}},
#  {'_id': ObjectId('573a139cf29313caabcf7db4'),
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 32, 'meter': 100},
#    'dvd': datetime.datetime(2007, 10, 30, 0, 0),
#    'critic': {'rating': 6.8, 'numReviews': 6, 'meter': 83},
#    'lastUpdated': datetime.datetime(2015, 4, 19, 18, 59, 44),
#    'rotten': 1,
#    'fresh': 5}},
#  {'_id': ObjectId('573a139df29313caabcfae44'),
#   'tomatoes': {'viewer': {'rating': 4.3, 'numReviews': 171, 'meter': 100},
#    'dvd': datetime.datetime(2001, 3, 13, 0, 0),
#    'critic': {'rating': 6.1, 'numReviews': 6, 'meter': 67},
#    'lastUpdated': datetime.datetime(2015, 7, 21, 19, 43, 24),
#    'rotten': 2,
#    'fresh': 4}},
#  {'_id': ObjectId('573a139df29313caabcfb957'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 145, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 15, 19, 16, 44)}},
#  {'_id': ObjectId('573a139ef29313caabcfc357'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 34, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 22, 19, 7, 34)}},
#  {'_id': ObjectId('573a139ef29313caabcfc53f'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 17, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 21, 57)}},
#  {'_id': ObjectId('573a139ef29313caabcfc892'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 84, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 16, 18, 21, 48)}},
#  {'_id': ObjectId('573a139ff29313caabcff0b6'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 25, 'meter': 100},
#    'dvd': datetime.datetime(2005, 5, 9, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 16, 18, 30, 40)}},
#  {'_id': ObjectId('573a139ff29313caabcff26e'),
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 77, 'meter': 100},
#    'dvd': datetime.datetime(2001, 9, 4, 0, 0),
#    'production': 'Avalanche Entertainment',
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 38, 42)}},
#  {'_id': ObjectId('573a139ff29313caabd01734'),
#   'tomatoes': {'viewer': {'rating': 4.6, 'numReviews': 7, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 1, 19, 8, 21)}},
#  {'_id': ObjectId('573a139ff29313caabd01f7b'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 46, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 23, 18, 19, 41)}},
#  {'_id': ObjectId('573a139ff29313caabd022fa'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 10, 'meter': 100},
#    'critic': {'rating': 6.5, 'numReviews': 6, 'meter': 83},
#    'lastUpdated': datetime.datetime(2015, 8, 22, 18, 21, 51),
#    'rotten': 1,
#    'production': '11 Marzo Cinematografica',
#    'fresh': 5}},
#  {'_id': ObjectId('573a13a0f29313caabd0378c'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 40, 'meter': 100},
#    'dvd': datetime.datetime(2003, 5, 27, 0, 0),
#    'production': 'Vanguard',
#    'lastUpdated': datetime.datetime(2015, 7, 29, 19, 34, 43)}},
#  {'_id': ObjectId('573a13a0f29313caabd039ad'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 101, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 14, 18, 22, 31)}},
#  {'_id': ObjectId('573a13a0f29313caabd0410f'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 34, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 11, 18, 43, 1)}},
#  {'_id': ObjectId('573a13a0f29313caabd04642'),
#   'tomatoes': {'viewer': {'rating': 2.5, 'numReviews': 2, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 2, 10, 18, 0, 12)}},
#  {'_id': ObjectId('573a13a0f29313caabd05ed6'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 12, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 18, 18, 42, 5)}},
#  {'_id': ObjectId('573a13a0f29313caabd06118'),
#   'tomatoes': {'viewer': {'rating': 4.8, 'numReviews': 52, 'meter': 100},
#    'dvd': datetime.datetime(2004, 8, 10, 0, 0),
#    'production': 'Journey Productions',
#    'lastUpdated': datetime.datetime(2015, 7, 21, 19, 32, 53)}},
#  {'_id': ObjectId('573a13a0f29313caabd06218'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 17, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 25, 10, 25, 40)}},
#  {'_id': ObjectId('573a13a1f29313caabd07869'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 52, 'meter': 100},
#    'dvd': datetime.datetime(2009, 6, 16, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 3, 1, 18, 14, 43)}},
#  {'_id': ObjectId('573a13a1f29313caabd07d48'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 323, 'meter': 100},
#    'dvd': datetime.datetime(2002, 1, 22, 0, 0),
#    'critic': {'rating': 7.0, 'numReviews': 9, 'meter': 89},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 19, 17, 20),
#    'rotten': 1,
#    'production': 'Clear Blue Sky Productions',
#    'fresh': 8}},
#  {'_id': ObjectId('573a13a1f29313caabd095e8'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 51, 'meter': 100},
#    'dvd': datetime.datetime(2004, 10, 26, 0, 0),
#    'production': 'Bandai',
#    'lastUpdated': datetime.datetime(2015, 8, 18, 19, 11, 10)}},
#  {'_id': ObjectId('573a13a1f29313caabd0962a'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 10, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 11, 18, 45, 54)}},
#  {'_id': ObjectId('573a13a2f29313caabd0a9b2'),
#   'tomatoes': {'website': 'http://www.goodhousekeepingmovie.com',
#    'viewer': {'rating': 3.8, 'numReviews': 33, 'meter': 100},
#    'critic': {'rating': 5.0, 'numReviews': 18, 'meter': 44},
#    'lastUpdated': datetime.datetime(2015, 8, 24, 18, 50, 21),
#    'rotten': 10,
#    'production': 'Universal Focus',
#    'fresh': 8}},
#  {'_id': ObjectId('573a13a2f29313caabd0b484'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 65, 'meter': 100},
#    'dvd': datetime.datetime(2005, 3, 29, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 16, 19, 25, 35)}},
#  {'_id': ObjectId('573a13a2f29313caabd0b8a5'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 48, 'meter': 100},
#    'dvd': datetime.datetime(1999, 5, 18, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 2, 25, 17, 31, 44)}},
#  {'_id': ObjectId('573a13a2f29313caabd0bb76'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 20, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 30, 19, 56, 30)}},
#  {'_id': ObjectId('573a13a3f29313caabd0c7cf'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 16, 'meter': 100},
#    'dvd': datetime.datetime(1998, 6, 30, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 1, 18, 4, 39)}},
#  {'_id': ObjectId('573a13a3f29313caabd0cccb'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 88, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 21, 18, 40, 30)}},
#  {'_id': ObjectId('573a13a3f29313caabd0d3a6'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 70, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 7, 22, 17, 39)}},
#  {'_id': ObjectId('573a13a3f29313caabd0e72a'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 109, 'meter': 100},
#    'dvd': datetime.datetime(2006, 1, 17, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 12, 19, 17, 42)}},
#  {'_id': ObjectId('573a13a3f29313caabd0ed93'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 17, 'meter': 100},
#    'dvd': datetime.datetime(2007, 4, 4, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 6, 6, 18, 24, 34)}},
#  {'_id': ObjectId('573a13a3f29313caabd0eeb1'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 20, 'meter': 100},
#    'dvd': datetime.datetime(2010, 5, 4, 0, 0),
#    'production': 'MPI Home Video',
#    'lastUpdated': datetime.datetime(2015, 6, 6, 18, 35, 25)}},
#  {'_id': ObjectId('573a13a4f29313caabd0f478'),
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 52, 'meter': 100},
#    'dvd': datetime.datetime(2008, 2, 26, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 15, 45)}},
#  {'_id': ObjectId('573a13a4f29313caabd0f7b2'),
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 120, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 5, 59)}},
#  {'_id': ObjectId('573a13a4f29313caabd0fd54'),
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 46, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 7, 4, 18, 56, 57)}},
#  {'_id': ObjectId('573a13a4f29313caabd124e2'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 82, 'meter': 100},
#    'dvd': datetime.datetime(2003, 6, 10, 0, 0),
#    'production': 'Showtime Networks Inc.',
#    'lastUpdated': datetime.datetime(2015, 7, 19, 19, 30, 25)}},
#  {'_id': ObjectId('573a13a4f29313caabd12707'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 436, 'meter': 100},
#    'dvd': datetime.datetime(2003, 10, 7, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 16, 20, 20, 21)}},
#  {'_id': ObjectId('573a13a5f29313caabd1370f'),
#   'tomatoes': {'viewer': {'rating': 4.6, 'numReviews': 39, 'meter': 100},
#    'dvd': datetime.datetime(2006, 4, 25, 0, 0),
#    'critic': {'rating': 7.1, 'numReviews': 15, 'meter': 87},
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 5, 5),
#    'rotten': 2,
#    'production': 'Indican Pictures',
#    'fresh': 13}},
#  {'_id': ObjectId('573a13a5f29313caabd1440a'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 36, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 12, 18, 37, 3)}},
#  {'_id': ObjectId('573a13a5f29313caabd14833'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 71, 'meter': 100},
#    'dvd': datetime.datetime(2008, 2, 19, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 2, 25, 17, 27, 34)}},
#  {'_id': ObjectId('573a13a5f29313caabd1489e'),
#   'tomatoes': {'viewer': {'rating': 1.8, 'numReviews': 6, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 19, 15, 40)}},
#  {'_id': ObjectId('573a13a5f29313caabd150ee'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 392, 'meter': 100},
#    'dvd': datetime.datetime(2007, 5, 8, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 13, 17, 18, 28)}},
#  {'_id': ObjectId('573a13a5f29313caabd15a53'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 123, 'meter': 100},
#    'dvd': datetime.datetime(2002, 1, 8, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 6, 25, 18, 1, 39)}},
#  {'_id': ObjectId('573a13a5f29313caabd15dae'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 36, 'meter': 100},
#    'dvd': datetime.datetime(2006, 4, 11, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 1, 18, 37)}},
#  {'_id': ObjectId('573a13a6f29313caabd16a5b'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 86, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 10, 4, 16, 50)}},
#  {'_id': ObjectId('573a13a6f29313caabd18069'),
#   'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 34, 'meter': 100},
#    'dvd': datetime.datetime(2005, 4, 5, 0, 0),
#    'production': 'Anime Works',
#    'lastUpdated': datetime.datetime(2015, 6, 7, 18, 6, 38)}},
#  {'_id': ObjectId('573a13a6f29313caabd18b9f'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 15, 6, 50, 51)}},
#  {'_id': ObjectId('573a13a7f29313caabd1a9d3'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 83, 'meter': 100},
#    'dvd': datetime.datetime(2000, 1, 17, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 45, 48)}},
#  {'_id': ObjectId('573a13a8f29313caabd1d756'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 11, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 10, 0, 0, 6)}},
#  {'_id': ObjectId('573a13a9f29313caabd1f835'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 111, 'meter': 100},
#    'dvd': datetime.datetime(2005, 8, 23, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 6, 1, 18, 10, 54)}},
#  {'_id': ObjectId('573a13a9f29313caabd1f891'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 83, 'meter': 100},
#    'dvd': datetime.datetime(2002, 6, 25, 0, 0),
#    'production': 'Eclectic DVD Distribution',
#    'lastUpdated': datetime.datetime(2014, 11, 15, 16, 39, 47)}},
#  {'_id': ObjectId('573a13a9f29313caabd209d9'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 15, 6, 50, 51)}},
#  {'_id': ObjectId('573a13aaf29313caabd21e57'),
#   'tomatoes': {'website': 'http://www.forgetbaghdad.com',
#    'viewer': {'rating': 3.8, 'numReviews': 83, 'meter': 100},
#    'dvd': datetime.datetime(2006, 9, 26, 0, 0),
#    'critic': {'rating': 6.9, 'numReviews': 12, 'meter': 75},
#    'lastUpdated': datetime.datetime(2015, 7, 18, 18, 59, 48),
#    'rotten': 3,
#    'fresh': 9}},
#  {'_id': ObjectId('573a13aaf29313caabd21f04'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 57, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 2, 18, 28, 43)}},
#  {'_id': ObjectId('573a13abf29313caabd23fa5'),
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 94, 'meter': 100},
#    'dvd': datetime.datetime(2005, 3, 8, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 19, 18, 41, 43)}},
#  {'_id': ObjectId('573a13abf29313caabd242e2'),
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 94, 'meter': 100},
#    'dvd': datetime.datetime(2005, 3, 8, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 19, 18, 41, 43)}},
#  {'_id': ObjectId('573a13abf29313caabd25619'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 45, 'meter': 100},
#    'dvd': datetime.datetime(2004, 6, 8, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 12, 17, 32, 30)}},
#  {'_id': ObjectId('573a13abf29313caabd25623'),
#   'tomatoes': {'viewer': {'rating': 1.9, 'numReviews': 29, 'meter': 100},
#    'dvd': datetime.datetime(2007, 5, 15, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 6, 7, 18, 9, 36)}},
#  {'_id': ObjectId('573a13abf29313caabd2627e'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 169, 'meter': 100},
#    'dvd': datetime.datetime(2007, 5, 29, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 37, 43)}},
#  {'_id': ObjectId('573a13acf29313caabd26a49'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 8, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 18, 18, 25, 13)}},
#  {'_id': ObjectId('573a13acf29313caabd27d25'),
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 48, 'meter': 100},
#    'dvd': datetime.datetime(2009, 9, 15, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 5, 3, 18, 15, 13)}},
#  {'_id': ObjectId('573a13acf29313caabd29433'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 305, 'meter': 100},
#    'dvd': datetime.datetime(2004, 9, 28, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 27, 54)}},
#  {'_id': ObjectId('573a13adf29313caabd29f57'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 44, 'meter': 100},
#    'dvd': datetime.datetime(1998, 1, 1, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 13, 58)}},
#  {'_id': ObjectId('573a13aef29313caabd2c769'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 8, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 18, 18, 25, 13)}},
#  {'_id': ObjectId('573a13aef29313caabd2dd10'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 44, 'meter': 100},
#    'dvd': datetime.datetime(1998, 1, 1, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 13, 58)}},
#  {'_id': ObjectId('573a13aff29313caabd32798'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 264, 'meter': 100},
#    'dvd': datetime.datetime(2005, 8, 2, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 19, 18, 51, 39)}},
#  {'_id': ObjectId('573a13b0f29313caabd3294a'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 52, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 25, 18, 48, 55)}},
#  {'_id': ObjectId('573a13b0f29313caabd33204'),
# ...
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 31, 'meter': 100},
#    'fresh': 1,
#    'critic': {'numReviews': 1},
#    'rotten': 0,
#    'lastUpdated': datetime.datetime(2015, 1, 11, 19, 20, 23)}},
#  {'_id': ObjectId('573a13c8f29313caabd789ec'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 58, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 3, 8, 18, 39, 58)}},
#  {'_id': ObjectId('573a13c8f29313caabd78dc1'),
#   'tomatoes': {'viewer': {'rating': 4.3, 'numReviews': 17, 'meter': 100},
#    'dvd': datetime.datetime(2012, 10, 9, 0, 0),
#    'production': 'FilmBuff',
#    'lastUpdated': datetime.datetime(2015, 8, 3, 18, 40, 56)}},
#  {'_id': ObjectId('573a13c9f29313caabd7a4b9'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 24, 11, 18, 43)}},
#  {'_id': ObjectId('573a13caf29313caabd7d66c'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 13, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 11, 20, 34, 32)}},
#  {'_id': ObjectId('573a13cef29313caabd871a8'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 15, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 10, 19, 53, 35)}},
#  {'_id': ObjectId('573a13cef29313caabd87391'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 7, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 6, 17, 18, 59, 46)}},
#  {'_id': ObjectId('573a13cef29313caabd87d23'),
#   'tomatoes': {'viewer': {'rating': 1.5, 'numReviews': 3, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 3, 21, 18, 55, 21)}},
#  {'_id': ObjectId('573a13d0f29313caabd8cde8'),
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 77, 'meter': 100},
#    'dvd': datetime.datetime(2013, 5, 31, 0, 0),
#    'production': 'Real Fiction',
#    'lastUpdated': datetime.datetime(2015, 7, 19, 18, 21, 27)}},
#  {'_id': ObjectId('573a13d3f29313caabd96882'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 2, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 3, 17, 19, 58, 10)}},
#  {'_id': ObjectId('573a13d3f29313caabd96983'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 7, 5, 29, 31)}},
#  {'_id': ObjectId('573a13d3f29313caabd96e5b'),
#   'tomatoes': {'viewer': {'rating': 2.2, 'numReviews': 3, 'meter': 100},
#    'fresh': 3,
#    'critic': {'numReviews': 3},
#    'rotten': 0,
#    'lastUpdated': datetime.datetime(2015, 1, 25, 13, 59, 39)}},
#  {'_id': ObjectId('573a13d4f29313caabd987c2'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 18, 'meter': 100},
#    'fresh': 1,
#    'critic': {'numReviews': 1},
#    'rotten': 0,
#    'lastUpdated': datetime.datetime(2015, 3, 29, 19, 4, 59)}},
#  {'_id': ObjectId('573a13d4f29313caabd989f9'),
#   'tomatoes': {'viewer': {'rating': 2.9, 'numReviews': 10, 'meter': 100},
#    'production': 'Happiness',
#    'lastUpdated': datetime.datetime(2015, 1, 27, 12, 43, 24)}},
#  {'_id': ObjectId('573a13d4f29313caabd98d81'),
#   'tomatoes': {'viewer': {'rating': 2.7, 'numReviews': 6, 'meter': 100},
#    'fresh': 1,
#    'critic': {'numReviews': 1},
#    'rotten': 0,
#    'lastUpdated': datetime.datetime(2015, 2, 11, 17, 59, 47)}},
#  {'_id': ObjectId('573a13d4f29313caabd99898'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 6, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 24, 9, 24, 10)}},
#  {'_id': ObjectId('573a13d5f29313caabd9d9bb'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 7, 'meter': 100},
#    'dvd': datetime.datetime(2013, 3, 18, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 5, 26, 18, 14, 33)}},
#  {'_id': ObjectId('573a13d6f29313caabd9e052'),
#   'tomatoes': {'viewer': {'rating': 2.2, 'numReviews': 15, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 10, 0, 52, 30)}},
#  {'_id': ObjectId('573a13d6f29313caabd9e3b0'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 6, 3, 15, 21)}},
#  {'_id': ObjectId('573a13d6f29313caabd9f2ee'),
#   'tomatoes': {'website': 'http://www.theinvisiblefront.com/',
#    'viewer': {'rating': 4.7, 'numReviews': 45, 'meter': 100},
#    'critic': {'rating': 7.5, 'numReviews': 7, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 4, 19, 38, 50),
#    'rotten': 0,
#    'production': 'Forest Brothers LLC.',
#    'fresh': 7}},
#  {'_id': ObjectId('573a13d6f29313caabd9f805'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 4, 'meter': 100},
#    'dvd': datetime.datetime(2012, 10, 30, 0, 0),
#    'production': 'Mediapool',
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 24, 24)}},
#  {'_id': ObjectId('573a13d6f29313caabda05f3'),
#   'tomatoes': {'website': 'http://belborbaaqui.wordpress.com/',
#    'viewer': {'rating': 4.6, 'numReviews': 139, 'meter': 100},
#    'critic': {'rating': 5.8, 'numReviews': 13, 'meter': 54},
#    'boxOffice': '$6.1k',
#    'rotten': 6,
#    'production': 'Abramorama Entertainment',
#    'lastUpdated': datetime.datetime(2015, 4, 19, 18, 37, 32),
#    'fresh': 7}},
#  {'_id': ObjectId('573a13d6f29313caabda08f6'),
#   'tomatoes': {'viewer': {'rating': 4.7, 'numReviews': 5, 'meter': 100},
#    'website': 'http://www.manfromorlando.com/',
#    'production': 'KinoNation',
#    'lastUpdated': datetime.datetime(2015, 9, 14, 21, 47, 40)}},
#  {'_id': ObjectId('573a13d7f29313caabda1e26'),
#   'tomatoes': {'viewer': {'rating': 4.8, 'numReviews': 39, 'meter': 100},
#    'website': 'http://thetaiwanoyster.com/',
#    'lastUpdated': datetime.datetime(2015, 7, 9, 18, 48, 20)}},
#  {'_id': ObjectId('573a13d7f29313caabda1ea6'),
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 10, 'meter': 100},
#    'website': 'http://www.wyssozki.de/',
#    'production': 'Unknown',
#    'lastUpdated': datetime.datetime(2015, 3, 24, 19, 21, 21)}},
#  {'_id': ObjectId('573a13d7f29313caabda3379'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 6, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 3, 20, 18, 17, 58)}},
#  {'_id': ObjectId('573a13d7f29313caabda4c64'),
#   'tomatoes': {'viewer': {'rating': 2.7, 'numReviews': 16, 'meter': 100},
#    'website': 'http://www.kaikellarakkaudella.fi/',
#    'lastUpdated': datetime.datetime(2015, 3, 12, 19, 12, 14)}},
#  {'_id': ObjectId('573a13d8f29313caabda6891'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 2, 'meter': 100},
#    'dvd': datetime.datetime(2012, 7, 31, 0, 0),
#    'production': 'LionsGate Entertainment',
#    'lastUpdated': datetime.datetime(2015, 8, 24, 19, 6, 41)}},
#  {'_id': ObjectId('573a13d8f29313caabda71c6'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 8, 'meter': 100},
#    'lastUpdated': datetime.datetime(2014, 11, 24, 10, 21, 16)}},
#  {'_id': ObjectId('573a13d8f29313caabda77f8'),
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 49, 'meter': 100},
#    'website': 'http://www.hivernomade.ch/en/',
#    'lastUpdated': datetime.datetime(2015, 8, 16, 18, 45, 9)}},
#  {'_id': ObjectId('573a13d8f29313caabda8081'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 2, 'meter': 100},
#    'website': 'http://thedeadmile.com/',
#    'lastUpdated': datetime.datetime(2015, 3, 22, 19, 12, 10)}},
#  {'_id': ObjectId('573a13d8f29313caabda81ee'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 3, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 5, 21, 19, 4, 20)}},
#  {'_id': ObjectId('573a13d9f29313caabdaabc6'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 20, 8, 25, 13)}},
#  {'_id': ObjectId('573a13daf29313caabdab49d'),
#   'tomatoes': {'viewer': {'rating': 2.9, 'numReviews': 13, 'meter': 100},
#    'website': 'http://www.thebrusselsbusiness.eu/',
#    'lastUpdated': datetime.datetime(2015, 3, 22, 19, 29, 5)}},
#  {'_id': ObjectId('573a13daf29313caabdab5af'),
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 3, 'meter': 100},
#    'production': 'Synergetic',
#    'lastUpdated': datetime.datetime(2015, 4, 16, 18, 32, 46)}},
#  {'_id': ObjectId('573a13daf29313caabdab7be'),
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 7, 'meter': 100},
#    'fresh': 1,
#    'critic': {'numReviews': 2},
#    'rotten': 1,
#    'lastUpdated': datetime.datetime(2015, 3, 1, 18, 27, 12)}},
#  {'_id': ObjectId('573a13daf29313caabdaba50'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 2, 'meter': 100},
#    'website': 'http://www.facebook.com/azombieinvasion',
#    'lastUpdated': datetime.datetime(2015, 3, 22, 19, 31, 8)}},
#  {'_id': ObjectId('573a13daf29313caabdad7c0'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 8, 8, 50, 4)}},
#  {'_id': ObjectId('573a13dcf29313caabdb2198'),
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 7, 'meter': 100},
#    'dvd': datetime.datetime(2014, 5, 26, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 6, 14, 19, 3, 19)}},
#  {'_id': ObjectId('573a13ddf29313caabdb3a07'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 5, 'meter': 100},
#    'website': 'http://fureverfilm.com/',
#    'production': 'FilmBuff',
#    'lastUpdated': datetime.datetime(2015, 5, 2, 18, 51, 40)}},
#  {'_id': ObjectId('573a13ddf29313caabdb3bb7'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 57, 'meter': 100},
#    'production': 'Indican Pictures',
#    'lastUpdated': datetime.datetime(2015, 4, 11, 19, 9, 15)}},
#  {'_id': ObjectId('573a13ddf29313caabdb46d4'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 64, 'meter': 100},
#    'critic': {'rating': 5.3, 'numReviews': 6, 'meter': 17},
#    'lastUpdated': datetime.datetime(2015, 9, 3, 18, 55, 39),
#    'rotten': 5,
#    'production': 'Amber Entertainment',
#    'fresh': 1}},
#  {'_id': ObjectId('573a13def29313caabdb5beb'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 3, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 12, 16, 55, 53)}},
#  {'_id': ObjectId('573a13def29313caabdb604c'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 3, 24, 18, 30, 15)}},
#  {'_id': ObjectId('573a13def29313caabdb6361'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 3, 13, 18, 35, 14)}},
#  {'_id': ObjectId('573a13def29313caabdb68fb'),
#   'tomatoes': {'website': 'http://seeyounextmovie.com/',
#    'viewer': {'rating': 4.3, 'numReviews': 22, 'meter': 100},
#    'dvd': datetime.datetime(2014, 9, 23, 0, 0),
#    'critic': {'rating': 8.8, 'numReviews': 7, 'meter': 86},
#    'lastUpdated': datetime.datetime(2015, 8, 19, 18, 4, 54),
#    'rotten': 1,
#    'production': 'Devolver Digital',
#    'fresh': 6}},
#  {'_id': ObjectId('573a13dff29313caabdb767f'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 16, 6, 46, 14)}},
#  {'_id': ObjectId('573a13dff29313caabdb84cf'),
#   'tomatoes': {'viewer': {'rating': 4.8, 'numReviews': 12, 'meter': 100},
#    'website': 'http://nosolicitingthemovie.com/',
#    'lastUpdated': datetime.datetime(2014, 11, 25, 12, 46, 54)}},
#  {'_id': ObjectId('573a13dff29313caabdb87e2'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 3, 'meter': 100},
#    'dvd': datetime.datetime(2014, 3, 24, 0, 0),
#    'website': 'http://www.thescenedoc.com/',
#    'production': 'Virgil Films',
#    'lastUpdated': datetime.datetime(2015, 6, 19, 19, 0, 30)}},
#  {'_id': ObjectId('573a13dff29313caabdb8a66'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 46, 'meter': 100},
#    'website': 'http://www.bridgetunnelfilm.com',
#    'production': 'Glacier Road Productions',
#    'lastUpdated': datetime.datetime(2015, 8, 23, 18, 44, 47)}},
#  {'_id': ObjectId('573a13e0f29313caabdba6c8'),
#   'tomatoes': {'viewer': {'rating': 2.6, 'numReviews': 9, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 3, 27, 20, 4, 26)}},
#  {'_id': ObjectId('573a13e0f29313caabdba876'),
#   'tomatoes': {'website': 'http://www.llynfoulkesfilm.com/',
#    'viewer': {'rating': 4.8, 'numReviews': 63, 'meter': 100},
#    'critic': {'rating': 7.7, 'numReviews': 10, 'meter': 90},
#    'lastUpdated': datetime.datetime(2015, 6, 18, 18, 5, 41),
#    'rotten': 1,
#    'production': 'Tamaroland Pictures',
#    'fresh': 9}},
#  {'_id': ObjectId('573a13e0f29313caabdbb92a'),
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 3, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 2, 8, 6, 35, 33)}},
#  {'_id': ObjectId('573a13e1f29313caabdbc331'),
#   'tomatoes': {'viewer': {'rating': 4.7, 'numReviews': 43, 'meter': 100},
#    'website': 'http://www.berkshirecounty-themovie.com/',
#    'production': 'A71 Entertainment',
#    'lastUpdated': datetime.datetime(2015, 7, 7, 18, 51, 35)}},
#  {'_id': ObjectId('573a13e1f29313caabdbd251'),
#   'tomatoes': {'website': 'http://www.defriest.com/',
#    'viewer': {'rating': 4.5, 'numReviews': 116, 'meter': 100},
#    'critic': {'rating': 7.2, 'numReviews': 10, 'meter': 90},
#    'lastUpdated': datetime.datetime(2015, 8, 23, 16, 23, 16),
#    'rotten': 1,
#    'production': 'City Drive Films',
#    'fresh': 9}},
#  {'_id': ObjectId('573a13e3f29313caabdc0372'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 4, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 3, 27, 20, 12, 29)}},
#  {'_id': ObjectId('573a13e3f29313caabdc08a4'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 2, 'meter': 100},
#    'website': 'http://www.facebook.com/MaryLossofSoul',
#    'lastUpdated': datetime.datetime(2014, 11, 25, 3, 47, 35)}},
#  {'_id': ObjectId('573a13e4f29313caabdc1572'),
#   'tomatoes': {'viewer': {'rating': 4.8, 'numReviews': 44, 'meter': 100},
#    'website': 'http://www.hardsunmovie.com',
#    'lastUpdated': datetime.datetime(2015, 5, 30, 19, 2, 5)}},
#  {'_id': ObjectId('573a13e4f29313caabdc16b7'),
#   'tomatoes': {'website': 'http://www.earthsgoldenplayground.com',
#    'viewer': {'rating': 5.0, 'numReviews': 36, 'meter': 100},
#    'critic': {'rating': 0.0, 'numReviews': 5, 'meter': 20},
#    'lastUpdated': datetime.datetime(2015, 4, 27, 18, 24),
#    'rotten': 4,
#    'fresh': 1}},
#  {'_id': ObjectId('573a13e4f29313caabdc20b2'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 2, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 24, 21, 3, 36)}},
#  {'_id': ObjectId('573a13e5f29313caabdc2878'),
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 2, 'meter': 100},
#    'lastUpdated': datetime.datetime(2014, 11, 25, 14, 58)}},
#  {'_id': ObjectId('573a13e5f29313caabdc30fa'),
#   'tomatoes': {'website': 'http://www.facebook.com/twinstersmovie',
#    'viewer': {'rating': 4.7, 'numReviews': 156, 'meter': 100},
#    'critic': {'rating': 8.0, 'numReviews': 10, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 43, 44),
#    'rotten': 0,
#    'production': 'Ignite Channel',
#    'fresh': 10}},
#  {'_id': ObjectId('573a13e5f29313caabdc418e'),
#   'tomatoes': {'viewer': {'rating': 4.9, 'numReviews': 39, 'meter': 100},
#    'dvd': datetime.datetime(2014, 1, 14, 0, 0),
#    'website': 'http://video.pbs.org/video/2365141872/',
#    'production': 'PBS Home Video',
#    'lastUpdated': datetime.datetime(2015, 6, 7, 18, 5, 38)}},
#  {'_id': ObjectId('573a13e6f29313caabdc628c'),
#   'tomatoes': {'viewer': {'rating': 5.0, 'numReviews': 3, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 4, 8, 18, 56, 58)}},
#  {'_id': ObjectId('573a13e7f29313caabdc6d63'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 16, 5, 44, 9)}},
#  {'_id': ObjectId('573a13e7f29313caabdc6de0'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 2, 'meter': 100},
#    'website': 'http://www.takepart.com/misconception',
#    'production': 'Third Rail Films',
#    'lastUpdated': datetime.datetime(2015, 4, 8, 19, 6, 23)}},
#  {'_id': ObjectId('573a13e7f29313caabdc7077'),
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 1, 10, 19, 15, 47)}},
#  {'_id': ObjectId('573a13e7f29313caabdc7a00'),
#   'tomatoes': {'viewer': {'rating': 4.5, 'numReviews': 24, 'meter': 100},
#    'production': 'American Cinematheque',
#    'lastUpdated': datetime.datetime(2015, 9, 2, 18, 7, 23)}}]

# %%
#confirm the above result
movies.find_one(
    {
        "tomatoes.viewer.meter": {'$exists': True}
    },
    {
        "_id": True,
        "tomatoes.viewer.meter": True
    },
    sort=[("tomatoes.viewer.meter", -1)])
# Out:
# {'_id': ObjectId('573a1391f29313caabcd952a'),
#  'tomatoes': {'viewer': {'meter': 100}}}

# %%
#Combien de films dont "Jeff Bridges" a joué dedans ?
movies.count_documents(
    {"cast": "Jeff Bridges"}
)
# Out:
# 44

# %%
#idem mais "Jeff Bridges" se trouve ds la 1è position de l'array' "actors" ?
movies.count_documents(
    {"cast.0": "Jeff Bridges"}
)
# Out:
# 25

# %%
#Combien de films dont le "runtime" est sup ou égale à 90 min ET inf ou égale à 120 min ?
movies.count_documents({
    "runtime": {"$gte": 90,
                "$lte": 120}
})
# Out:
# 13060

# %%
#Combien de films dont le "runtime" est sup ou égale à 90 min ET inf ou égale à 120 min ?
pipeline = [
    {
        "$match": {
            "runtime": {"$gte": 90,
                        "$lte": 120}
        }
    },
    {
        "$count": "runtime_counter"
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'runtime_counter': 13060}]

# %%
#Combien de films dont le meter de la clé tomatoes est sup à 95 OU le "metacritic" est sup à 88 ?
movies.count_documents({"tomatoes.viewer.meter": {'$gte': 30},
                        "tomatoes.critic.meter": {'$gte': 30}})
# Out:
# 8618

# %%
#Combien de films dont le meter de la clé tomatoes est sup ou égale à 95 min ET le "runtime" est sup à 180 min
movies.count_documents({"tomatoes.viewer.meter": {'$gte': 95},
                        "runtime": {'$gte': 180}})
# Out:
# 26

# %%
#Combien de films dont le meter de la clé tomatoes est sup ou égale à 95 min ET le "runtime" est sup à 180 min
pipeline = [
    {
        "$match": {
            "$and": [
                {"tomatoes.viewer.meter": {"$gte": 95}},
                {"runtime": {"$gte": 180}}
            ]
        },
    },
]
len(list(movies.aggregate(pipeline)))
# Out:
# 26

# %%
#Combien de films dont la clé "tomatoes.viewer.meter" n'est pas égale à "blabla" ?
movies.count_documents({"tomatoes.viewer.meter": {"$ne": "blabla"}})  # same as movies.count_documents({})
# Out:
# 21349

# %%
#Combien de films dont la clé "tomato.meter" existe (et inversement)
movies.count_documents({"tomatoes.viewer.meter": {"$exists": 1}})
# Out:
# 16199

# %%
#Combien de films dont la clé "tomato.meter" existe (et inversement)
movies.count_documents({"tomatoes.viewer.meter": {"$exists": 0}})
# Out:
# 5150

# %%
#modifier dans le document ayant le title : Blacksmith Scene, la valeur de l'attribut movie à "blabla"
movies.update_one(
    {"title": "Blacksmith Scene"},
    {"$set": {"movie": "blabla"}}
)
# Out:
# UpdateResult({'n': 0, 'electionId': ObjectId('7fffffff00000000000000b2'), 'opTime': {'ts': Timestamp(1725309777, 92), 't': 178}, 'nModified': 0, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1725309777, 92), 'signature': {'hash': b'}XO\xbc\x82\x16\x99\xe4G\x85\xd3\xcdg\xb20\xc6v\xe1;\xbe', 'keyId': 7351789228159664129}}, 'operationTime': Timestamp(1725309777, 92), 'updatedExisting': False}, acknowledged=True)

# %%
#Combien de films ont été écrit par ""Ethan Coen" et "Joel Coen"" ?
pipeline = [
    {"$match": {
        "writers": {"$in": ["Ethan Coen", "Joel Coen"]}
    }}
]
len(list(movies.aggregate(pipeline)))
# Out:
# 14

# %%
movies.count_documents({"writers": {"$in": ["Joel Coen", "Ethan Coen"]}})
# Out:
# 14

# %%
movies.find({"writers": {"$eq": ["Ethan Coen", "Joel Coen"]}}).distinct("_id")
# Out:
# [ObjectId('573a1398f29313caabcea992'),
#  ObjectId('573a139af29313caabcefe7e'),
#  ObjectId('573a139af29313caabcf0797')]

# %%
movies.find({"writers": {"$eq": ["Joel Coen", "Ethan Coen"]}}).distinct("_id")
# Out:
# [ObjectId('573a1398f29313caabce8fe0'),
#  ObjectId('573a1399f29313caabcec141'),
#  ObjectId('573a1399f29313caabcec611'),
#  ObjectId('573a13a3f29313caabd0db04'),
#  ObjectId('573a13bbf29313caabd52b17'),
#  ObjectId('573a13bdf29313caabd597d1'),
#  ObjectId('573a13d5f29313caabd9d807')]

# %%
#Combien de film ont été produit par un seul pays ?
pipeline = [
    {"$group": {"_id": "$countries", "total": {"$sum": 1}}},
    {"$sort": {"total": -1}},
]
list(movies.aggregate(pipeline))[:5]
# Out:
# [{'_id': ['USA'], 'total': 8225},
#  {'_id': ['UK'], 'total': 999},
#  {'_id': ['France'], 'total': 717},
#  {'_id': ['Japan'], 'total': 556},
#  {'_id': ['Canada'], 'total': 498}]

# %%
pipeline = [
    {
        "$unwind": "$countries"  # Décompose les tableaux de pays en documents individuels
    },
    {
        "$group": {
            "_id": "$countries",  # Grouper par pays de production
            "filmCount": {"$sum": 1}  # Compter le nombre de films pour chaque pays
        }
    },
    {
        "$project": {
            "_id": 0,  # Ne pas inclure l'ID de groupe dans les résultats
            "country": "$_id",  # Renommer l'ID du groupe en "country"
            "filmCount": 1  # Inclure le compte des films
        }
    },
    {
        "$sort": {"filmCount": -1}
    }
]
list(movies.aggregate(pipeline))[:5]
# Out:
# [{'filmCount': 10921, 'country': 'USA'},
#  {'filmCount': 2652, 'country': 'UK'},
#  {'filmCount': 2647, 'country': 'France'},
#  {'filmCount': 1494, 'country': 'Germany'},
#  {'filmCount': 1260, 'country': 'Canada'}]

# %%
#Combien de film dont la clé genre est un tableau qui contient Comedy, Crime et Drame ?
pipeline = [
    {
        "$match": {
            "genres": {
                "$all": ["Comedy", "Crime", "Drama"],  # Le tableau doit contenir tous ces genres
            }
        }
    },
    {
        "$count": "numMovies"  # Compte le nombre de documents qui correspondent au critère
    }
]
list(movies.aggregate(pipeline))
# Out:
# [{'numMovies': 155}]

# %%
result=list(movies.find({
    "countries":["UK"],
    "tomatoes.boxOffice":{"$exists":True}
},
    {"tomatoes.boxOffice":1}
))
list_suffix=set(elem['tomatoes']['boxOffice'][0] for elem in result)
list_suffix
# Out:
# {'$'}

# %%
pipeline = [
    {
        "$addFields": {
            "boxOfficeUK": {
                "$cond": {
                    "if": {"$regexMatch": {"input": "$tomatoes.boxOffice", "regex": "^\\$[0-9]+(\\.[0-9]+)?M"}},
                    "then": {
                        "$toDouble": {
                            "$substr": [
                                "$tomatoes.boxOffice",
                                1,
                                {"$subtract": [{"$strLenBytes": "$tomatoes.boxOffice"}, 2]}
                            ]
                        }
                    },
                    "else": 0
                }
            }
        }
    },
    {
        "$match": {
            "countries":["UK"],
            "boxOfficeUK": {"$gt": 5}
        }
    },
    {
        "$project": {
            "_id": 0,
            "country": 1,
            "tomatoes.boxOffice":1
        }
    }
]

list(movies.aggregate(pipeline))
# Out:
# [{'tomatoes': {'boxOffice': '$11.5M'}},
#  {'tomatoes': {'boxOffice': '$44.9M'}},
#  {'tomatoes': {'boxOffice': '$8.0M'}},
#  {'tomatoes': {'boxOffice': '$26.0M'}},
#  {'tomatoes': {'boxOffice': '$17.4M'}},
#  {'tomatoes': {'boxOffice': '$25.4M'}},
#  {'tomatoes': {'boxOffice': '$39.7M'}},
#  {'tomatoes': {'boxOffice': '$30.2M'}},
#  {'tomatoes': {'boxOffice': '$9.0M'}},
#  {'tomatoes': {'boxOffice': '$18.4M'}},
#  {'tomatoes': {'boxOffice': '$6.4M'}},
#  {'tomatoes': {'boxOffice': '$12.8M'}},
#  {'tomatoes': {'boxOffice': '$15.0M'}},
#  {'tomatoes': {'boxOffice': '$15.3M'}},
#  {'tomatoes': {'boxOffice': '$10.7M'}},
#  {'tomatoes': {'boxOffice': '$128.3M'}},
#  {'tomatoes': {'boxOffice': '$35.9M'}}]
